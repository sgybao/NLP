# %% [markdown]
# # Homework 1: Preprocessing and Text Classification

# %% [markdown]
# Student Name: Yue Bao
#
# Student ID: 1011641

# %% [markdown]
# # General Info
#
# <b>Due date</b>: Sunday, 5 Apr 2020 5pm
#
# <b>Submission method</b>: Canvas submission
#
# <b>Submission materials</b>: completed copy of this iPython notebook
#
# <b>Late submissions</b>: -20% per day (both week and weekend days counted)
#
# <b>Marks</b>: 10% of mark for class (with 9% on correctness + 1% on quality and efficiency of your code)
#
# <b>Materials</b>: See [Using Jupyter Notebook and Python page](https://canvas.lms.unimelb.edu.au/courses/17601/pages/using-jupyter-notebook-and-python?module_item_id=1678430) on Canvas (under Modules>Resources) for information on the basic setup required for this class, including an iPython notebook viewer and the python packages NLTK, Numpy, Scipy, Matplotlib, Scikit-Learn, and Gensim. In particular, if you are not using a lab computer which already has it installed, we recommend installing all the data for NLTK, since you will need various parts of it to complete this assignment. You can also use any Python built-in packages, but do not use any other 3rd party packages (the packages listed above are all fine to use); if your iPython notebook doesn't run on the marker's machine, you will lose marks. <b> You should use Python 3</b>.
#
# To familiarize yourself with NLTK, here is a free online book:  Steven Bird, Ewan Klein, and Edward Loper (2009). <a href=http://nltk.org/book>Natural Language Processing with Python</a>. O'Reilly Media Inc. You may also consult the <a href=https://www.nltk.org/api/nltk.html>NLTK API</a>.
#
# <b>Evaluation</b>: Your iPython notebook should run end-to-end without any errors in a reasonable amount of time, and you must follow all instructions provided below, including specific implementation requirements and instructions for what needs to be printed (please avoid printing output we don't ask for). You should edit the sections below where requested, but leave the rest of the code as is. You should leave the output from running your code in the iPython notebook you submit, to assist with marking. The amount each section is worth is given in parenthesis after the instructions.
#
# You will be marked not only on the correctness of your methods, but also the quality and efficency of your code: in particular, you should be careful to use Python built-in functions and operators when appropriate and pick descriptive variable names that adhere to <a href="https://www.python.org/dev/peps/pep-0008/">Python style requirements</a>. If you think it might be unclear what you are doing, you should comment your code to help the marker make sense of it.
#
# <b>Updates</b>: Any major changes to the assignment will be announced via Canvas. Minor changes and clarifications will be announced on the discussion board; we recommend you check it regularly.
#
# <b>Academic misconduct</b>: For most people, collaboration will form a natural part of the undertaking of this homework, and we encourge you to discuss it in general terms with other students. However, this ultimately is still an individual task, and so reuse of code or other instances of clear influence will be considered cheating. We will be checking submissions for originality and will invoke the University’s <a href="http://academichonesty.unimelb.edu.au/policy.html">Academic Misconduct policy</a> where inappropriate levels of collusion or plagiarism are deemed to have taken place.

# %% [markdown]
# # Overview
#
# In this homework, you'll be working with a collection tweets. The task is to classify whether a tweet constitutes a rumour event. This homework involves writing code to preprocess data and perform text classification.

# %% [markdown]
# # 1. Preprocessing (5 marks)

# %% [markdown]
# **Instructions**: Run the code below to download the tweet corpus for the assignment. Note: the download may take some time. **No implementation is needed.**

# %%
import requests
import os
from pathlib import Path

fname = 'rumour-data.tgz'
data_dir = os.path.splitext(fname)[0] #'rumour-data'

my_file = Path(fname)
if not my_file.is_file():
    url = "https://github.com/jhlau/jhlau.github.io/blob/master/files/rumour-data.tgz?raw=true"
    r = requests.get(url)

    #Save to the current directory
    with open(fname, 'wb') as f:
        f.write(r.content)
        
print("Done. File downloaded:", my_file)
# Out:
# Done. File downloaded: rumour-data.tgz

# %% [markdown]
# **Instructions**: Run the code to extract the zip file. Note: the extraction may take a minute or two. **No implementation is needed.**

# %%
import tarfile

#decompress rumour-data.tgz
tar = tarfile.open(fname, "r:gz")
tar.extractall()
tar.close()

#remove superfluous files (e.g. .DS_store)
extra_files = []
for r, d, f in os.walk(data_dir):
    for file in f:
        if (file.startswith(".")):
            extra_files.append(os.path.join(r, file))
for f in extra_files:
    os.remove(f)

print("Extraction done.")
# Out:
# Extraction done.

# %% [markdown]
# ### Question 1 (1.0 mark)
#
# **Instructions**: The corpus data is in the *rumour-data* folder. It contains 2 sub-folders: *non-rumours* and *rumours*. As the names suggest, *rumours* contains all rumour-propagating tweets, while *non-rumours* has normal tweets. Within  *rumours* and *non-rumours*, you'll find some sub-folders, each named with an ID. Each of these IDs constitutes an 'event', where an event is defined as consisting a **source tweet** and its **reactions**.
#
# An illustration of the folder structure is given below:
#
#     rumour-data
#         - rumours
#             - 498254340310966273
#                 - reactions
#                     - 498254340310966273.json
#                     - 498260814487642112.json
#                 - source-tweet
#                     - 498254340310966273.json
#         - non-rumours
#
# Now we need to gather the tweet messages for rumours and non-rumour events. As the individual tweets are stored in json format, we need to use a json parser to parse and collect the actual tweet message. The function `get_tweet_text_from_json(file_path)` is provided to do that.
#
# **Task**: Complete the `get_events(event_dir)` function. The function should return **a list of events** for a particular class of tweets (e.g. rumours), and each event should contain the source tweet message and all reaction tweet messages.
#
# **Check**: Use the assertion statements in *"For your testing"* below for the expected output.

# %%
import json

def get_tweet_text_from_json(file_path):
    with open(file_path) as json_file:
        data = json.load(json_file)
        return data["text"]
    
def get_events(event_dir):
    event_list = []
    for event in sorted(os.listdir(event_dir)):
        if event != '.DS_Store':
            each_event = []
            tweet_path = os.path.join(event_dir, event, 'source-tweet')
            for json_tweet in os.listdir(tweet_path):
                tweet = get_tweet_text_from_json(tweet_path + '/' + json_tweet)
                each_event.append(tweet)

            reaction_path = os.path.join(event_dir, event, 'reactions')
            for json_reaction in os.listdir(reaction_path):
                reaction = get_tweet_text_from_json(reaction_path + '/' + json_reaction)
                each_event.append(reaction)
        
            event_list.append(each_event)  
    return event_list
    
#a list of events, and each event is a list of tweets (source tweet + reactions)    
rumour_events = get_events(os.path.join(data_dir, "rumours"))
nonrumour_events = get_events(os.path.join(data_dir, "non-rumours"))

print("Number of rumour events =", len(rumour_events))
print("Number of non-rumour events =", len(nonrumour_events))
# Out:
# Number of rumour events = 500
# Number of non-rumour events = 1000

# %% [markdown]
# **For your testing:**

# %%
assert(len(rumour_events) == 500)
assert(len(nonrumour_events) == 1000)

# %%
rumour_events
# Out:
# [['Michael Brown is the 17 yr old boy who was shot 10x &amp; killed by police in #Ferguson today. Media reports "police shoot man". #blackboysonly',
#   '@TrueNameBrand @CyMadD0x @AmeenaGK \n\nYou must be too "racist" to notice how the #WarOnWomen is stopping us all from getting equal pay...',
#   '@d_m_elms @jaythenerdkid or traces back some bogus allegations of something he did in kindergarten. All to justify that he was "dangerous"',
#   '@AmeenaGK @RaavynnDigitaL how quaint. black men are "boys" until saying so would get police in trouble, then they\'re "men" and "thugs".',
#   '@retrocombine @AmeenaGK was 18 and assaulted a police officer.',
#   '@kevinwmiller @AmeenaGK ???',
#   'I meant MSM report, not NYPD report, but point taken. @justinstoned @PsychicDogTalk @AmeenaGK',
#   '@kevinwmiller @AmeenaGK @retrocombine Does not excuse that he was shot ten times. Ten. To protect what? The candy?',
#   "@AmeenaGK He's a young boy.",
#   '@AmeenaGK @retrocombine Was this "boy" over six feet and around 200lbs?',
#   "The reason black on black violence isn't reported is because nobody gives a shit if poor people kill each other. @PsychicDogTalk @AmeenaGK",
#   'You do know there are black cops right? Also, what is a "libertarian" doing siding with the pigs? @PsychicDogTalk @AmeenaGK',
#   "@AmeenaGK @retrocombine Of course she's upset, her son is dead. It wouldn't matter to her who is at fault.",
#   "msm that's cable right? @CyMadD0x @PsychicDogTalk @AmeenaGK",
#   '@AmeenaGK @jaythenerdkid CHILD KILLED TO PROTECT CANDY should be the headline',
#   "@kevinwmiller @retrocombine What happened BEFORE the cop was pushed? If it is what happened, what motivated it? That's where the story is.",
#   "@AmeenaGK @retrocombine I just don't understand jumping to conclusions and turning everything into a race war.",
#   'Michael Brown is the 17 yr old boy who was shot 10x &amp; killed by police in #Ferguson today. Media reports "police shoot man". #blackboysonly',
#   "@CyMadD0x @AmeenaGK\n\njust pointing out the double Standard between how black and black violence is barely reported\n\nI'm not screaming racism",
#   '@kevinwmiller @AmeenaGK people bring up race because race issues are a major problem these days.',
#   '@kevinwmiller @retrocombine Even if that is the case, it does not warrant 8 bullets in your back.',
#   "@kevinwmiller @AmeenaGK i got no idea what the deal is with this specific case. but i do know that there's a much larger problem out there.",
#   '@AmeenaGK @retrocombine Two shots fired outside police car. Where is the eight bullets in your back?',
#   '@CyMadD0x @AmeenaGK \n\nAll the democrats run on these days is #racism, sexism &amp; communism. \n\nI hope incident was captured on camera\n\n#Trayvon',
#   "@kevinwmiller @AmeenaGK that may or may not resolve this one case, but there's still a larger problem that needs to be addressed.",
#   "@retrocombine @AmeenaGK This didn't seem racially motivated. It seemed like a criminal trying to take an officers gun then he got shot.",
#   '@AmeenaGK @retrocombine Yeah, I agree. Just sit back and wait for all the facts is all. See what really happened.',
#   '@AmeenaGK @RaavynnDigitaL what a fucking joke.',
#   'tru for most marginlized grps in nyc. try reporting gay domestic violence in bed stuy. @CyMadD0x @PsychicDogTalk @AmeenaGK',
#   '@AmeenaGK @retrocombine Two men struggled with an officer, pushes him back in and went for his sidearm. Weapon fired inside police car.',
#   '@AmeenaGK @retrocombine 17 year old boy?',
#   '@AmeenaGK @kevinwmiller i agree. i consider it excessive force.',
#   "@kevinwmiller @AmeenaGK regardless of whether something's a race war or not, there's serious racial issues in the US.",
#   "@kevinwmiller @AmeenaGK i'm not sure how that matters, he's still underage",
#   "@AmeenaGK he's not a Boy. Racist",
#   '@AmeenaGK @retrocombine According to CBS, http://t.co/Joj9cniAE4',
#   '@AmeenaGK @CyMadD0x \n\nAn unarmed black 17 year old was shot by cops instead of fellow blacks... \n\nBetter make national news of it #Ferguson',
#   "@retrocombine @AmeenaGK If I pushed a cop back into his car, and then went for his gun, I'd assume I'd be shot. Me being white and all.",
#   '@kevinwmiller @AmeenaGK what matters here is the reaction. this has brought a lot of racially-motivated events to light.',
#   '@AmeenaGK @jaythenerdkid And how long before a conservative pundit finds some pic of him messing around with friends to ID him as a "man"',
#   "It's not some leftist conspiracy to make black people seem less violent. #tinfoilin =p @PsychicDogTalk @AmeenaGK",
#   '@kevinwmiller @retrocombine That\'s what the mother says; &amp; even the police chief said "more than a couple" http://t.co/iUTZSW8ZgE.',
#   "@d_m_elms @AmeenaGK they'll drag his entire history. every stolen sip of his dad's beer, every second-hand tendril of pot smoke. watch.",
#   '@AmeenaGK @retrocombine If it happened? How else would a shot be fired inside a police car?'],
#  ["17 year old unarmed kid shot ten times by police for stealing candy. I didn't know that was punishable by death.\n\n(read the #ferguson tag)",
#   "@inthefade there's no excuse",
#   '@inthefade He was 18. Nothing to do with stealing candy. He was walking in the street. Horrible situation. But stop spreading false facts.',
#   '@inthefade It is if someone starts assaulting an officer',
#   '@AnneMarieFlynn2 @adam_zander @inthefade This is unbelievable, or should be.',
#   '@JackieWillard2 These days anything, especially with Stand Your Ground and even a sneeze is punishable by death. @inthefade',
#   '@Alasscan_ @inthefade true',
#   ". @inthefade We don't even know that he stole any candy.",
#   "No excuse. “@inthefade: 17 year old unarmed kid shot ten times by police for stealing candy. I didn't know that was punishable by death.",
#   '@AnneMarieFlynn2 @klemosy @inthefade Anything is punishable by death if the youth is black.',
#   '@inthefade @Alasscan_ apparently it is now',
#   "@pjhnsn8 I was just going off what I read in the #ferguson tag early last night. Wasn't any real news out at that point.",
#   '@inthefade #Shot ten times for stealing candy? God have mercy!',
#   '@inthefade @divineem It applies to Black people.',
#   '@inthefade there has not been any proof that he stole candy. I guess skittles(candy) has become a reason to kill black teens.',
#   '@inthefade @Alllwftopic Agreed! Should be charged w/murder!!',
#   '.@inthefade This story makes me physically sick. @marieann66 #ferguson  http://t.co/PDo2pakAln',
#   '@inthefade @Smilingl8dy you should say "allegedly" about the stealing candy. Also, police stmt does not mention that as cause.',
#   '@inthefade I understand, it has changed to cigs,  a tussle in a car, and then his saggy pants,maybe there never will be a truthful story.',
#   "@inthefade @Alasscan_ It's not-unless you happen to be a black male,apparently.We have to make police far more accountable. This can't go on",
#   "17 year old unarmed kid shot ten times by police for stealing candy. I didn't know that was punishable by death.\n\n(read the #ferguson tag)"],
#  ['White man aiming down on police...nothing happens. Unarmed black kid walking back from store shot 10 times. #Ferguson http://t.co/48EcUF2Bwa'],
#  ["Teenager #MikeBrown won't start college on Monday because he was shot ten times by a #Ferguson police officer. http://t.co/B4hWevO7l9",
#   '@armybulldog20 http://t.co/cFWVhcZMx1',
#   '@RedwoodGirl @YourAnonGlobal @YourAnonNews I will do that. Thanks again for help.',
#   '@sweden  Glad I could help. Are you really in Sweden? The US must seem barbaric to Europeans from stories like this. :(',
#   '@YourAnonGlobal @2squig when I was a teen I read "Black Like Me" and things have not progressed much if at all',
#   "@cosmiclandmine There may be a little more to the story. I'll wait before  I pass judgement. It is always bad when a person dies.",
#   "@I_hate_it_here_ @ArmyBulldog20 @YourAnonGlobal everybody knows that 'walking while black' is a very serious crime to racist police. Obvs.",
#   "Teenager #MikeBrown won't start college on Monday because he was shot ten times by a #Ferguson police officer. http://t.co/B4hWevO7l9",
#   '@YourAnonGlobal \nSame age as my son, then.',
#   '@7um9_ Should have been thank you for the link.',
#   '@RedwoodGirl Well, we have our own things that is bad. But not as much as you have.',
#   '@RedwoodGirl @sweden @YourAnonGlobal @YourAnonNews &amp; the UK Home Office is relaxed about routinely arming our police?\nI definitely think not',
#   '@YourAnonGlobal @cannotthinkwhy 10 bloody shots to down someone? Bionic man? Or just police overkill?',
#   '@armybulldog20 no worries.',
#   "@sweden @YourAnonGlobal @YourAnonNews Yes, it's an awful event. Check the #Ferguson hashtag for lots of anger and sadness.",
#   '@YourAnonGlobal @TefPoe WTF? Is this for real?',
#   '@YourAnonGlobal What was Mike doing?',
#   '@YourAnonGlobal @2squig holy crap .....',
#   '@sweden @YourAnonGlobal @YourAnonNews Eyewitness report in the Post-Dispatch story says Brown fled from being put in police car. &gt;',
#   ".@billthenewguy Racism is about as dumb as it gets. We're all from the same race (human) @YourAnonGlobal",
#   "@YourAnonGlobal @YourAnonNews what's the story? it's sad but posting a picture of this poor kid dead means nothing.",
#   '@YourAnonGlobal @YourAnonNews What is this about? Can you give me a link where I can read about it please?',
#   '@RedwoodGirl @YourAnonGlobal @YourAnonNews Oh my god. For shoplifting? This is awful! I have to read. Thank you!',
#   '@YourAnonGlobal @YourAnonNews Ten times too many',
#   '@7um9_ Thanks you.',
#   "“@YourAnonGlobal: #MikeBrown won't start college Monday because he was shot ten times by a #Ferguson police officer. http://t.co/FABNrZ9iCQ”",
#   "@TonyMoule47 @YourAnonGlobal \nLooks like cops feel free to shoot to kill, if the target is a black man\nI doubt we'll see a cop jailed for it",
#   "@YourAnonGlobal @robert_veres Mike Brown's family wish is to not post pictures of his dead body , thx",
#   '@sweden @YourAnonGlobal @YourAnonNews Which was probably not a good idea, but no way does it deserve getting shot ten times and killed.',
#   '@sweden @youranonglobal @youranonnews http://t.co/cFWVhcZMx1',
#   '@sweden @YourAnonGlobal @YourAnonNews St Louis Post Dispatch story: http://t.co/I6hatQKNWI. Apparently he shoplifted a candy bar.',
#   '@Renemies http://t.co/W1n9bYASlc',
#   '@ArmyBulldog20 @YourAnonGlobal walking while black'],
#  ['Supposedly there might be one or two witnesses who have the shooting or part of the shooting recorded on their phones. #Ferguson'],
#  ['St. Louis: Unarmed teenager #MikeBrown was shot ten times by a #Ferguson police officer for accusation of shoplifting http://t.co/cmaG8mnMiP'],
#  ['Witness: Police allegedly stopped Mike Brown after yelling at him to walk on sidewalk. #Ferguson http://t.co/XG00R6w0k6',
#   '@MichaelSkolnik @AC_BOwen #Cleveland Any Excuse Will Do.\nIn A Police Chase 11-29-12~#2UnarmedBLACKS #MURDERED \nBy #13RACISTCOPS #137GUNSHOTS',
#   '@MichaelSkolnik @AC_BOwen #GOOGLE #Cleveland Police Shoot\n137 Times&lt;~#MURDERING #2UNARMEDBLACKS They Have \n#MURDERED Many #UNARMEDBLACKS',
#   'Another win for the gene pool @MichaelSkolnik',
#   '“@MichaelSkolnik: Witness: Police allegedly stopped Mike Brown after yelling at him to walk on sidewalk. #Ferguson http://t.co/TYdMSNxGlo”',
#   '@MichaelSkolnik cool! Darkskinned man is a crime element in your village?? So, why #obama is alive yet???',
#   "If u think something another says can somehow hold you back, you're a loser &amp; deserve failure @TimmyTurnUp @MichaelSkolnik @Agent_Kindi",
#   '@MichaelSkolnik @AC_BOwen #Cleveland A Cop Shot A 19yr Old In The \nHead! #Black #Unarmed #MomsOnlyChild Cop Said He #THOUGHT He\nSaw A Gun!!!',
#   'Witness: Police allegedly stopped Mike Brown after yelling at him to walk on sidewalk. #Ferguson http://t.co/XG00R6w0k6',
#   "@Agent_Kindi&lt;&lt;&lt;&lt; @SecretService I Don't Like His Tweet Asking Why \nIs #Obama Alive Yet!! #WePray #SecretService  @MichaelSkolnik",
#   "@Progress4Ohio @MichaelSkolnik  I'm not RACIST. We live together with over 200 nations in Russia. And U can go out for this words, mucacho.",
#   '@MichaelSkolnik @AC_BOwen #Cleveland #MalissaWilliamsAndTimothyRussell\nGot No #Justice 12 Of The #13RacistCops #NotCHARGED #BlackLifeMatters',
#   '@Agent_Kindi&lt;&lt;&lt;~~~~It Is People Like You That #MURDER #UNARMEDBLACKS You Ask Why Is #Obama Still Alive.#RACIST \n#KKK #SMH @MichaelSkolnik',
#   '@Supreme___Power @MichaelSkolnik You so edgy.',
#   '@MichaelSkolnik @AC_BOwen #Cleveland @CivilRights \n#MalissaWilliamsAndTimothyRussell Were Shot Up,#UNARMED \n12 Of #13RacistCops #NotCHARGED',
#   '@TimmyTurnUp @MichaelSkolnik @Agent_Kindi @Supreme___Power White guys jealous.',
#   '@MichaelSkolnik @Agent_Kindi @Supreme___Power These responses explain why thiskeeps happening. Too many white men hate black men. Sad.',
#   '@TimmyTurnUp @MichaelSkolnik @Supreme___Power U just want to say "white is guilty, because they white"? In Moscow black guys sold drugs...',
#   '@MichaelSkolnik @AC_BOwen #Cleveland @CivilRights #2UNARMEDBLACKS\n#MURDERED 11-29-12~The Case Was Being Covered Up~Mayor Was On Cops Sides!!',
#   '@TimmyTurnUp @MichaelSkolnik @Supreme___Power so, what the fuck? Is anyone in your village walk through streets with a knife or a gun???',
#   "@Progress4Ohio @MichaelSkolnik I'm glad, amigo, you love your president, who kills many children in Ukrain and Gaza and many places more ;-)",
#   '@ValMackinnon @TimmyTurnUp @MichaelSkolnik @Supreme___Power perfect!!)) Like Daniel Craig throw his GF to the window. White girls smart ;-)',
#   "@Agent_Kindi &lt;&lt;&lt; ~~~~@SecretService  The #SecretService Protects #Obama #PresidentObama He Get's Threats All The Time.@MichaelSkolnik"],
#  ['.@NBCNews I demand that you retract the lie that #Ferguson people were shouting "Kill the police". Reporters at scene have refuted that.',
#   '@daiconrad @QuadCityPat thanks for that, I included it here http://t.co/hUi26I5oZZ',
#   '.@NBCNews I demand that you retract the lie that #Ferguson people were shouting "Kill the police". Reporters at scene have refuted that.',
#   '@kileykroh @QuadCityPat It seems a small step from "killer cops" to some mishearing as "kill the cops". For what it\'s worth.',
#   '.@Conservativrulz @NBCNews the fuck outta here troll #scram',
#   '@Conservativrulz @KMBTweets @QuadCityPat @NBCNews @AP @blackvoices  \nOk.',
#   "@QuadCityPat @NBCNews  Oh ISH!  So @NBC lied about it? The media must have a narrative. Unarmed blk boy shot 10 times doesn't cut it 4 them.",
#   '@KMBTweets @QuadCityPat @NBCNews @AP @blackvoices AP is has a very conservative bias. #liberalmediamyfoot',
#   '@kileykroh I don\'t have links to specific reporters, but I was looking at local video of the protests.They were saying "No Justice No Peace"',
#   '@QuadCityPat @NBCNews Media has always falsely reported on racial issues to keep the races in America divided. Division wks for the 1%',
#   '@QuadCityPat @Conservativrulz @NBCNews Heh. She shares a name with a birth control pill.',
#   '@3ChicsPolitico @QuadCityPat @NBCNews @nbc  George Bush did it.  !!!!!! Of course!!   LORD THE IGNORANCE.',
#   '@kileykroh And "Stop Killing Us"',
#   "@QuadCityPat @kileykroh  AH SHARPTON will have a field day on this.  He's the biggest racists on the planet...on any planet.",
#   '@QuadCityPat thank you for that tweet. God bless.',
#   '@QuadCityPat @NBCNews  \n“Get Out of Town Cracker” sprayed on white man’s burnt-down house March 28, 2014 .CRIME/IS CRIME..REGARDLESS.',
#   '@QuadCityPat @Conservativrulz @NBCNews how the fuck can this idiot compare vandalism to a shooting death? and this idiot gets to vote',
#   '@QuadCityPat @adbridgeforth @NBCNews Exactly.  No justice, no peace.',
#   '@SharonMelendes @KMBTweets @QuadCityPat @NBCNews @AP @blackvoices  ignorance&gt;&gt;..JUST CONSERVATIVES KILL PEOPLE. GEEESH. YEP&gt;&gt;/BUSH DID IT.',
#   '.@Conservativrulz Parity: HOW THE FUCK DOES IT WORK?! #moron @QuadCityPat @NBCNews',
#   "@QuadCityPat @Donna_West @NBCNews: That's the LYING ASS MEDIA for ya!!",
#   '@QuadCityPat @NBCNews Blacks beat Matthew Boorujuy to death while calling him a cracker May 4, 2014. NO  KILLING IS RIGHT..W/BLACK.BLK/WHITE',
#   "@QuadCityPat do you have a link to local reporters at scene refuting? I'm working on a piece and would like to include. Thanks!",
#   '@QuadCityPat @_MylesHigh @NBCNews anything to promote fear, huh? #Sad',
#   '@kileykroh @QuadCityPat I just retweeted a vine that shows some chanting "Hey hey, ho ho, those killer cops have got to go."',
#   '@QuadCityPat yeah same, was hoping to find something from someone on the ground',
#   "@Conservativrulz @QuadCityPat @NBCNews You're comparing vandalism to a murder??  Eff your life!",
#   '@QuadCityPat @NBCNews Yes, and tell @AP &amp; @blackvoices to do the same! It is divisive propaganda.'],
#  ["So last week NYPD tried to tell us that #EricGarner wasn't in a chokehold, now #Ferguson police telling us #MikeBrown assaulted the officer",
#   "So last week NYPD tried to tell us that #EricGarner wasn't in a chokehold, now #Ferguson police telling us #MikeBrown assaulted the officer",
#   "@SoulRevision Even if it were true (which it almost definitely isn't), that's no excuse to execute #MikeBrown in the street.",
#   '@SoulRevision @zellieimani They telling us lies on this Sunday'],
#  ["So #Ferguson Police can afford machine guns but they can't afford dash cameras for their squad cars? #interesting #MikeBrown",
#   "@unpreachedtruth @TheAnonMessage chief of police said last night they had them but but haven't got them in the boxes still.",
#   '@unpreachedtruth @TheAnonMessage thought it was that they had purchased them but never installed them.',
#   "@vdogg9 @TheAnonMessage So they can't afford to open them?",
#   '@unpreachedtruth @Wanderer19 Like the pro-gunners who can find $ for AR-15s, but claim mandatory gun insurance would be financial hardship.',
#   "@runsammrun @TheAnonMessage That's crazy. They didn't seem as disorganized when it came to preparing for the riots.",
#   '@unpreachedtruth @TheAnonMessage ha. the stakes are higher.',
#   '@unpreachedtruth @deBeauxOs1 well, they at least bothered to take the machine guns out if the box.',
#   '@unpreachedtruth @TheAnonMessage not sure about afford, I read it was just a matter of laziness / disorganization / carelessness.',
#   '@rockermom53 @unpreachedtruth | Agree. They have plenty war-hardware, need to focus on ppl skills &amp; train to serve &amp; protect',
#   '@unpreachedtruth @norwind huh',
#   "@unpreachedtruth that's because it's important to be ready to slaughter people who think they have rights. That proves they never did.",
#   "So #Ferguson Police can afford machine guns but they can't afford dash cameras for their squad cars? #interesting #MikeBrown",
#   "@unpreachedtruth @TheAnonMessage they have them but they're still in boxes",
#   "@runsammrun @TheAnonMessage smh. so they couldn't afford to open and install them?",
#   '@rockermom53 @unpreachedtruth |installed video cameras on patrol cars to make video/&amp; audio recording of contact with the public/or suspect',
#   '@unpreachedtruth @BallerinaX with the 1033 program, rifles probably cost less than body cams.',
#   '@DaleGunn3 @Wanderer19 They are protecting and serving themselves. Clearly not #MikeBrown #smh',
#   "@norwind @unpreachedtruth I read they have them but haven't installed them. But that is a LOT of fire power for such a small city.",
#   '@unpreachedtruth @Wanderer19 Protecting and serving, right?'],
#  ["Line of police cars with high beams on greets anyone trying to enter #Ferguson. It's shut down. No media allowed. http://t.co/bk6jFFM7jj",
#   '@AnonymousPress And FAA has declared #Ferguson a no-fly zone.',
#   '~&gt; @AnonymousPress Gaza. Iraq. Soon they will burst into our homes, rape our babies, and force mothers to watch.',
#   '@AnonymousPress what the fuck',
#   '@AnonymousPress Chef is on board',
#   '@AnonymousPress Why am I reminded of Tienanmen Square.',
#   '@AnonymousPress is this photo from last night?? Please clarify because you are using  present tense.',
#   'These pigs need to be taken down! @AnonymousPress @CFormigoni5',
#   '@AnonymousPress cop shoots unarmed black man, citizens start looting and burning the community.is it me or does this not make any sense.',
#   '@AnonymousPress  Freedom of the press my ass',
#   '@AnonymousPress Yeah Land of the Free My A%&amp;',
#   '@AnonymousPress man these guys are such boneheads!!',
#   "@AnonymousPress And this isn't tyranny because ...?? Beuller??",
#   '@AnonymousPress Is Ferguson joining Russia and  China communist style of governance. The cops are calling the protesters animals.',
#   "@AnonymousPress that's from last night. Not tonight."],
#  ['Before his death #MikeBrown told his mother, "The world will know who #MichaelBrown is!" #Ferguson',
#   'Before his death #MikeBrown told his mother, "The world will know who #MichaelBrown is!" #Ferguson',
#   '@BridjesONeil @Donna_West gonna call a big "probably not" on that one.',
#   '“@BridjesONeil: Before his death #MikeBrown told his mother, "The world will know who #MichaelBrown is!" #Ferguson” Holy Moly! amazing',
#   '@xbreakingeven @BridjesONeil It sounds a little made up :(',
#   '😞😞 “@BridjesONeil: Before his death #MikeBrown told his mother, "The world will know who #MichaelBrown is!" #Ferguson”',
#   "@GingePurps His mother has not spoken tonight. Another speaker shared that information. It must've been told to him.",
#   '“@BridjesONeil: Before his death #MikeBrown told his mother, "The world will know who #MichaelBrown is!" #Ferguson”',
#   '@BridjesONeil @nellbernstein heart wrenching',
#   '“@BridjesONeil: Before his death #MikeBrown told his mother, "The world will know who #MichaelBrown is!" #Ferguson” is this real or',
#   '@BridjesONeil @AntonioFrench naaaaaaawwwww for real?????',
#   '@BridjesONeil @AntonioFrench Sounds like something someone who was on a kamikaze mission would say.',
#   '“@BridjesONeil: Before his death #MikeBrown told his mother, "The world will know who #MichaelBrown is!" #Ferguson” sounds like bullshit....',
#   '@BridjesONeil قال زو الثمانية عشر لوالدته قبل مقتله بيد الشرطي الامريكي سيعلم العالم من هوً  ميكي براون',
#   "@BridjesONeil @Donna_West meaning I can't imagine anyone outside of a movie saying such a thing.",
#   '@BridjesONeil @AntonioFrench Seriously? I doubt it.  Maybe more likely, "I love ya momma".',
#   '@BridjesONeil @saramarietweets regardless. We have always known him...we all have a child we know and love. We just now have another we morn',
#   'Speechless. RT @BridjesONeil: Before his death #MikeBrown told his mother, "The world will know who #MichaelBrown is!" #Ferguson',
#   '“@BridjesONeil: Before his death #MikeBrown told his mother, "The world will know who #MichaelBrown is!" #Ferguson” sigh'],
#  ['Currently the #FoxNews website has zero, repeat, ZERO coverage of the #Ferguson protests, probably due to lack of cowboy hats.',
#   "@clydetheslyde @SacJim2012 they have already f'd themselves..all the #different accounts of what happened..#dirtyTruth will come to light..",
#   "@clydetheslyde There is plenty in the world to cover instead of focusing on one woman's ass.",
#   "@mechphree @clydetheslyde @mylifeishid FOX HAS BECOME A REPUBLICAN POLITICIANS INFOMERCIAL,&amp; ISN'T REALLY INTERESTED IN REAL NEWS,BOYCOTT !",
#   '@michael_flinch @smeezi Yikes, indeed.',
#   "@clydetheslyde assholes on FOXNEWS are a major reason why stupid cops don't give a damn about d life of young black kids",
#   "@SacJim2012 @clydetheslyde I know that's right..hoping to god #Someone captured on phone +hasn't came forward -yet..(video/shooting)",
#   '@clydetheslyde get some "don\'t tread on me" flags and fox will go',
#   "@clydetheslyde if it's not #Bengazie It's now Michelle Obama gots to loose weight in her butt. #gross",
#   '@clydetheslyde My column: AN EXECUTION IN FERGUSON: http://t.co/bh8fgwu3gZ \n#ferguson #michaelbrown #policebrutality',
#   '@clydetheslyde or no missing pretty blonde white girl.',
#   "@graceslick77 @clydetheslyde If we don't Jail these Rogue..Racist Cops they won't Stop Killing young Unarmed Black Men.. #Sick",
#   '.@clydetheslyde liar http://t.co/CZk1kFS41Q',
#   '@clydetheslyde Good to know but exactly what is to be expected.',
#   "@clydetheslyde They are obsessed with Michelle Obama' s derrière. #perverts",
#   '@my2bits4u @clydetheslyde so tragic!',
#   '@clydetheslyde @Madaza41 I remember the same type of coverage when we invaded Iraq. Boots on the ground?  Cont...',
#   "@clydetheslyde @Madaza41 Boots on the ground? Who cares! We need more coverage of Brittney Spears' blobs!",
#   '@michael_flinch @clydetheslyde the fact that you had to dig to find it is the problem, this should be headline news. http://t.co/0LKOR9MyqV',
#   "@clydetheslyde you have the right to remain silent but isn't that how we ended up here? #Ferguson http://t.co/SErbzckzdX",
#   ".@clydetheslyde It's the lack of property damage. On Fox, it's property&gt;people",
#   "@clydetheslyde @mchenthompson  Isn't this the truth!",
#   '@mechphree @clydetheslyde @mylifeishid or be white. Or old and white. Or an old, rich and white Senator.',
#   "@clydetheslyde @GrooveSDC They don't want their hillbilly viewers to start thinking that the race war has finally started... yet. #FOXNEWS",
#   "@clydetheslyde Their cameras can't focus on brown people.",
#   '@michael_flinch its not just foxnews tho, foxnews is just one of the many.',
#   '@graceslick77 @clydetheslyde #HatersHate and #LiarsLie',
#   '@clydetheslyde @mylifeishid #MikeBrown would need to be shot in #Benghazi  for #foxnews to cover it',
#   '@SacJim2012 @clydetheslyde I was raised by a hater; + knew very wrong-always.But it baffles me w #Diversity in creation y ppl hate rt race..',
#   '@clydetheslyde Thanks 4 going where many of us don\'t care to wonder ✌️. No surprises, but really no articles "he ran at my car really fast."',
#   '@smeezi it was actually interesting',
#   "@michael_flinch @smeezi I was talking about the website.  Plus, dude, it's just a joke. Get over yourself!",
#   "@clydetheslyde @moiskd Imagine if Ferguson folks were strutting around with AR's. Think Perry&amp;Hannity would be hunkered down in solidarity?",
#   "@clydetheslyde @SacJim2012 won't release the name of the cop who did the shooting &amp; have not spoke to the witnesses..#BuyingTime",
#   '@smeezi @clydetheslyde turn on Fox News now',
#   'Currently the #FoxNews website has zero, repeat, ZERO coverage of the #Ferguson protests, probably due to lack of cowboy hats.',
#   '@clydetheslyde Shocking... Earlier they had a segment on TV asking if black America would do anything to stop the looting in Ferguson',
#   '@michael_flinch what did they say?',
#   '@mechphree @mylifeishid Nicely played, sir!',
#   '@clydetheslyde Your tweet really makes this page stronger: http://t.co/QNABzh699U',
#   '@my2bits4u @DMeralles @clydetheslyde http://t.co/u8QxZ0Dv60',
#   "“@clydetheslyde: Currently the #FoxNews website has zero/........as the three wise monkeys commented 'see no evil hear no evil speak no evil",
#   '@michael_flinch @clydetheslyde yikes.',
#   "@clydetheslyde Na, it's too many black people for #FoxNews to care",
#   '@clydetheslyde Too busy bitching about POTUS for sure',
#   '@clydetheslyde @smeezi http://t.co/shgRwLx9Ww',
#   '@graceslick77 @clydetheslyde Buying Time to Protect a Racist..Murdering Cop.. #Sick #Coward',
#   '@smeezi there was a black conservative taking about it and it was just a really different pov',
#   '@michael_flinch yeh i dont want to watch shitty programming. i believe you, but its not headlining their news or even on their homepage.'],
#  ['The ferguson chief says that his feelings are hurt that ppl consider him a part of the problem. #ferguson http://t.co/VoJGrMOPbZ',
#   "@ShannonLeeKiss @WyzeChef @AdmireLaniya__ Even though it seems difficult. This country doesn't need racial division. We are Americans.",
#   '@WyzeChef @radicalhearts wow... Making it about his feel feels after a teen has been murdered?!',
#   "@OberstabKrieger @WyzeChef @AdmireLaniya__ I don't think looting is effective.  But I'm not going to judge because I don't live there.",
#   "@joshmhump @WyzeChef @AdmireLaniya__ But that would never happen to their kid so they don't really seem to care.  It's upsetting.",
#   '@LibertyIsALady @WyzeChef @AdmireLaniya__ But if I had to make a generalization about WP it would be that most of them harbor some racism.',
#   "@petee224 @ShannonLeeKiss @joshmhump @WyzeChef exactly. So don't lose the purpose of the tweet by RahRahing for white people over a genrlztn",
#   "@ShannonLeeKiss @WyzeChef @AdmireLaniya__  Sad.  Nonetheless, I'll stand for your rights.",
#   '@joshmhump @WyzeChef @AdmireLaniya__ It seems to me that many non Black people are focused on the civil disturbances more than the dead kid.',
#   "If Red Riding Hood was black, media/cops would've put wolf on paid vacation &amp; talked about his wolf tearz @tklowenstein @WyzeChef #Ferguson",
#   '@WyzeChef @ShannonLeeKiss @AdmireLaniya__  ♥',
#   "@ShannonLeeKiss @WyzeChef @AdmireLaniya__ We should never as people respond to a crime with crime. We should do what's right.",
#   '@joshmhump @petee224 @ShannonLeeKiss @WyzeChef advocating against meaningless and harmless white prejudice.',
#   '@WyzeChef @pixiestateomind that time Mike Brown has no feelings to speak of.',
#   'The ferguson chief says that his feelings are hurt that ppl consider him a part of the problem. #ferguson http://t.co/VoJGrMOPbZ',
#   "@LibertyIsALady @WyzeChef @AdmireLaniya__ Stand for the Constitution and the American Dream.  That's what's being violated.",
#   '“@WyzeChef: The ferguson chief says that his feelings are hurt that ppl consider him a part of the problem. http://t.co/HUlpIqjoFL” - lol',
#   '@petee224 @ShannonLeeKiss @joshmhump @WyzeChef We should be so thankful for it. The comment was a generalization but that generalization',
#   "@ShannonLeeKiss @WyzeChef @AdmireLaniya__  It's too many, that's for sure.",
#   "@ShannonLeeKiss @WyzeChef @AdmireLaniya__ Never said he wasn't. I was replying to your racist comment above.",
#   '@ShannonLeeKiss @WyzeChef @AdmireLaniya__ The whole situation is awful. The officer should be held accountable for his action.',
#   '@WyzeChef officially my favorite use of this!',
#   "@joshmhump @WyzeChef @AdmireLaniya__ If I lived there I can't promise that I would react differently.",
#   '@ShannonLeeKiss @WyzeChef @AdmireLaniya__  Please don\'t do the same thing they do, in reverse.  It\'s "some" white people.  :)',
#   ".@WyzeChef If the #Ferguson chief thinks his feelings are relevant to his job, that's probably part of the problem.",
#   "@WyzeChef @xianb8 but that story about a kid attacking a cop for no reason while on his way to his grandmother's house makes so much sense",
#   '@ShannonLeeKiss @WyzeChef @AdmireLaniya__ BTW - you said "white people love the victim card" and I felt judged because of my skin color.',
#   '@AdmireLaniya__ @petee224 @ShannonLeeKiss @WyzeChef RahRahing for white people?',
#   '@AdmireLaniya__ @ShannonLeeKiss @WyzeChef   Your anger is understandable.  But your generalized judgement is a shame.',
#   "@LibertyIsALady @WyzeChef @AdmireLaniya__ I don't know you personally.  I judge people as individuals.",
#   '@joshmhump @WyzeChef @AdmireLaniya__ So many people are interested in raking the protesters over the coals instead of looking ...',
#   '@AdmireLaniya__ @ShannonLeeKiss @WyzeChef   You should recognize a friend when you see one. I believe the solution is thinking of everyone.',
#   '@ShannonLeeKiss @WyzeChef @AdmireLaniya__  I do.  And more.',
#   '@WyzeChef @Principia “They go around gratuitously shooting ppl and then agonize about it on social media…and they write poetry”',
#   '@LibertyIsALady @ShannonLeeKiss @AdmireLaniya__ no doubt.',
#   "@joshmhump @WyzeChef @AdmireLaniya__ I think that's awful and self centered.  They are making it all about them and how they are affected.",
#   "@AdmireLaniya__ @ShannonLeeKiss @joshmhump @WyzeChef always a blessing when people stand together for what's right. http://t.co/f4lkRMjFMU",
#   "@WyzeChef @TheBlackVoice He couldn't have been serious... They are so oblivious its damn near hilarious!",
#   '@joshmhump @WyzeChef @AdmireLaniya__ Thanks for listening.',
#   '@joshmhump @WyzeChef @AdmireLaniya__ at what caused their reaction.',
#   '@joshmhump @petee224 @ShannonLeeKiss @WyzeChef I clearly said prejudice.',
#   "@OberstabKrieger @WyzeChef @AdmireLaniya__ If that happened in my neighborhood I can't promise that I wouldn't want to tear something up.",
#   '@LibertyIsALady @ShannonLeeKiss @WyzeChef boo fucking hoo join the club. Advocate that same thing for PoC and stop thinking of yourself',
#   "@LibertyIsALady @WyzeChef @AdmireLaniya__ It's many.  I don't buy into reverse racism.  It's a farce.",
#   '@WyzeChef @Principia Art srsly, Douglas Adams called it...',
#   '@WyzeChef @AdmireLaniya__ White people love the victim card.',
#   '@AdmireLaniya__ no need to be condescending. So by your comment its us against them?',
#   '@LibertyIsALady @ShannonLeeKiss @WyzeChef Well I don\'t. And you\'ve done anything but prove yourself as a "friend" whatever that means.',
#   "@joshmhump @WyzeChef @AdmireLaniya__ Absolutely!  The looting is unfortunate but I'm not going to judge those people.",
#   "@AdmireLaniya__ @petee224 @ShannonLeeKiss @WyzeChef I didn't advocate for white people. So you're saying every white person is racist.",
#   '@joshmhump @WyzeChef @AdmireLaniya__ I agree.  I hope the Ferguson PD comes to the same conclusion',
#   '@ShannonLeeKiss u r tweeting w/white ppl right now who r on ur side yet u condemned us all. C problem?@joshmhump @WyzeChef @AdmireLaniya__',
#   "@joshmhump @WyzeChef @AdmireLaniya__ If you don't see that young man as a victim than I don't know what one is.",
#   '@LibertyIsALady @WyzeChef @AdmireLaniya__ most people would objectively come to the same conclusion.',
#   '@petee224 @ShannonLeeKiss @joshmhump @WyzeChef Yes. Because you feel that having white people on our side should be such a blessing.',
#   '@LibertyIsALady @WyzeChef @AdmireLaniya__ Based on my personal experiences, 39 years of observations, history and current events ...',
#   '@WyzeChef @Principia “My officers don’t go around gratuitously shooting ppl and then bragging about it in seedy paramilitary cop bars…"',
#   '@WyzeChef What is he SMOKING? He cannot be that stupid.',
#   '@AdmireLaniya__ @petee224 @ShannonLeeKiss @WyzeChef I agree with @petee224',
#   "@ShannonLeeKiss @WyzeChef @AdmireLaniya__ That's the pot calling the kettle black!",
#   "@WyzeChef @AdmireLaniya__ They've been making this whole situation all about them by focusing on the looting.",
#   '@WyzeChef @Principia bummer that…So, since when did the cops start having feelings that could be hurt ?',
#   '@LibertyIsALady @WyzeChef @AdmireLaniya__ Me blowing smoke up your behind would not do anyone any good.'],
#  ['#Ferguson is completely shut down. No journalists allowed.',
#   '@kschottt @nagoul1 FAA just closed off Ferguson to all news helicopters too',
#   '@callmelit @nagoul1 Smells like #Gaza',
#   '@nagoul1 @YourAnonNews not good, State or Feds need to step in and bring some integrity &amp; accountibility',
#   '@nagoul1 @YourAnonNews How can they identify a journalist?',
#   '@sternhe the only thing i can think is, is this even legal',
#   "@kschottt here's the official release http://t.co/MVUFTfMAhy",
#   '“@nagoul1: #Ferguson is completely shut down. No journalists allowed.” unreal. what the fuck kind of freedom is that?',
#   "@nagoul1 They just going to cleanse the neighbourhood of blacks and 'black sympathisers' so no-one can complain?? #COPPOLITICS",
#   '“@nagoul1: #Ferguson is completely shut down. No journalists allowed.” And so it begins',
#   "@callmelit @nagoul1 They don't want us seeing this! https://t.co/b3aA8YwAKO\n#ferguson Police shoot at unarmed civilians in their own yard!!",
#   '@nagoul1 @YourAnonNews @_cokeee aka Marshall Law in full effect. This is why everyone needs to own a gun.',
#   "Wouldn't want an objective voice there: “@nagoul1: #Ferguson is completely shut down. No journalists allowed.”",
#   '“@nagoul1: #Ferguson is completely shut down. No journalists allowed.” sus',
#   '@nagoul1 @YourAnonNews See now that right there is some scary shit! \nBlack out time &amp; anything goes with having 2 answer 4 it.',
#   '@callmelit @nagoul1 Channel 2 and Channel 5 have reporters right with the protesters, word of a CNN truck around earlier as well',
#   "@nagoul1 @YourAnonNews that's where citizen journalists come in. many have a phone w/a camera. if they can stop looting long enough to do so",
#   '@nagoul1 @YourAnonNews shut down how? #Ferguson',
#   '@nagoul1: Another Gaza in America. #FascistCops',
#   "@kschottt @sternhe It shouldn't be, but in a police state it is.",
#   '@nagoul1 fucking disgusting.',
#   '@nagoul1 Be careful',
#   '@nagoul1 @YourAnonNews Unacceptable'],
#  ['Police have thrown something at the crowd. Not sure what tho. Protester says "they have enough bullets for everybody down here #Ferguson',
#   '@Nettaaaaaaaa Oh shit',
#   'Police have thrown something at the crowd. Not sure what tho. Protester says "they have enough bullets for everybody down here #Ferguson',
#   "FUCK. Don't let the cops BAIT the crowd. #myNYPD uses that trick to have excuse to disburse crowds. they want a reaction  @Nettaaaaaaaa"],
#  ['St. Louis Co Police tell me ofcr shot a man who pointed handgun at him at Chambers &amp; Sheffingdell at about 1 a.m. Man in critical. #ferguson',
#   "@JrGothDetective @valeriehahn according to police that's the truth",
#   'True? “@valeriehahn: CountyPD tell me ofcr shot a man who pointed handgun at him at Chambers/Sheffingdell at 1 a.m. Man critical #ferguson”',
#   "@valeriehahn I'm glad this officer wasn't at the bundy ranch,  because he would've shot a lot of people for pointing guns at him.  Smh",
#   "@valeriehahn Uh! Oh. This is serious and officially out of control. #Ferguson I sure hope it wasn't false sighting or #PD in more hot water",
#   '@Twitlertwit @valeriehahn @kodacohen or the video!',
#   "@valeriehahn @kodacohen Why should we believe anything #FERGUSON police have to say, won't release # of bullets or autopsy #MICHAELBROWN",
#   '@valeriehahn tx for keeping us informed.  Stay safe!',
#   'St. Louis Co Police tell me ofcr shot a man who pointed handgun at him at Chambers &amp; Sheffingdell at about 1 a.m. Man in critical. #ferguson',
#   '@valeriehahn source?',
#   '@valeriehahn How many weeks until police interview witnesses? @mattdpearce',
#   '@valeriehahn Thank you so much for getting this scoop.  People have been on pins and needles at the reddit live feed. http://t.co/Rd2wHonMgC'],
#  ['It was a St. Louis County police officer who shot this man, according to PIO Brian Schellman. #ferguson',
#   '@valeriehahn Surprise. :(',
#   '@iamlivin4god @valeriehahn yes "they" should really take advantage of their first amendment right to stay at home in fear of being shot',
#   'It was a St. Louis County police officer who shot this man, according to PIO Brian Schellman. #ferguson',
#   '@valeriehahn you’re doing an awesome job',
#   '“@valeriehahn: It was a St. Louis County police officer who shot this man, according to PIO Brian Schellman. #ferguson” another one shot :/',
#   '@valeriehahn  if they would stay home and quit the chaos for fun, they would not get hurt. Now it will be the cops fault. smh'],
#  ['What are #Ferguson Police hiding about "drive by" shooting of black woman recording last night\'s action? http://t.co/wfuDYm9q27 #OpFerguson',
#   '@occbaystreet NOBODY Believes Spook Was Shot By A Drive-By! @SpookPacShakur Howard Grad Is Alive PreciousGirl! PRAY♥ http://t.co/xahPZBOwLv',
#   '@occbaystreet they hav 2 make them seem violent&amp; "thuggish" 2 justify their continued #PoliceState in #Ferguson! @ru4peace2 @Dreamdefenders',
#   "@KUHU45 Yup... Say the word 'drive-by' &amp; it conjures up gang wars... Strokes the #Ferguson narrative I think @occbaystreet @Dreamdefenders",
#   '@KUHU45 @Dreamdefenders they shot her up with less lethals then blamed "black people" then killed another black man over it. Fuckers.',
#   '@occbaystreet those r all code words/phrases to stereotype the blk protesters "drive by", "wearing mask" etc @ru4peace2 @Dreamdefenders',
#   "@KUHU45 @Dreamdefenders can't open their fuckin' mouths w/o lies spilling out.",
#   '@occbaystreet We allow peaceful protest in the USA. It is unacceptable to tear gas people that are peacefully protesting.',
#   'The cop literally goes to cover the other cops mouth. Wtf. @occbaystreet',
#   'WTF? RT @occbaystreet What are Police hiding about "drive by" shooting of woman recording last night\'s action? http://t.co/dicBCVYMVZ',
#   '@occbaystreet WOW...notice how the police was stopped from telling who shot the lady! This was NO "drive by"! #Ferguson @Dreamdefenders',
#   '@occbaystreet @Dreamdefenders NO one shld believe any police account of what happens to protesters....Police lie!\n#Ferguson #MikeBrown',
#   "@occbaystreet @YourAnonNews  Suspect number 1.Cops  Suspect number 2. The dumb ass KKK. I can't believe there are still KKK around! B ONE!",
#   '@occbaystreet A lady was shot lastnight',
#   '@ru4peace2 exactly AND wld police hav been standn their so CALM if ppl had just done a "drive by" #Ferguson @occbaystreet @Dreamdefenders',
#   "@occbaystreet @YourAnonNews you don't see this happening in the burbs.",
#   '“@CassandraRules: The cop literally goes to cover the other cops mouth. Wtf. @occbaystreet” worse part is, he was a black man.',
#   "@KUHU45 I just watched that video &amp; if it was a drive-by he'd have said so bc it's a public safety concern @occbaystreet @Dreamdefenders",
#   '@occbaystreet @IMShawnAndrews told story many times. once got beat by cops just 4 being w/ buddy who was buying cheeseburger while black.',
#   '@SeriusBall @IMShawnAndrews I believe it.',
#   "@occbaystreet Safe to say what happened is still under wraps... I agree a 'drive-by' shooting is not 'likely'... @KUHU45 @Dreamdefenders",
#   '@kathysamira @SpookPacShakur We can make this go big, right away. Could I talk to witnesses somehow?',
#   '@LisaJac21671472 yeah, by the cops it looks like',
#   '@occbaystreet @YourAnonNews so they allow police helicopters and not media huh....',
#   "@KUHU45 @ru4peace2 @Dreamdefenders nah. And what reason in the world would a drive by target her. They aren't random."],
#  ['Police in St. Louis County say an officer shot and critically wounded a suspect early this morning near #Ferguson http://t.co/htLmEiuCS5',
#   '@kmoxnews @AntonioFrench strange... it didnt take 22 hrs to release a statement acknowledging the incident',
#   'Police in St. Louis County say an officer shot and critically wounded a suspect early this morning near #Ferguson http://t.co/htLmEiuCS5',
#   '. @kmoxnews Why are you referring to the protesters as suspects??',
#   '@GodWomb @kmoxnews &amp; was she kneeling down with her hands in the air too? #FactCheck',
#   '@kmoxnews good fuck the police',
#   '@kmoxnews @AntonioFrench @wildwalkerwoman that article looks like bs',
#   '@GodWomb I have yet to see that confirmed by #Ferguson tweeps. Get your info from them, not #MSM because... #agenda',
#   '@kmoxnews @AntonioFrench this has got to STOP. #MikeBrown',
#   '@GodWomb @kmoxnews @TefPoe &amp; #NYT has announced #MartialLaw :((( http://t.co/A46fTxEux2'],
#  ['Another police shooting in protest-plagued #Ferguson: http://t.co/NcVUm7Fqdp (Scott Olson, Getty Images) http://t.co/YfIp2RUB4N',
#   '@USATODAY @NaphiSoc http://t.co/mwIYhuJcw5',
#   '.@USATODAY Funny, I would have said that the "plague" is police violence, not protests in response to it. #Ferguson',
#   '@nhdogmom @USATODAY shot first ask questions later',
#   '@USATODAY while they are plagued with protest - parts of Africa is plagued with Ebola.',
#   '@USATODAY @NaphiSoc Who is the idiot that thinks this is the solution to anything? #Ferguson',
#   '@NaphiSoc @USATODAY yes...."accidents" do happen when you put the police under the spot.',
#   '@USATODAY And you wonder why America is becoming a Police State, look back 30 years and tell me if you see then what you see now.',
#   '@USATODAY @NaphiSoc That witness is in danger...',
#   '@USATODAY the truth the power they hold as any state official they have taken it  far in abusing their authority if state is no loyal nation',
#   '@USATODAY no fly zone,god what will they think up next,if military like police call it like it is come at you run they shoot everyone',
#   "@USATODAY the reason the people are mad is because they can't bribe this PD like the one they got rid of.",
#   '@dosSteckis @USATODAY has to be some white guy lacking evolution to comment!',
#   '@Shimaganish @USATODAY should be under Federal custody at this point.',
#   "@USATODAY I''ll wait for #Ferguson invest before conclusion but only 3 black officers on force. That's wrong.",
#   "@USATODAY that'll happen when you point a gun at a cop and refuse to stand down",
#   'Another police shooting in protest-plagued #Ferguson: http://t.co/NcVUm7Fqdp (Scott Olson, Getty Images) http://t.co/YfIp2RUB4N',
#   '@USATODAY There nothing but a real big gang it really makes you sick he did wrong so just say so.'],
#  ['A woman in #Ferguson was shot in head last night and released this selfie. Conflicting reports of how it happened: http://t.co/25WX6EkquG',
#   '@SeanCornholio wow',
#   '@MichaelSkolnik The story is true.',
#   '@MichaelSkolnik Shooting related to protesting. Ppl on the street are upset about this. Also, 6mo pregnant woman forced facedown on ground',
#   '@MichaelSkolnik as reported by @KMOV @LauraKHettiger; injured in a RANDOM drive-by shooting per Lt. Col w/@STLCPD http://t.co/YcJivhDui8',
#   '@SeanCornholio and shame on people like your boy skolnik giving it pub...  just perpetuates ridiculous things like that (the selfie)',
#   '@MichaelSkolnik @prettyhurtsss_ wow.',
#   '@MichaelSkolnik when u spew racism,hate of us blks&amp;Potus  @milbank @ezrakelin @morningmika @GlennKesslerWP u shw slvs http://t.co/WQCjnr013h',
#   '@KUHU45 @MichaelSkolnik This is terrible. The police is out of control and needs to be stopped asap.',
#   '@MichaelSkolnik Not minding ur own business is often the first step towards big problems.No matter what color u are or how much money u have',
#   '“@MichaelSkolnik: A woman in #Ferguson was shot in head last night, took selfie. http://t.co/5DZv7HE8FM” EVERYTHING WRONG WITH THIS WORLD⬆️',
#   '@kev_cudi_ crazy right?',
#   '@MariaChappelleN which version?',
#   'gm @MichaelSkolnik wow @milbank @ezrakelin @morningmika @GlennKesslerWP just cld Potus all but N wrd on air.Birthers http://t.co/hBVvcHvw48',
#   '“@MichaelSkolnik: A woman in #Ferguson was shot in head last night and released this selfie. http://t.co/qcXNu5M2Vj” #HUalum',
#   '@liberalphenom @charmed86 @thereval @thereidreport @trymainlee we blks 4 Potus see &gt; racism runs deep @milbank @ezrakelin @GlennKesslerWP',
#   '- @MichaelSkolnik A MONTH LATER; #Ferguson police have YET to interview #MyaAatenWhite. The ambulances came only after numerous calls.',
#   '@MichaelSkolnik they just went aft Potus,Flotus&amp;fam 4 going on vacation lk whites do daily @milbank @ezrakelin @morningmika @GlennKesslerWP',
#   '@liberalphenom &gt; @thereval @thereidreport @trymainlee Obamas cnt vac per racist @milbank @ezrakelin  @GlennKesslerWP http://t.co/EddrhLVnw8',
#   '@liberalphenom @thereval @thereidreport @trymainlee Potus blk per @milbank @ezrakelin @GlennKesslerWP cnt go golf.wow http://t.co/nWHp1OMGdq',
#   'A woman in #Ferguson was shot in head last night and released this selfie. Conflicting reports of how it happened: http://t.co/25WX6EkquG',
#   '@kev_cudi_ "my boy" is a bit much. I just follow to get ridiculous shit like this.',
#   "@MariaChappelleN @MichaelSkolnik she's been reporting on the story for days diligently. I don't think she would be violent.",
#   '#casual #impressive  “@MichaelSkolnik: A woman in #Ferguson was shot in head last night and released this selfie: http://t.co/ki10cz6Jiw”',
#   "@MichaelSkolnik compelling photo. It's always miraculous to hear about a headshot victim surviving.",
#   '@MichaelSkolnik Holy Moses. I never used to believe it, but social media really is changing everything about how we interact and see.'],
# ...
#   "@HoussamiNadine If you read that in English why can't you tweet to me in English?",
#   '@CatholicLisa und warum verschwinden Flugzeuge wie zB malaysische Airline einfach so? Kommt schon bitte informiert euch bevor ihr nur den',
#   '@CatholicLisa bringt sich der Kerl und weitere 150 Menschen um der auf einmal konvertiert ist! Lasst euch nicht manipulieren bitte wacht auf',
#   '@CatholicLisa Medien glaubt! Islam ist nicht das was ihr in den Medien hört! Klar gibt es radikale aber die gibt es in allen Religionen und',
#   '@politikmama It is true that a German news website is claiming that, as it says in my tweet.',
#   '@CatholicLisa no matter what he was he wa also a Young man a human being Muslim Christ jewish whtever we shouldnt judge about him he is now',
#   '@CatholicLisa seine Strafe von lieben Gott bekommt ob Moslem Christ und sonst was! Die Medien wollen einfach jegliche Wahrheit vertuschen',
#   '@CatholicLisa between Gods hands and only God will judge him and us!',
#   '@CatholicLisa das ist absurd was alles gesagt wird! Haben die zwei Russen die auch angeblich selbstmord begangen haben ach mit Islam zu tun?',
#   "@fawfulfan ah! So it's not confirmed or true.. Was confused. Didn't hear it on news only Twitter. Thank you",
#   '@CatholicLisa Hope this can be verified. @MarkSteynOnline',
#   '@CatholicLisa Nationen! Ich bin selbst Moslem und finde soviele was passiert falsch aber ich glaube fest daran dass jeder der Fehler macht',
#   '@CatholicLisa is this true?'],
#  ['#GermanWings co-pilot was a fresh #Muslim convert - http://t.co/iNVyryt5LE via @Orvan \nConverts to #Islam are very disturbed #WhiteMuslims',
#   '@wuhokay @Thew3B the position of having to keep cockpit doors locked on planes is all to do with terrorism Culpable anyway their fault evil',
#   '@riwired But no evidence has been made public, so what is this (not so objective) writer talking about when saying "all evidence indicates"?',
#   '@riwired Must be something like that, and frankly, it was the first thing I thought of yesterday. But look at this: https://t.co/uAD4PF3KiF',
#   '@riwired Could be just IS propaganda. Thing is that I see lots of tweets claiming that he was a jihadist. Truth is that no one knows.',
#   '@prittstift_nl You\'re right. But there have been pro ISIS accounts claiming he was a "brother" who did it for "Allah." Perhaps that\'s why?',
#   '@riwired @Orvan ..while other religions convert thugs to good humans..\n\n..is.lam converts good humans to killers.. always..\n..boycott.\n\n#HDL',
#   '@KapilSpeaks @Jen3578 @riwired @wuhokay @Thew3B I agree totally.',
#   '@CoraBuhlert Seems that people are jumping to conclusions. :| @Orvan',
#   "@riwired @Orvan There is no evidence for this beyond someone's comment on the site of an obscure magazine no one has ever heard of.",
#   "@Jen3578 @riwired @wuhokay @Thew3B technology can't make things IDIOT proof, whoever designed the door, should have provided pilot access"],
#  ['#Germanwings co-pilot suffered serious depression 6 years ago: German newspaper http://t.co/LXDzBdNdMB http://t.co/yTUNdHyEJY'],
#  ["Andreas Lubitiz was 'deemed unsuitable for flight duties' during  training #Germanwings http://t.co/nk5GGyuxaa http://t.co/HQpKZD4DSI",
#   "@Independent SHAME ON OUR SOCIETY ! This was a mental ill man and Lufhansa knew that ! They are the murderers who didn't protect him !!!",
#   '@Independent He was Directing his own18min horror movie with his"audience"behind and"widescreen"up front.He musthave weird DVD collectn !',
#   "@Independent he was a terrorist who killed innocents  but u won't call him that because he was white and not a Muslim .",
#   '@Independent BTW you messed the name up, which also goes to shows how unnecessary it is to print the real name.',
#   '@Independent love stories,songs lyrics,heart touching status: Punjabian Da King  song Dil chandre http://t.co/ALjzBJzObT',
#   '@Independent http://t.co/aLgn6mKMil #Germanwings Why not have a pincode on each flight so that flight crew can access the cockpit?',
#   '@Independent By printing the full name you inflict serious harm on his family and his relatives. This is really disgusting!',
#   '@Independent force him back to work too early?Could stigmatise sufferers.Will some professions be deemed off limits for sufferers? #kneejerk',
#   '@Independent Feel so sorry for everyone concerned.So many issues arising from this.Seriously raises mental health to fore.Did airline 1 of 2'],
#  ['#Germanwings Co Pilot New Muslim Convert\n\nIslamic State Praises Their Hero\n\n#WakeUpAmerica 🇺🇸 \nhttp://t.co/NYefk5WCPm http://t.co/J195dkGFGU',
#   'Leftists want the truth NOT LIES. We are all different faiths unlike the RIGHT.\n#USURY is TREASON you dumb masses.\n\n@JackJolis @DrMartyFox',
#   "@DrMartyFox @GolanMay So far it's nothing more than a conspiracy theorie going around on the alternative and social media. #IwantFacts",
#   '@DrMartyFox @etabori don’t fall for this. Its bullshit',
#   '@cox24563 @DrMartyFox @GolanMay Michael Mannheimer did break this story. His website is down and he doesnt react on Facebook.',
#   "@DrMartyFox If this is true it's making Islam seem like the movie Invasion of the Body Snatchers. It makes you stop using your brain.",
#   '@DrMartyFox @peddoc63 @LindaSuhler @gatewaypundit TRUTH revealed. Finally. The TRUTH will set you free. NOW what do we do w/this TRUTH?',
#   '@DrMartyFox @RickCanton We should remember the innocent deaths and not give any mention to the co pilot....gives them publicity.',
#   "@DrMartyFox The German co-pilot and the mosque in Bremen -- man, the leftist powers-that-be REALLY don't want this to be true.",
#   '@DrMartyFox what da FUCK is that ??? @recedam1 @abd_charlie @AbouDjaffar @An0n1214 are y serious ???',
#   '@RachelCohen12 @DrMartyFox Me, too. The way of the world now.',
#   '@DrMartyFox @peddoc63 @LindaSuhler @gatewaypundit My thoughts were "copycat 91descent" to mountains. NO DRUGS mentioned for depression.',
#   '@IL4me @DrMartyFox @GolanMay True. It would be all over the news.',
#   '@drmartyfox \nThe Facebook page is fake and has been removed.',
#   '@DrMartyFox converted after death? Are you serious? Omg',
#   '@th_christine @DrMartyFox @RickCanton they can claim work place violence like Obama did .',
#   '@DrMartyFox @RickCanton Glad they were able to rule out terrorism right off the bat!',
#   '@DrMartyFox @GolanMay You do realize that\'s not HIS page right? That is some nutty "fan" page',
#   "@EelPieLtd @DrMartyFox @ThePatriot143 fox news be like tjey found......we're like a koran",
#   '@RachelCohen12 @DrMartyFox Mine,too. Slow methodical descent.',
#   '@DrMartyFox They got this right?',
#   '@DrMartyFox @ThePatriot143 : MSM silent...... Fox News silent......',
#   '@DrMartyFox Was my first thought... was the pilot a Muslim?'],
#  ['Report: Germanwings Co-Pilot Treated For Depression http://t.co/ewynIJ23A2',
#   '.@nprnews @MorningEdition relevant because?',
#   '@justincapps @nprnews That is exactly what it is, further stigmatizing mental illness. THis time it cost them.',
#   '@amras @nprnews Came to say this. Tweets are powerful statements and can convey far more than the 140 characters, whether intended or not.',
#   "@nprnews LET'S STIGMATIZE THIS INCREDIBLY COMMON ILLNESS!!!!!!!!!!!!!!!",
#   '@nprnews Some people may be mentally ill; some murderers. But these things do not go hand in hand.',
#   '“@nprnews: Report: Germanwings Co-Pilot Treated For Depression http://t.co/38qVFIkC5v” OK and?',
#   "@SPLaws TBD at this point. I just worry about knee-jerk over-reactions. Not that we're prone to those in America or anything.",
#   'Cue the bashing of people with mental illness: “@nprnews: Report: Germanwings Co-Pilot Treated For Depression http://t.co/2CEYFKu69M”',
#   "@david_burns I'm chewing at the bit...  Good call DB",
#   '@SPLaws Germans too, evidently. Or at least one of them.',
#   '@nprnews What do u know.  That was thought of in the beginning',
#   "@nprnews So what else are we going to forbid people with depression from doing? I'd like a list - I've been diagnosed since I was a teen",
#   '@nprnews 1. He should not have been flying 2. Foreign carriers STILL do not have the 2 people in cabin at all times policy. Why?',
#   'Wow, yeah, NPR. MT @david_burns let’s be careful. If depression is red flag, we’ll end up with no one to fly, drive, teach, etc. @nprnews',
#   '“@nprnews: Report: Germanwings Co-Pilot Treated For Depression received 18 months of psychiatric treatment http://t.co/UaNq0REgiP”',
#   '@david_burns @MorningEdition You  paint a rather fine portrait with the type of large brush that I use   to whitewash my barn.',
#   "@nprnews Inform! Please don't participate in the sensationalism, don't stigmatise depression more than it is.",
#   '@nprnews @MorningEdition let’s be careful. If depression is red flag, we’ll end up with no one to fly, drive buses, teach kids, etc.',
#   '@nprnews Along with ~6% of the global population, who, it apparently must be pointed out, have NOT flown planes into mountainsides.',
#   '@nprnews This story only serves airlines bc it blames something identifiable so ppl feel safe again, even when that thing is not the cause.',
#   "Raise a virtual hand if you have, too, and haven't killed people. 🙋 #nostigma MT “@nprnews: Report: Germanwings Co-Pilot Tx For Depression”",
#   '@david_burns right David. I just jumped right on that one. As a citizen with an overactive imagination, did the pilot do it 4 other reasons?',
#   '@david_burns @MorningEdition @nprnews real question is WHY are so many Americans depressed? Cant all be contributed to chemical embalance',
#   '@nprnews This is an embarrassing, racist, ableist, and otherwise appalling reporting of this.',
#   '“@nprnews: Report: Germanwings Co-Pilot Treated For Depression http://t.co/6R9oHad22d”@JonRottenberg #depression'],
#  ['#Germanwings #CoPilot was a recent Muslim convert as well as a psychiatric patient. #ISIS is lauding him as a hero. http://t.co/J29Y3tDjOP',
#   "@DanOClunaigh @Zone6Combat Didn't assume u a Muslim as didn't read thread , just saw that tiresome word, didn't mention pilot either",
#   "@DanOClunaigh @Zone6Combat As u r a non Muslim, I'm curious as to your concerns of any implication of Islamic involvement ?",
#   "@Zone6Combat The 'Andreas Lubitz Fans' page was set up by some brainless fool of the other variety or an agent provocateur. It's not his.",
#   '.@DanOClunaigh Find the article, complete w/ screenshots of his personal Facebook acct w/ Jihadist rhetoric before calling ppl idiots.',
#   '@ellepuntopi È bellissimo che mettono la foto dove c\'è scritto "not known as terrorist" asserendo il contrario. @Zone6Combat',
#   "@Zone6Combat ...it's how investigation works among professionals who aren't hysterical islamophobes.",
#   '@OkKelly22 @Zone6Combat I have no concern that there was any Islamist involvement, looks like he was a good European Christian if anything.',
#   "@Zone6Combat he could have aimed that plane at the Sagrada Familia or Trade Center in Barcelona, how come he didn't?",
#   '@Zone6Combat are you actually kidding? Please point to the substantial evidence of terrorist motives. Evidence pls. Even just one bit.',
#   "@Zone6Combat WHERE is this Facebook page you speak of? Let's see it. The world needs your evidence!",
#   '.@SimZombie @ellepuntopi Not being a "known terrorist" on a watch list doesn\'t mean he didn\'t have jihadist sympathies and beliefs.',
#   "@Zone6Combat Lack of substantial evidence of any terrorist motives means it's not terrorism, until such motives are found. Yep, sound logic,",
#   '@Zone6Combat better yet, link it with your ridiculous tweet so everyone can read it.',
#   "@Zone6Combat #facepalm Yeah I'm the delusional one here.",
#   '@Zone6Combat Noooooooooooooooo. Who would have EVER thought.',
#   '@Zone6Combat As you say. @ellepuntopi',
#   '@DanOClunaigh @Zone6Combat  ::::yawn:::: http://t.co/NjBemt7cHo',
#   '@Zone6Combat great fact checking there you idiots.',
#   '@Zone6Combat Um yes, terrorism is by definition political.',
#   "@OkKelly22 @Zone6Combat I'm not a Muslim and there's absolutely no evidence that the copilot was either.",
#   '@OkKelly22 @Zone6Combat Now getting back to the point: in absence of ANY evidence your assertions are groundless so why make them?',
#   '@Zone6Combat He had 10 mins, a microphone and the whole world listening to that voice recorder, where was his political message?'],
#  ['GERMAN NEWS REPORT: Co-Pilot of Germanwings Airbus Was MUSLIM CONVERT …’Hero of Islamic State’? http://t.co/Pw2kxje31m via @gatewaypundit',
#   '@jjauthor @gatewaypundit MSM refuses to say muslim. Just a mental case. As are all muslim/jihads.',
#   "@jjauthor @gatewaypundit Isn't Islam a wonderfully peaceful religion? I wonder how Iran will do with all of the peaceful centrifuges O gave?",
#   '@jjauthor @gatewaypundit i knew that scarf he was wearing in that photo meant trouble!',
#   '@jjauthor @gatewaypundit terrorism',
#   '@jjauthor @gatewaypundit. I knew it! Those crazy bastards are the only ones evil enough to do shit like that!',
#   "@jjauthor @gatewaypundit Hmmm.Doesn't pundit mean joke? I haven't seen this on news.",
#   '@jjauthor @DesireeAaron @gatewaypundit this is not a surprise.'],
#  ['BREAKING: German Media Site Says Germanwings Co-Pilot Was Muslim Convert http://t.co/bTKvcLMN60 via @anyclinic',
#   "@SoTrophyHntrs @RWSurferGirl @anyclinic It's about as legitimate as @rwsurfergirl's honesty.",
#   '@RWSurferGirl @anyclinic Is this a legit news sight?  It looks suspicious.',
#   '@JohnnyUtah27 @RWSurferGirl @anyclinic as if they would know in the first thirty seconds.....',
#   '@RWSurferGirl @anyclinic dam i thought he was muslim no wonder he was depreased',
#   "@MrJamieD @RWSurferGirl @anyclinic you can't be sain and cut off heads",
#   '@FredSanford13 @RWSurferGirl @anyclinic A good rumor has to start somewhere.',
#   '@RWSurferGirl @anyclinic No Way!!\n😵',
#   '@RWSurferGirl @anyclinic this man was sick and allowed to fly  his doctor should have mentioned this to Germanwings or more proactive..',
#   "@RWSurferGirl @anyclinic mental illness and a Muslim girlfriend and now it's discovered he's a Muslim convert while",
#   "@RWSurferGirl @anyclinic turns out the guy couldn't handle losing his job, and probably his girlfriend dumping him added to the problem..",
#   '@FredSanford13 @RWSurferGirl @anyclinic Especially since most of the posts on twitter is BS, nothing should be taken for granted.',
#   '@pbanik @RWSurferGirl @anyclinic Away from me troll!',
#   '@RWSurferGirl @anyclinic probably nonsense though.',
#   '@MrJamieD @RWSurferGirl I find the claim of suicide nonsense with this revelation.',
#   '@RWSurferGirl @anyclinic I question the relevancy to religion and mental stability, Is this a claim of radicalism?',
#   '@JohnnyUtah27 @RWSurferGirl @anyclinic yes they do!',
#   '@RWSurferGirl @weekiwachee03 @anyclinic In all fairness to muslims....this story is an unsubstantiated croc from a source with 154 followers',
#   '@RWSurferGirl @anyclinic is that true, or is that said just to cover up their incompetence?',
#   "@JohnnyUtah27 @RWSurferGirl @anyclinic if it's true, it'll be awhile before they let that little jewel out!",
#   "@SoTrophyHntrs If you don't like trolls, why do you read and/or follow @rwsurfergirl? Some of her tweets are based on dishonesty.",
#   '@CedarStArt @RWSurferGirl @anyclinic yup its all about painting a narrative.   They do it well.',
#   '@weekiwachee03 @RWSurferGirl @anyclinic its embarrassing that some conservative sites would publish it, makes them look like the daily kos',
#   "@RWSurferGirl @anyclinic I've seen several smaller websites proclaim the same thing. I'm waiting for confirmation before retweeting",
#   '@CedarStArt @RWSurferGirl @anyclinic Hah so very true!   Literally the first word out about the plane crash "Not terrorism".  Time will tell',
#   "@RWSurferGirl I'm confused, I just now read that he was suffering from depression &amp; had DRs notes excusing him from work @anyclinic",
#   '@JohnnyUtah27 @RWSurferGirl Screenshots of his social media since taken down is enough for me.']]

# %% [markdown]
# ### Question 2 (1.0 mark)
#
# **Instructions**: Next we need to preprocess the collected tweets to create a bag-of-words representation. The preprocessing steps required here are: (1) tokenize each tweet into individual word tokens (using NLTK `TweetTokenizer`); and (2) remove stopwords (based on NLTK `stopwords`).
#
# **Task**: Complete the `preprocess_events(event)` function. The function takes **a list of events** as input, and returns **a list of preprocessed events**. Each preprocessed event should have a dictionary of words and frequencies.
#
# **Check**: Use the assertion statements in *"For your testing"* below for the expected output.

# %%
import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from collections import defaultdict

tt = TweetTokenizer()
stopwords = set(stopwords.words('english'))

def preprocess_events(events):
    list_of_events = []
    
    for each_event in events:
        merged_tweets = ' '.join(each_event)
        each_tweet_tokens = tt.tokenize(merged_tweets)
        filtered_tokens = [w for w in each_tweet_tokens if w.lower() not in stopwords]
        new = count_vocab(filtered_tokens)
        list_of_events.append(new)   
    return list_of_events;
       
def count_vocab(token_list):
    vocab = {}
    for token in token_list:
        vocab.setdefault(token, 0)
        vocab[token] += 1  
    return vocab

preprocessed_rumour_events = preprocess_events(rumour_events)
preprocessed_nonrumour_events = preprocess_events(nonrumour_events)

print("Number of preprocessed rumour events =", len(preprocessed_rumour_events))
print("Number of preprocessed non-rumour events =", len(preprocessed_nonrumour_events))
# Out:
# Number of preprocessed rumour events = 500
# Number of preprocessed non-rumour events = 1000

# %% [markdown]
# **For your testing**:

# %%
assert(len(preprocessed_rumour_events) == 500)
assert(len(preprocessed_nonrumour_events) == 1000)

# %% [markdown]
# **Instructions**: Hashtags (i.e. topic tags which start with #) pose an interesting tokenisation problem because they often include multiple words written without spaces or capitalization. Run the code below to collect all unique hashtags in the preprocessed data. **No implementation is needed.**

# %%
def get_all_hashtags(events):
    hashtags = set([])
    for event in events:
        for word, frequency in event.items():
            if word.startswith("#"):
                hashtags.add(word)
    return hashtags

hashtags = get_all_hashtags(preprocessed_rumour_events + preprocessed_nonrumour_events)
print("Number of hashtags =", len(hashtags))
#hashtags
# Out:
# Number of hashtags = 1829

# %% [markdown]
# ### Question 3 (2.0 mark)
#
# **Instructions**: Our task here to tokenize the hashtags, by implementing a reversed version of the MaxMatch algorithm discussed in class, where matching begins at the end of the hashtag and progresses backwards. NLTK has a list of words that you can use for matching, see starter code below. Be careful about efficiency with respect to doing word lookups. One extra challenge you have to deal with is that the provided list of words includes only lemmas: your MaxMatch algorithm should match inflected forms by converting them into lemmas using the NLTK lemmatizer before matching. When lemmatising a word, you also need to provide the part-of-speech tag of the word. You should use `nltk.tag.pos_tag` for doing part-of-speech tagging.
#
# Note that the list of words is incomplete, and, if you are unable to make any longer match, your code should default to matching a single letter. Create a new list of tokenized hashtags (this should be a list of lists of strings) and use slicing to print out the last 20 hashtags in the list.
#
# For example, given "#speakup", the algorithm should produce: \["#", "speak", "up"\]. And note that you do not need to delete the hashtag symbol ("#") from the tokenised outputs.
#
# **Task**: Complete the `tokenize_hashtags(hashtags)` function by implementing a reversed MaxMatch algorithm. The function takes as input **a set of hashtags**, and returns **a dictionary** where key="hashtag" and value="a list of word tokens".
#
# **Check**: Use the assertion statements in *"For your testing"* below for the expected output.

# %%
#import nltk
#nltk.download('averaged_perceptron_tagger')
#nltk.download('words')
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet


lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()
words = set(nltk.corpus.words.words()) #a list of words provided by NLTK

def tokenize_hashtags(hashtags):
    dic = {}
    for each in sorted(hashtags):

        item = MaxMatch(each).split()[::-1]
        dic[each] = item
    return dic

def MaxMatch(hashtag):
    if hashtag == '':
        return ''
    for i in range(1,len(hashtag)-1):
        first_token = hashtag[i:]
        the_rest = hashtag[:i]
        
        lemma = (lemmatizer.lemmatize
                 (first_token.lower(), get_wordnet_pos(first_token.lower())))
        if lemma in [w.lower() for w in words]:
            return first_token + " " + MaxMatch(the_rest)
      
    first_token = hashtag[-1]
    the_rest = hashtag[:-1]
    return first_token + " " + MaxMatch(the_rest)

def get_wordnet_pos(word):
    pos_tag = nltk.tag.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,"N": wordnet.NOUN,
                "V": wordnet.VERB,"R": wordnet.ADV}

    return tag_dict.get(pos_tag, wordnet.NOUN)

tokenized_hashtags = tokenize_hashtags(hashtags)

print(list(tokenized_hashtags.items())[:20])
# Out:
# [('#', ['#']), ('###ards', ['#', '#', '#', 'ar', 'ds']), ('#11', ['#', '1', '1']), ('#137GUNSHOTS', ['#', '1', '3', '7', 'GUNSHOTS']), ('#13RACISTCOPS', ['#', '1', '3', 'RACIST', 'COPS']), ('#13RacistCops', ['#', '1', '3', 'Racist', 'Cops']), ('#14Words', ['#', '1', '4', 'Words']), ('#152', ['#', '1', '5', '2']), ('#1A', ['#', '1', 'A']), ('#20', ['#', '2', '0']), ('#2014', ['#', '2', '0', '1', '4']), ('#28hours', ['#', '2', '8', 'hours']), ('#2A', ['#', '2', 'A']), ('#2UNARMEDBLACKS', ['#', '2', 'UNARMED', 'BLACKS']), ('#2UnarmedBLACKS', ['#', '2', 'Unarmed', 'BLACKS']), ('#498a', ['#', '4', '9', '8', 'a']), ('#4U2521', ['#', '4', 'U', '2', '5', '2', '1']), ('#4U925', ['#', '4', 'U', '9', '2', '5']), ('#4U9525', ['#', '4', 'U', '9', '5', '2', '5']), ("#4U9525's", ['#', '4', 'U', '9', '5', '2', '5', "'", 's'])]

# %% [markdown]
# **For your testing:**

# %%
assert(len(tokenized_hashtags) == len(hashtags))

# %% [markdown]
# ### Question 4 (1.0 mark)
#
# **Instructions**: Now that we have the tokenized hashtags, we need to go back and update the bag-of-words representation for each event.
#
# **Task**: Complete the ``update_event_bow(events)`` function. The function takes **a list of preprocessed events**, and for each event, it looks for every hashtag it has and updates the bag-of-words dictionary with the tokenized hashtag tokens. Note: you do not need to delete the counts of the original hashtags when updating the bag-of-words (e.g., if a document has "#speakup":2 in its bag-of-words representation, you do not need to delete this hashtag and its counts).

# %%
def update_event_bow(events):
    b = []
    
    for each_event in events:
        hashtag_set = each_event.keys() & tokenized_hashtags.keys()
        #print(hashtag_set)
        d=[]
        for i in hashtag_set:
            a = tokenized_hashtags[i]
            d = d + a
        for token in d:
            each_event.setdefault(token, 0)
            each_event[token] += 1 
        b.append(each_event)
        
    return b
     
update_event_bow(preprocessed_rumour_events)
update_event_bow(preprocessed_nonrumour_events)

print("Number of preprocessed rumour events =", len(preprocessed_rumour_events))
print("Number of preprocessed non-rumour events =", len(preprocessed_nonrumour_events))
# Out:
# Number of preprocessed rumour events = 500
# Number of preprocessed non-rumour events = 1000

# %%
preprocessed_rumour_events
# Out:
# [{'Michael': 2,
#   'Brown': 2,
#   '17': 4,
#   'yr': 2,
#   'old': 4,
#   'boy': 5,
#   'shot': 7,
#   '10x': 2,
#   '&': 4,
#   'killed': 2,
#   'police': 10,
#   '#Ferguson': 3,
#   'today': 2,
#   '.': 47,
#   'Media': 2,
#   'reports': 2,
#   '"': 22,
#   'shoot': 2,
#   'man': 3,
#   '#blackboysonly': 2,
#   '@TrueNameBrand': 1,
#   '@CyMadD0x': 6,
#   '@AmeenaGK': 38,
#   'must': 1,
#   'racist': 1,
#   'notice': 1,
#   '#WarOnWomen': 1,
#   'stopping': 1,
#   'us': 1,
#   'getting': 1,
#   'equal': 1,
#   'pay': 1,
#   '...': 2,
#   '@d_m_elms': 2,
#   '@jaythenerdkid': 3,
#   'traces': 1,
#   'back': 6,
#   'bogus': 1,
#   'allegations': 1,
#   'something': 1,
#   'kindergarten': 1,
#   'justify': 1,
#   'dangerous': 1,
#   '@RaavynnDigitaL': 2,
#   'quaint': 1,
#   'black': 8,
#   'men': 3,
#   'boys': 1,
#   'saying': 1,
#   'would': 2,
#   'get': 1,
#   'trouble': 1,
#   ',': 17,
#   "they're": 1,
#   'thugs': 1,
#   '@retrocombine': 16,
#   '18': 1,
#   'assaulted': 1,
#   'officer': 2,
#   '@kevinwmiller': 12,
#   '?': 15,
#   'meant': 1,
#   'MSM': 1,
#   'report': 2,
#   'NYPD': 1,
#   'point': 1,
#   'taken': 1,
#   '@justinstoned': 1,
#   '@PsychicDogTalk': 6,
#   'excuse': 1,
#   'ten': 1,
#   'times': 1,
#   'Ten': 1,
#   'protect': 1,
#   'candy': 1,
#   "He's": 1,
#   'young': 1,
#   'six': 1,
#   'feet': 1,
#   'around': 2,
#   '200lbs': 1,
#   'reason': 1,
#   'violence': 3,
#   'reported': 2,
#   'nobody': 1,
#   'gives': 1,
#   'shit': 1,
#   'poor': 1,
#   'people': 3,
#   'kill': 1,
#   'know': 2,
#   'cops': 2,
#   'right': 2,
#   'Also': 1,
#   'libertarian': 1,
#   'siding': 1,
#   'pigs': 1,
#   'course': 1,
#   'upset': 1,
#   'son': 1,
#   'dead': 1,
#   'matter': 1,
#   'fault': 1,
#   'msm': 1,
#   "that's": 1,
#   'cable': 1,
#   'CHILD': 1,
#   'KILLED': 1,
#   'PROTECT': 1,
#   'CANDY': 1,
#   'headline': 1,
#   'happened': 4,
#   'cop': 2,
#   'pushed': 2,
#   'motivated': 2,
#   "That's": 2,
#   'story': 1,
#   'understand': 1,
#   'jumping': 1,
#   'conclusions': 1,
#   'turning': 1,
#   'everything': 1,
#   'race': 4,
#   'war': 2,
#   'pointing': 1,
#   'double': 1,
#   'Standard': 1,
#   'barely': 1,
#   "I'm": 1,
#   'screaming': 1,
#   'racism': 2,
#   'bring': 1,
#   'issues': 2,
#   'major': 1,
#   'problem': 3,
#   'days': 2,
#   'Even': 1,
#   'case': 3,
#   'warrant': 1,
#   '8': 1,
#   'bullets': 2,
#   'got': 2,
#   'idea': 1,
#   'deal': 1,
#   'specific': 1,
#   "there's": 3,
#   'much': 1,
#   'larger': 2,
#   'Two': 2,
#   'shots': 1,
#   'fired': 3,
#   'outside': 1,
#   'car': 4,
#   'eight': 1,
#   'democrats': 1,
#   'run': 1,
#   '#racism': 1,
#   'sexism': 1,
#   'communism': 1,
#   'hope': 1,
#   'incident': 1,
#   'captured': 1,
#   'camera': 1,
#   '#Trayvon': 1,
#   'may': 2,
#   'resolve': 1,
#   'one': 1,
#   'still': 2,
#   'needs': 1,
#   'addressed': 1,
#   'seem': 2,
#   'racially': 1,
#   'seemed': 1,
#   'like': 1,
#   'criminal': 1,
#   'trying': 1,
#   'take': 1,
#   'officers': 1,
#   'gun': 2,
#   'Yeah': 1,
#   'agree': 2,
#   'sit': 1,
#   'wait': 1,
#   'facts': 1,
#   'See': 1,
#   'really': 1,
#   'fucking': 1,
#   'joke': 1,
#   'tru': 1,
#   'marginlized': 1,
#   'grps': 1,
#   'nyc': 1,
#   'try': 1,
#   'reporting': 1,
#   'gay': 1,
#   'domestic': 1,
#   'bed': 1,
#   'stuy': 1,
#   'struggled': 1,
#   'pushes': 1,
#   'went': 2,
#   'sidearm': 1,
#   'Weapon': 1,
#   'inside': 2,
#   'year': 2,
#   'consider': 1,
#   'excessive': 1,
#   'force': 1,
#   'regardless': 1,
#   'whether': 1,
#   "something's": 1,
#   'serious': 1,
#   'racial': 1,
#   'US': 1,
#   "i'm": 1,
#   'sure': 1,
#   'matters': 2,
#   "he's": 2,
#   'underage': 1,
#   'Boy': 1,
#   'Racist': 1,
#   'According': 1,
#   'CBS': 1,
#   'http://t.co/Joj9cniAE4': 1,
#   'unarmed': 1,
#   'instead': 1,
#   'fellow': 1,
#   'blacks': 1,
#   'Better': 1,
#   'make': 2,
#   'national': 1,
#   'news': 1,
#   "I'd": 2,
#   'assume': 1,
#   'white': 1,
#   'reaction': 1,
#   'brought': 1,
#   'lot': 1,
#   'racially-motivated': 1,
#   'events': 1,
#   'light': 1,
#   'long': 1,
#   'conservative': 1,
#   'pundit': 1,
#   'finds': 1,
#   'pic': 1,
#   'messing': 1,
#   'friends': 1,
#   'ID': 1,
#   'leftist': 1,
#   'conspiracy': 1,
#   'less': 1,
#   'violent': 1,
#   '#tinfoilin': 1,
#   '=p': 1,
#   'mother': 1,
#   'says': 1,
#   ';': 1,
#   'even': 1,
#   'chief': 1,
#   'said': 1,
#   'couple': 1,
#   'http://t.co/iUTZSW8ZgE': 1,
#   "they'll": 1,
#   'drag': 1,
#   'entire': 1,
#   'history': 1,
#   'every': 2,
#   'stolen': 1,
#   'sip': 1,
#   "dad's": 1,
#   'beer': 1,
#   'second-hand': 1,
#   'tendril': 1,
#   'pot': 1,
#   'smoke': 1,
#   'watch': 1,
#   'else': 1,
#   '#': 6,
#   'tin': 1,
#   'fo': 1,
#   'i': 1,
#   'lin': 1,
#   'Ferguson': 1,
#   'Tray': 1,
#   'v': 1,
#   'on': 1,
#   'blackboy': 1,
#   'sonly': 1,
#   'Wa': 1,
#   'rOn': 1,
#   'Women': 1},
#  {'17': 3,
#   'year': 3,
#   'old': 3,
#   'unarmed': 3,
#   'kid': 3,
#   'shot': 3,
#   'ten': 4,
#   'times': 4,
#   'police': 5,
#   'stealing': 6,
#   'candy': 9,
#   '.': 28,
#   'know': 4,
#   'punishable': 5,
#   'death': 5,
#   '(': 3,
#   'read': 3,
#   '#ferguson': 4,
#   'tag': 3,
#   ')': 3,
#   '@inthefade': 18,
#   "there's": 1,
#   'excuse': 2,
#   '18': 1,
#   'Nothing': 1,
#   'walking': 1,
#   'street': 1,
#   'Horrible': 1,
#   'situation': 1,
#   'stop': 1,
#   'spreading': 1,
#   'false': 1,
#   'facts': 1,
#   'someone': 1,
#   'starts': 1,
#   'assaulting': 1,
#   'officer': 1,
#   '@AnneMarieFlynn2': 2,
#   '@adam_zander': 1,
#   'unbelievable': 1,
#   ',': 8,
#   '@JackieWillard2': 1,
#   'days': 1,
#   'anything': 1,
#   'especially': 1,
#   'Stand': 1,
#   'Ground': 1,
#   'even': 2,
#   'sneeze': 1,
#   '@Alasscan_': 3,
#   'true': 1,
#   'stole': 2,
#   '“': 1,
#   ':': 1,
#   '@klemosy': 1,
#   'Anything': 1,
#   'youth': 1,
#   'black': 3,
#   'apparently': 1,
#   '@pjhnsn8': 1,
#   'going': 1,
#   'early': 1,
#   'last': 1,
#   'night': 1,
#   'real': 1,
#   'news': 1,
#   'point': 1,
#   '#Shot': 1,
#   '?': 1,
#   'God': 1,
#   'mercy': 1,
#   '!': 4,
#   '@divineem': 1,
#   'applies': 1,
#   'Black': 1,
#   'people': 1,
#   'proof': 1,
#   'guess': 1,
#   'skittles': 1,
#   'become': 1,
#   'reason': 1,
#   'kill': 1,
#   'teens': 1,
#   '@Alllwftopic': 1,
#   'Agreed': 1,
#   'charged': 1,
#   'w': 1,
#   '/': 1,
#   'murder': 1,
#   'story': 2,
#   'makes': 1,
#   'physically': 1,
#   'sick': 1,
#   '@marieann66': 1,
#   'http://t.co/PDo2pakAln': 1,
#   '@Smilingl8dy': 1,
#   'say': 1,
#   '"': 2,
#   'allegedly': 1,
#   'Also': 1,
#   'stmt': 1,
#   'mention': 1,
#   'cause': 1,
#   'understand': 1,
#   'changed': 1,
#   'cigs': 1,
#   'tussle': 1,
#   'car': 1,
#   'saggy': 1,
#   'pants': 1,
#   'maybe': 1,
#   'never': 1,
#   'truthful': 1,
#   'not-unless': 1,
#   'happen': 1,
#   'male': 1,
#   'apparently.We': 1,
#   'make': 1,
#   'far': 1,
#   'accountable': 1,
#   "can't": 1,
#   'go': 1,
#   '#': 2,
#   'ferguson': 1,
#   'Shot': 1},
#  {'White': 1,
#   'man': 1,
#   'aiming': 1,
#   'police': 1,
#   '...': 1,
#   'nothing': 1,
#   'happens': 1,
#   '.': 2,
#   'Unarmed': 1,
#   'black': 1,
#   'kid': 1,
#   'walking': 1,
#   'back': 1,
#   'store': 1,
#   'shot': 1,
#   '10': 1,
#   'times': 1,
#   '#Ferguson': 1,
#   'http://t.co/48EcUF2Bwa': 1,
#   '#': 1,
#   'Ferguson': 1},
#  {'Teenager': 2,
#   '#MikeBrown': 3,
#   'start': 3,
#   'college': 3,
#   'Monday': 3,
#   'shot': 4,
#   'ten': 4,
#   'times': 5,
#   '#Ferguson': 4,
#   'police': 7,
#   'officer': 3,
#   '.': 29,
#   'http://t.co/B4hWevO7l9': 2,
#   '@armybulldog20': 2,
#   'http://t.co/cFWVhcZMx1': 2,
#   '@RedwoodGirl': 4,
#   '@YourAnonGlobal': 22,
#   '@YourAnonNews': 10,
#   'Thanks': 2,
#   'help': 2,
#   '@sweden': 7,
#   'Glad': 1,
#   'could': 1,
#   'really': 1,
#   'Sweden': 1,
#   '?': 12,
#   'US': 1,
#   'must': 1,
#   'seem': 1,
#   'barbaric': 1,
#   'Europeans': 1,
#   'stories': 1,
#   'like': 2,
#   ':(': 1,
#   '@2squig': 2,
#   'teen': 1,
#   'read': 3,
#   '"': 2,
#   'Black': 1,
#   'Like': 1,
#   'things': 2,
#   'progressed': 1,
#   'much': 2,
#   '@cosmiclandmine': 1,
#   'may': 1,
#   'little': 1,
#   'story': 4,
#   "I'll": 1,
#   'wait': 1,
#   'pass': 1,
#   'judgement': 1,
#   'always': 1,
#   'bad': 2,
#   'person': 1,
#   'dies': 1,
#   '@I_hate_it_here_': 1,
#   '@ArmyBulldog20': 2,
#   'everybody': 1,
#   'knows': 1,
#   "'": 2,
#   'walking': 2,
#   'black': 3,
#   'serious': 1,
#   'crime': 1,
#   'racist': 1,
#   'Obvs': 1,
#   'age': 1,
#   'son': 1,
#   ',': 6,
#   '@7um9_': 2,
#   'thank': 1,
#   'link': 2,
#   'Well': 1,
#   '&': 1,
#   'UK': 1,
#   'Home': 1,
#   'Office': 1,
#   'relaxed': 1,
#   'routinely': 1,
#   'arming': 1,
#   'definitely': 1,
#   'think': 1,
#   '@cannotthinkwhy': 1,
#   '10': 1,
#   'bloody': 1,
#   'shots': 1,
#   'someone': 1,
#   'Bionic': 1,
#   'man': 2,
#   'overkill': 1,
#   'worries': 1,
#   'Yes': 1,
#   'awful': 2,
#   'event': 1,
#   'Check': 1,
#   'hashtag': 1,
#   'lots': 1,
#   'anger': 1,
#   'sadness': 1,
#   '@TefPoe': 1,
#   'WTF': 1,
#   'real': 1,
#   'Mike': 3,
#   'holy': 1,
#   'crap': 1,
#   '...': 1,
#   'Eyewitness': 1,
#   'report': 1,
#   'Post-Dispatch': 1,
#   'says': 1,
#   'Brown': 2,
#   'fled': 1,
#   'put': 1,
#   'car': 1,
#   '>': 1,
#   '@billthenewguy': 1,
#   'Racism': 1,
#   'dumb': 1,
#   'gets': 1,
#   "We're": 1,
#   'race': 1,
#   '(': 1,
#   'human': 1,
#   ')': 1,
#   "what's": 1,
#   'sad': 1,
#   'posting': 1,
#   'picture': 1,
#   'poor': 1,
#   'kid': 1,
#   'dead': 2,
#   'means': 1,
#   'nothing': 1,
#   'give': 1,
#   'please': 1,
#   'Oh': 1,
#   'god': 1,
#   'shoplifting': 1,
#   '!': 2,
#   'Thank': 1,
#   'Ten': 1,
#   'many': 1,
#   '“': 1,
#   ':': 2,
#   'http://t.co/FABNrZ9iCQ': 1,
#   '”': 1,
#   '@TonyMoule47': 1,
#   'Looks': 1,
#   'cops': 1,
#   'feel': 1,
#   'free': 1,
#   'shoot': 1,
#   'kill': 1,
#   'target': 1,
#   'doubt': 1,
#   "we'll": 1,
#   'see': 1,
#   'cop': 1,
#   'jailed': 1,
#   '@robert_veres': 1,
#   "Brown's": 1,
#   'family': 1,
#   'wish': 1,
#   'post': 1,
#   'pictures': 1,
#   'body': 1,
#   'thx': 1,
#   'probably': 1,
#   'good': 1,
#   'idea': 1,
#   'way': 1,
#   'deserve': 1,
#   'getting': 1,
#   'killed': 1,
#   '@youranonglobal': 1,
#   '@youranonnews': 1,
#   'St': 1,
#   'Louis': 1,
#   'Post': 1,
#   'Dispatch': 1,
#   'http://t.co/I6hatQKNWI': 1,
#   'Apparently': 1,
#   'shoplifted': 1,
#   'candy': 1,
#   'bar': 1,
#   '@Renemies': 1,
#   'http://t.co/W1n9bYASlc': 1,
#   '#': 2,
#   'Ferguson': 1},
#  {'Supposedly': 1,
#   'might': 1,
#   'one': 1,
#   'two': 1,
#   'witnesses': 1,
#   'shooting': 2,
#   'part': 1,
#   'recorded': 1,
#   'phones': 1,
#   '.': 1,
#   '#Ferguson': 1,
#   '#': 1,
#   'Ferguson': 1},
#  {'St': 1,
#   '.': 1,
#   'Louis': 1,
#   ':': 1,
#   'Unarmed': 1,
#   'teenager': 1,
#   '#MikeBrown': 1,
#   'shot': 1,
#   'ten': 1,
#   'times': 1,
#   '#Ferguson': 1,
#   'police': 1,
#   'officer': 1,
#   'accusation': 1,
#   'shoplifting': 1,
#   'http://t.co/cmaG8mnMiP': 1,
#   '#': 2,
#   'Ferguson': 1,
#   'Mike': 1,
#   'Brown': 1},
#  {'Witness': 3,
#   ':': 4,
#   'Police': 5,
#   'allegedly': 3,
#   'stopped': 3,
#   'Mike': 3,
#   'Brown': 3,
#   'yelling': 3,
#   'walk': 4,
#   'sidewalk': 3,
#   '.': 15,
#   '#Ferguson': 3,
#   'http://t.co/XG00R6w0k6': 2,
#   '@MichaelSkolnik': 21,
#   '@AC_BOwen': 6,
#   '#Cleveland': 6,
#   'Excuse': 1,
#   'Chase': 1,
#   '11-29-': 2,
#   '12': 4,
#   '~': 10,
#   '#2UnarmedBLACKS': 1,
#   '#MURDERED': 3,
#   '#13RACISTCOPS': 1,
#   '#137GUNSHOTS': 1,
#   '#GOOGLE': 1,
#   'Shoot': 1,
#   '137': 1,
#   'Times': 1,
#   '<': 10,
#   '#MURDERING': 1,
#   '#2UNARMEDBLACKS': 2,
#   'Many': 1,
#   '#UNARMEDBLACKS': 2,
#   'Another': 1,
#   'win': 1,
#   'gene': 1,
#   'pool': 1,
#   '“': 1,
#   'http://t.co/TYdMSNxGlo': 1,
#   '”': 1,
#   'cool': 1,
#   '!': 11,
#   'Darkskinned': 1,
#   'man': 1,
#   'crime': 1,
#   'element': 1,
#   'village': 2,
#   '?': 10,
#   ',': 9,
#   '#obama': 1,
#   'alive': 1,
#   'yet': 1,
#   'u': 1,
#   'think': 1,
#   'something': 1,
#   'another': 1,
#   'says': 1,
#   'somehow': 1,
#   'hold': 1,
#   'back': 1,
#   'loser': 1,
#   '&': 1,
#   'deserve': 1,
#   'failure': 1,
#   '@TimmyTurnUp': 5,
#   '@Agent_Kindi': 6,
#   'Cop': 2,
#   'Shot': 2,
#   '19yr': 1,
#   'Old': 1,
#   'Head': 1,
#   '#Black': 1,
#   '#Unarmed': 1,
#   '#MomsOnlyChild': 1,
#   'Said': 1,
#   '#THOUGHT': 1,
#   'Saw': 1,
#   'Gun': 1,
#   '@SecretService': 2,
#   'Like': 3,
#   'Tweet': 1,
#   'Asking': 1,
#   '#Obama': 3,
#   'Alive': 2,
#   'Yet': 1,
#   '#WePray': 1,
#   '#SecretService': 2,
#   '@Progress4Ohio': 2,
#   "I'm": 2,
#   'RACIST': 3,
#   'live': 1,
#   'together': 1,
#   '200': 1,
#   'nations': 1,
#   'Russia': 1,
#   'U': 2,
#   'go': 1,
#   'words': 1,
#   'mucacho': 1,
#   '#MalissaWilliamsAndTimothyRussell': 2,
#   'Got': 1,
#   '#Justice': 1,
#   '#13RacistCops': 2,
#   '#NotCHARGED': 2,
#   '#BlackLifeMatters': 1,
#   'People': 1,
#   '#MURDER': 1,
#   'Ask': 1,
#   'Still': 1,
#   '#RACIST': 1,
#   '#KKK': 1,
#   '#SMH': 1,
#   '@Supreme___Power': 6,
#   'edgy': 1,
#   '@CivilRights': 2,
#   '#UNARMED': 1,
#   'White': 2,
#   'guys': 2,
#   'jealous': 1,
#   'responses': 1,
#   'explain': 1,
#   'thiskeeps': 1,
#   'happening': 1,
#   'many': 3,
#   'white': 3,
#   'men': 2,
#   'hate': 1,
#   'black': 2,
#   'Sad': 1,
#   'want': 1,
#   'say': 1,
#   '"': 2,
#   'guilty': 1,
#   'Moscow': 1,
#   'sold': 1,
#   'drugs': 1,
#   '...': 1,
#   'Case': 1,
#   'Covered': 1,
#   'Mayor': 1,
#   'Cops': 2,
#   'Sides': 1,
#   'fuck': 1,
#   'anyone': 1,
#   'streets': 1,
#   'knife': 1,
#   'gun': 1,
#   'glad': 1,
#   'amigo': 1,
#   'love': 1,
#   'president': 1,
#   'kills': 1,
#   'children': 1,
#   'Ukrain': 1,
#   'Gaza': 1,
#   'places': 1,
#   ';-)': 2,
#   '@ValMackinnon': 1,
#   'perfect': 1,
#   ')': 2,
#   'Daniel': 1,
#   'Craig': 1,
#   'throw': 1,
#   'GF': 1,
#   'window': 1,
#   'girls': 1,
#   'smart': 1,
#   'Protects': 1,
#   '#PresidentObama': 1,
#   "Get's": 1,
#   'Threats': 1,
#   'Time': 1,
#   '#': 29,
#   'GO': 1,
#   'OGLE': 1,
#   'Unarmed': 2,
#   'MURDERED': 1,
#   '2': 2,
#   'BLACKS': 3,
#   'THOUGHT': 1,
#   'P': 1,
#   're': 1,
#   'si': 1,
#   'den': 1,
#   'tO': 1,
#   'b': 3,
#   'ama': 3,
#   'MURDER': 1,
#   'O': 1,
#   'Justice': 1,
#   '1': 3,
#   '3': 3,
#   'COPS': 1,
#   'MURDERING': 1,
#   'UNARMED': 3,
#   'We': 1,
#   'Pray': 1,
#   'M': 2,
#   'om': 1,
#   'sOnly': 1,
#   'Child': 1,
#   'C': 1,
#   'lev': 1,
#   'eland': 1,
#   'Black': 2,
#   'Life': 1,
#   'Matters': 1,
#   'Not': 1,
#   'CHARGED': 1,
#   '7': 1,
#   'GUNSHOTS': 1,
#   'Racist': 1,
#   'Ferguson': 1,
#   'Secret': 1,
#   'Service': 1,
#   'o': 1,
#   'K': 3,
#   'Malis': 1,
#   'sa': 1,
#   'William': 1,
#   'sAnd': 1,
#   'Timothy': 1,
#   'Russell': 1,
#   'S': 1,
#   'H': 1},
#  {'.': 30,
#   '@NBCNews': 19,
#   'demand': 2,
#   'retract': 2,
#   'lie': 2,
#   '#Ferguson': 2,
#   'people': 2,
#   'shouting': 2,
#   '"': 14,
#   'Kill': 2,
#   'police': 2,
#   'Reporters': 2,
#   'scene': 3,
#   'refuted': 2,
#   '@daiconrad': 1,
#   '@QuadCityPat': 23,
#   'thanks': 1,
#   ',': 10,
#   'included': 1,
#   'http://t.co/hUi26I5oZZ': 1,
#   '@kileykroh': 5,
#   'seems': 1,
#   'small': 1,
#   'step': 1,
#   'killer': 2,
#   'cops': 3,
#   'mishearing': 1,
#   'kill': 1,
#   'worth': 1,
#   '. .': 2,
#   '@Conservativrulz': 6,
#   'fuck': 2,
#   'outta': 1,
#   'troll': 1,
#   '#scram': 1,
#   '@KMBTweets': 3,
#   '@AP': 4,
#   '@blackvoices': 4,
#   'Ok': 1,
#   'Oh': 1,
#   'ISH': 1,
#   '!': 12,
#   '@NBC': 1,
#   'lied': 1,
#   '?': 7,
#   'media': 1,
#   'must': 1,
#   'narrative': 1,
#   'Unarmed': 1,
#   'blk': 1,
#   'boy': 1,
#   'shot': 1,
#   '10': 1,
#   'times': 1,
#   'cut': 1,
#   '4': 2,
#   'AP': 1,
#   'conservative': 1,
#   'bias': 1,
#   '#liberalmediamyfoot': 1,
#   'links': 1,
#   'specific': 1,
#   'reporters': 2,
#   'looking': 1,
#   'local': 2,
#   'video': 1,
#   'protests.They': 1,
#   'saying': 1,
#   'Justice': 1,
#   'Peace': 1,
#   'Media': 1,
#   'always': 1,
#   'falsely': 1,
#   'reported': 1,
#   'racial': 1,
#   'issues': 1,
#   'keep': 1,
#   'races': 1,
#   'America': 1,
#   'divided': 1,
#   'Division': 1,
#   'wks': 1,
#   '1': 1,
#   '%': 1,
#   'Heh': 1,
#   'shares': 1,
#   'name': 1,
#   'birth': 1,
#   'control': 1,
#   'pill': 1,
#   '@3ChicsPolitico': 1,
#   '@nbc': 1,
#   'George': 1,
#   'Bush': 1,
#   'course': 1,
#   'LORD': 1,
#   'IGNORANCE': 1,
#   'Stop': 1,
#   'Killing': 1,
#   'Us': 1,
#   'AH': 1,
#   'SHARPTON': 1,
#   'field': 1,
#   'day': 1,
#   "He's": 1,
#   'biggest': 1,
#   'racists': 1,
#   'planet': 2,
#   '...': 1,
#   'thank': 1,
#   'tweet': 1,
#   'God': 1,
#   'bless': 1,
#   '“': 1,
#   'Get': 1,
#   'Town': 1,
#   'Cracker': 1,
#   '”': 1,
#   'sprayed': 1,
#   'white': 1,
#   'man': 1,
#   '’': 1,
#   'burnt-down': 1,
#   'house': 1,
#   'March': 1,
#   '28': 1,
#   '2014': 2,
#   'CRIME': 2,
#   '/': 3,
#   '..': 3,
#   'REGARDLESS': 1,
#   'idiot': 2,
#   'compare': 1,
#   'vandalism': 2,
#   'shooting': 1,
#   'death': 2,
#   'gets': 1,
#   'vote': 1,
#   '@adbridgeforth': 1,
#   'Exactly': 1,
#   'justice': 1,
#   'peace': 1,
#   '@SharonMelendes': 1,
#   'ignorance': 1,
#   '>': 4,
#   'CONSERVATIVES': 1,
#   'KILL': 1,
#   'PEOPLE': 1,
#   'GEEESH': 1,
#   'YEP': 1,
#   'BUSH': 1,
#   'Parity': 1,
#   ':': 2,
#   'FUCK': 1,
#   'WORK': 1,
#   '#moron': 1,
#   '@Donna_West': 1,
#   "That's": 1,
#   'LYING': 1,
#   'ASS': 1,
#   'MEDIA': 1,
#   'ya': 1,
#   'Blacks': 1,
#   'beat': 1,
#   'Matthew': 1,
#   'Boorujuy': 1,
#   'calling': 1,
#   'cracker': 1,
#   'May': 1,
#   'KILLING': 1,
#   'RIGHT': 1,
#   'W': 1,
#   'BLACK.BLK/WHITE': 1,
#   'link': 1,
#   'refuting': 1,
#   "I'm": 1,
#   'working': 1,
#   'piece': 1,
#   'would': 1,
#   'like': 1,
#   'include': 1,
#   'Thanks': 1,
#   '@_MylesHigh': 1,
#   'anything': 1,
#   'promote': 1,
#   'fear': 1,
#   'huh': 1,
#   '#Sad': 1,
#   'retweeted': 1,
#   'vine': 1,
#   'shows': 1,
#   'chanting': 1,
#   'Hey': 1,
#   'hey': 1,
#   'ho': 2,
#   'got': 1,
#   'go': 1,
#   'yeah': 1,
#   'hoping': 1,
#   'find': 1,
#   'something': 1,
#   'someone': 1,
#   'ground': 1,
#   'comparing': 1,
#   'murder': 1,
#   'Eff': 1,
#   'life': 1,
#   'Yes': 1,
#   'tell': 1,
#   '&': 1,
#   'divisive': 1,
#   'propaganda': 1,
#   '#': 5,
#   'scram': 1,
#   'Sad': 1,
#   'liber': 1,
#   'alme': 1,
#   'di': 1,
#   'amy': 1,
#   'foot': 1,
#   'Ferguson': 1,
#   'moron': 1},
#  {'last': 2,
#   'week': 2,
#   'NYPD': 2,
#   'tried': 2,
#   'tell': 2,
#   'us': 5,
#   '#EricGarner': 2,
#   'chokehold': 2,
#   ',': 3,
#   '#Ferguson': 2,
#   'police': 2,
#   'telling': 3,
#   '#MikeBrown': 3,
#   'assaulted': 2,
#   'officer': 2,
#   '@SoulRevision': 2,
#   'Even': 1,
#   'true': 1,
#   '(': 1,
#   'almost': 1,
#   'definitely': 1,
#   ')': 1,
#   "that's": 1,
#   'excuse': 1,
#   'execute': 1,
#   'street': 1,
#   '.': 1,
#   '@zellieimani': 1,
#   'lies': 1,
#   'Sunday': 1,
#   '#': 3,
#   'Eric': 1,
#   'Garner': 1,
#   'Ferguson': 1,
#   'Mike': 1,
#   'Brown': 1},
#  {'#Ferguson': 2,
#   'Police': 2,
#   'afford': 7,
#   'machine': 3,
#   'guns': 3,
#   "can't": 3,
#   'dash': 2,
#   'cameras': 3,
#   'squad': 2,
#   'cars': 3,
#   '?': 5,
#   '#interesting': 2,
#   '#MikeBrown': 3,
#   '@unpreachedtruth': 14,
#   '@TheAnonMessage': 8,
#   'chief': 1,
#   'police': 1,
#   'said': 1,
#   'last': 1,
#   'night': 1,
#   'got': 1,
#   'boxes': 2,
#   'still': 2,
#   '.': 17,
#   'thought': 1,
#   'purchased': 1,
#   'never': 2,
#   'installed': 3,
#   '@vdogg9': 1,
#   'open': 2,
#   '@Wanderer19': 3,
#   'Like': 1,
#   'pro-gunners': 1,
#   'find': 1,
#   '$': 1,
#   'AR': 1,
#   '-': 1,
#   '15s': 1,
#   ',': 6,
#   'claim': 1,
#   'mandatory': 1,
#   'gun': 1,
#   'insurance': 1,
#   'would': 1,
#   'financial': 1,
#   'hardship': 1,
#   '@runsammrun': 2,
#   "That's": 1,
#   'crazy': 1,
#   'seem': 1,
#   'disorganized': 1,
#   'came': 1,
#   'preparing': 1,
#   'riots': 1,
#   'ha': 1,
#   'stakes': 1,
#   'higher': 1,
#   '@deBeauxOs1': 1,
#   'well': 1,
#   'least': 1,
#   'bothered': 1,
#   'take': 1,
#   'box': 1,
#   'sure': 1,
#   'read': 2,
#   'matter': 1,
#   'laziness': 1,
#   '/': 4,
#   'disorganization': 1,
#   'carelessness': 1,
#   '@rockermom53': 2,
#   '|': 2,
#   'Agree': 1,
#   'plenty': 1,
#   'war-hardware': 1,
#   'need': 1,
#   'focus': 1,
#   'ppl': 1,
#   'skills': 1,
#   '&': 3,
#   'train': 1,
#   'serve': 1,
#   'protect': 1,
#   '@norwind': 2,
#   'huh': 1,
#   "that's": 1,
#   'important': 1,
#   'ready': 1,
#   'slaughter': 1,
#   'people': 1,
#   'think': 1,
#   'rights': 1,
#   'proves': 1,
#   "they're": 1,
#   'smh': 1,
#   'install': 1,
#   'video': 2,
#   'patrol': 1,
#   'make': 1,
#   'audio': 1,
#   'recording': 1,
#   'contact': 1,
#   'public': 1,
#   'suspect': 1,
#   '@BallerinaX': 1,
#   '1033': 1,
#   'program': 1,
#   'rifles': 1,
#   'probably': 1,
#   'cost': 1,
#   'less': 1,
#   'body': 1,
#   'cams': 1,
#   '@DaleGunn3': 1,
#   'protecting': 1,
#   'serving': 2,
#   'Clearly': 1,
#   '#smh': 1,
#   'LOT': 1,
#   'fire': 1,
#   'power': 1,
#   'small': 1,
#   'city': 1,
#   'Protecting': 1,
#   'right': 1,
#   '#': 4,
#   'Ferguson': 1,
#   's': 1,
#   'm': 1,
#   'h': 1,
#   'interesting': 1,
#   'Mike': 1,
#   'Brown': 1},
#  {'Line': 1,
#   'police': 1,
#   'cars': 1,
#   'high': 1,
#   'beams': 1,
#   'greets': 1,
#   'anyone': 1,
#   'trying': 1,
#   'enter': 1,
#   '#Ferguson': 2,
#   '.': 14,
#   'shut': 1,
#   'media': 1,
#   'allowed': 1,
#   'http://t.co/bk6jFFM7jj': 1,
#   '@AnonymousPress': 14,
#   'FAA': 1,
#   'declared': 1,
#   'no-fly': 1,
#   'zone': 1,
#   '~': 1,
#   '>': 1,
#   'Gaza': 1,
#   'Iraq': 1,
#   'Soon': 1,
#   'burst': 1,
#   'homes': 1,
#   ',': 3,
#   'rape': 1,
#   'babies': 1,
#   'force': 1,
#   'mothers': 1,
#   'watch': 1,
#   'fuck': 1,
#   'Chef': 1,
#   'board': 1,
#   'reminded': 1,
#   'Tienanmen': 1,
#   'Square': 1,
#   'photo': 1,
#   'last': 2,
#   'night': 2,
#   '?': 6,
#   'Please': 1,
#   'clarify': 1,
#   'using': 1,
#   'present': 1,
#   'tense': 1,
#   'pigs': 1,
#   'need': 1,
#   'taken': 1,
#   '!': 3,
#   '@CFormigoni5': 1,
#   'cop': 1,
#   'shoots': 1,
#   'unarmed': 1,
#   'black': 1,
#   'man': 2,
#   'citizens': 1,
#   'start': 1,
#   'looting': 1,
#   'burning': 1,
#   'community.is': 1,
#   'make': 1,
#   'sense': 1,
#   'Freedom': 1,
#   'press': 1,
#   'ass': 1,
#   'Yeah': 1,
#   'Land': 1,
#   'Free': 1,
#   '%': 1,
#   '&': 1,
#   'guys': 1,
#   'boneheads': 1,
#   'tyranny': 1,
#   '...': 1,
#   'Beuller': 1,
#   'Ferguson': 2,
#   'joining': 1,
#   'Russia': 1,
#   'China': 1,
#   'communist': 1,
#   'style': 1,
#   'governance': 1,
#   'cops': 1,
#   'calling': 1,
#   'protesters': 1,
#   'animals': 1,
#   "that's": 1,
#   'tonight': 1,
#   '#': 1},
#  {'death': 9,
#   '#MikeBrown': 9,
#   'told': 10,
#   'mother': 10,
#   ',': 10,
#   '"': 22,
#   'world': 9,
#   'know': 10,
#   '#MichaelBrown': 9,
#   '!': 10,
#   '#Ferguson': 9,
#   '@BridjesONeil': 16,
#   '@Donna_West': 2,
#   'gonna': 1,
#   'call': 1,
#   'big': 1,
#   'probably': 1,
#   'one': 1,
#   '.': 11,
#   '“': 6,
#   ':': 7,
#   '”': 6,
#   'Holy': 1,
#   'Moly': 1,
#   'amazing': 1,
#   '@xbreakingeven': 1,
#   'sounds': 2,
#   'little': 1,
#   'made': 1,
#   ':(': 1,
#   '😞': 2,
#   '@GingePurps': 1,
#   'spoken': 1,
#   'tonight': 1,
#   'Another': 1,
#   'speaker': 1,
#   'shared': 1,
#   'information': 1,
#   "must've": 1,
#   '@nellbernstein': 1,
#   'heart': 1,
#   'wrenching': 1,
#   'real': 2,
#   '@AntonioFrench': 3,
#   'naaaaaaawwwww': 1,
#   '?': 4,
#   'Sounds': 1,
#   'like': 2,
#   'something': 1,
#   'someone': 1,
#   'kamikaze': 1,
#   'mission': 1,
#   'would': 1,
#   'say': 1,
#   'bullshit': 1,
#   '...': 2,
#   'قال': 1,
#   'زو': 1,
#   'الثمانية': 1,
#   'عشر': 1,
#   'لوالدته': 1,
#   'قبل': 1,
#   'مقتله': 1,
#   'بيد': 1,
#   'الشرطي': 1,
#   'الامريكي': 1,
#   'سيعلم': 1,
#   'العالم': 1,
#   'من': 1,
#   'هو': 1,
#   'ً': 1,
#   'ميكي': 1,
#   'براون': 1,
#   'meaning': 1,
#   "can't": 1,
#   'imagine': 1,
#   'anyone': 1,
#   'outside': 1,
#   'movie': 1,
#   'saying': 1,
#   'thing': 1,
#   'Seriously': 1,
#   'doubt': 1,
#   'Maybe': 1,
#   'likely': 1,
#   'love': 2,
#   'ya': 1,
#   'momma': 1,
#   '@saramarietweets': 1,
#   'regardless': 1,
#   'always': 1,
#   'known': 1,
#   'child': 1,
#   'another': 1,
#   'morn': 1,
#   'Speechless': 1,
#   'RT': 1,
#   'sigh': 1,
#   '#': 3,
#   'Ferguson': 1,
#   'Mike': 1,
#   'Brown': 2,
#   'Michael': 1},
#  {'Currently': 3,
#   '#FoxNews': 4,
#   'website': 4,
#   'zero': 3,
#   ',': 19,
#   'repeat': 2,
#   'ZERO': 2,
#   'coverage': 4,
#   '#Ferguson': 3,
#   'protests': 2,
#   'probably': 2,
#   'due': 2,
#   'lack': 3,
#   'cowboy': 2,
#   'hats': 2,
#   '.': 27,
#   '@clydetheslyde': 39,
#   '@SacJim2012': 4,
#   'already': 1,
#   "f'd": 1,
#   '..': 11,
#   '#different': 1,
#   'accounts': 1,
#   'happened': 1,
#   '#dirtyTruth': 1,
#   'come': 1,
#   'light': 1,
#   'plenty': 1,
#   'world': 1,
#   'cover': 2,
#   'instead': 1,
#   'focusing': 1,
#   'one': 2,
#   "woman's": 1,
#   'ass': 1,
#   '@mechphree': 3,
#   '@mylifeishid': 4,
#   'FOX': 2,
#   'BECOME': 1,
#   'REPUBLICAN': 1,
#   'POLITICIANS': 1,
#   'INFOMERCIAL': 1,
#   '&': 3,
#   'REALLY': 1,
#   'INTERESTED': 1,
#   'REAL': 1,
#   'NEWS': 2,
#   'BOYCOTT': 1,
#   '!': 7,
#   '@michael_flinch': 7,
#   '@smeezi': 6,
#   'Yikes': 1,
#   'indeed': 1,
#   'assholes': 1,
#   'FOXNEWS': 1,
#   'major': 1,
#   'reason': 1,
#   'stupid': 1,
#   'cops': 1,
#   'give': 1,
#   'damn': 1,
#   'life': 1,
#   'young': 2,
#   'black': 4,
#   'kids': 1,
#   'know': 2,
#   "that's": 1,
#   'right': 2,
#   'hoping': 1,
#   'god': 1,
#   '#Someone': 1,
#   'captured': 1,
#   'phone': 1,
#   '+': 2,
#   'came': 1,
#   'forward': 1,
#   '-': 1,
#   'yet': 2,
#   '(': 1,
#   'video': 1,
#   '/': 2,
#   'shooting': 2,
#   ')': 1,
#   'get': 1,
#   '"': 4,
#   'tread': 1,
#   'flags': 1,
#   'fox': 2,
#   'go': 1,
#   '#Bengazie': 1,
#   'Michelle': 2,
#   'Obama': 2,
#   'gots': 1,
#   'loose': 1,
#   'weight': 1,
#   'butt': 1,
#   '#gross': 1,
#   'column': 1,
#   ':': 4,
#   'EXECUTION': 1,
#   'FERGUSON': 1,
#   'http://t.co/bh8fgwu3gZ': 1,
#   '#ferguson': 1,
#   '#michaelbrown': 1,
#   '#policebrutality': 1,
#   'missing': 1,
#   'pretty': 1,
#   'blonde': 1,
#   'white': 4,
#   'girl': 1,
#   '@graceslick77': 3,
#   'Jail': 1,
#   'Rogue': 1,
#   'Racist': 2,
#   'Cops': 1,
#   'Stop': 1,
#   'Killing': 1,
#   'Unarmed': 1,
#   'Black': 1,
#   'Men': 1,
#   '#Sick': 2,
#   'liar': 1,
#   'http://t.co/CZk1kFS41Q': 1,
#   'Good': 1,
#   'exactly': 1,
#   'expected': 1,
#   'obsessed': 1,
#   "'": 3,
#   'derrière': 1,
#   '#perverts': 1,
#   '@my2bits4u': 2,
#   'tragic': 1,
#   '@Madaza41': 2,
#   'remember': 1,
#   'type': 1,
#   'invaded': 1,
#   'Iraq': 1,
#   'Boots': 2,
#   'ground': 2,
#   '?': 5,
#   'Cont': 1,
#   '...': 4,
#   'cares': 1,
#   'need': 2,
#   'Brittney': 1,
#   'Spears': 1,
#   'blobs': 1,
#   'fact': 1,
#   'dig': 1,
#   'find': 1,
#   'problem': 1,
#   'headline': 1,
#   'news': 3,
#   'http://t.co/0LKOR9MyqV': 1,
#   'remain': 1,
#   'silent': 1,
#   'ended': 1,
#   'http://t.co/SErbzckzdX': 1,
#   'property': 2,
#   'damage': 1,
#   'Fox': 3,
#   '>': 1,
#   'people': 3,
#   '@mchenthompson': 1,
#   'truth': 1,
#   'old': 2,
#   'rich': 1,
#   'Senator': 1,
#   '@GrooveSDC': 1,
#   'want': 2,
#   'hillbilly': 1,
#   'viewers': 1,
#   'start': 1,
#   'thinking': 1,
#   'race': 2,
#   'war': 1,
#   'finally': 1,
#   'started': 1,
#   '#FOXNEWS': 1,
#   'cameras': 1,
#   "can't": 1,
#   'focus': 1,
#   'brown': 2,
#   'foxnews': 2,
#   'tho': 1,
#   'many': 3,
#   '#HatersHate': 1,
#   '#LiarsLie': 1,
#   '#MikeBrown': 1,
#   'would': 3,
#   'shot': 1,
#   '#Benghazi': 1,
#   '#foxnews': 1,
#   'raised': 1,
#   'hater': 1,
#   ';': 1,
#   'knew': 1,
#   'wrong-always.But': 1,
#   'baffles': 1,
#   'w': 1,
#   '#Diversity': 1,
#   'creation': 1,
#   'ppl': 1,
#   'hate': 1,
#   'rt': 1,
#   'Thanks': 1,
#   '4': 1,
#   'going': 1,
#   'us': 1,
#   'care': 2,
#   'wonder': 1,
#   '✌': 1,
#   '️': 1,
#   'surprises': 1,
#   'really': 4,
#   'articles': 1,
#   'ran': 1,
#   'car': 1,
#   'fast': 1,
#   'actually': 1,
#   'interesting': 1,
#   'talking': 1,
#   'Plus': 1,
#   'dude': 1,
#   'joke': 1,
#   'Get': 1,
#   '@moiskd': 1,
#   'Imagine': 1,
#   'Ferguson': 3,
#   'folks': 1,
#   'strutting': 1,
#   'around': 1,
#   "AR's": 1,
#   'Think': 1,
#   'Perry': 1,
#   'Hannity': 1,
#   'hunkered': 1,
#   'solidarity': 1,
#   'release': 1,
#   'name': 1,
#   'cop': 1,
#   'spoke': 1,
#   'witnesses': 1,
#   '#BuyingTime': 1,
#   'turn': 1,
#   'News': 2,
#   'Shocking': 1,
#   'Earlier': 1,
#   'segment': 1,
#   'TV': 1,
#   'asking': 1,
#   'America': 1,
#   'anything': 1,
#   'stop': 1,
#   'looting': 1,
#   'say': 1,
#   'Nicely': 1,
#   'played': 1,
#   'sir': 1,
#   'tweet': 1,
#   'makes': 1,
#   'page': 1,
#   'stronger': 1,
#   'http://t.co/QNABzh699U': 1,
#   '@DMeralles': 1,
#   'http://t.co/u8QxZ0Dv60': 1,
#   '“': 1,
#   'three': 1,
#   'wise': 1,
#   'monkeys': 1,
#   'commented': 1,
#   'see': 1,
#   'evil': 3,
#   'hear': 1,
#   'speak': 1,
#   'yikes': 1,
#   'Na': 1,
#   'busy': 1,
#   'bitching': 1,
#   'POTUS': 1,
#   'sure': 1,
#   'http://t.co/shgRwLx9Ww': 1,
#   'Buying': 1,
#   'Time': 2,
#   'Protect': 1,
#   'Murdering': 1,
#   'Cop': 1,
#   '#Coward': 1,
#   'conservative': 1,
#   'taking': 1,
#   'different': 2,
#   'pov': 1,
#   'yeh': 1,
#   'dont': 1,
#   'watch': 1,
#   'shitty': 1,
#   'programming': 1,
#   'believe': 1,
#   'headlining': 1,
#   'even': 1,
#   'homepage': 1,
#   '#': 21,
#   'Ben': 2,
#   'ghazi': 1,
#   'Buy': 1,
#   'ing': 1,
#   'Diversity': 1,
#   'dirty': 1,
#   'Truth': 1,
#   'police': 1,
#   'brutality': 1,
#   'Sick': 1,
#   'Coward': 1,
#   'gaz': 1,
#   'ie': 1,
#   'Mike': 1,
#   'Brown': 1,
#   'Someone': 1,
#   'Liars': 1,
#   'Lie': 1,
#   'Haters': 1,
#   'Hate': 1,
#   'michael': 1,
#   'gross': 1,
#   'perverts': 1,
#   'ferguson': 1},
#  {'ferguson': 4,
#   'chief': 4,
#   'says': 3,
#   'feelings': 6,
#   'hurt': 4,
#   'ppl': 6,
#   'consider': 3,
#   'part': 4,
#   'problem': 5,
#   '.': 69,
#   '#ferguson': 2,
#   'http://t.co/VoJGrMOPbZ': 2,
#   '@ShannonLeeKiss': 26,
#   '@WyzeChef': 59,
#   '@AdmireLaniya__': 41,
#   'Even': 1,
#   'though': 1,
#   'seems': 2,
#   'difficult': 1,
#   'country': 1,
#   'need': 2,
#   'racial': 1,
#   'division': 1,
#   'Americans': 1,
#   '@radicalhearts': 1,
#   'wow': 1,
#   '...': 5,
#   'Making': 1,
#   'feel': 2,
#   'feels': 1,
#   'teen': 1,
#   'murdered': 1,
#   '?': 6,
#   '!': 5,
#   '@OberstabKrieger': 2,
#   'think': 2,
#   'looting': 3,
#   'effective': 1,
#   "I'm": 2,
#   'going': 2,
#   'judge': 3,
#   'live': 1,
#   '@joshmhump': 17,
#   'would': 5,
#   'never': 2,
#   'happen': 1,
#   'kid': 3,
#   'really': 1,
#   'seem': 1,
#   'care': 1,
#   'upsetting': 1,
#   '@LibertyIsALady': 10,
#   'make': 1,
#   'generalization': 3,
#   'WP': 1,
#   'harbor': 1,
#   'racism': 2,
#   '@petee224': 9,
#   'exactly': 1,
#   'lose': 1,
#   'purpose': 1,
#   'tweet': 1,
#   'RahRahing': 2,
#   'white': 9,
#   'people': 14,
#   'genrlztn': 1,
#   'Sad': 1,
#   'Nonetheless': 1,
#   ',': 9,
#   "I'll": 1,
#   'stand': 2,
#   'rights': 1,
#   'many': 4,
#   'non': 1,
#   'Black': 1,
#   'focused': 1,
#   'civil': 1,
#   'disturbances': 1,
#   'dead': 1,
#   'Red': 1,
#   'Riding': 1,
#   'Hood': 1,
#   'black': 2,
#   'media': 2,
#   '/': 2,
#   'cops': 2,
#   "would've": 1,
#   'put': 1,
#   'wolf': 2,
#   'paid': 1,
#   'vacation': 1,
#   '&': 1,
#   'talked': 1,
#   'tearz': 1,
#   '@tklowenstein': 1,
#   '#Ferguson': 2,
#   '♥': 1,
#   'respond': 1,
#   'crime': 2,
#   "what's": 3,
#   'right': 3,
#   'advocating': 1,
#   'meaningless': 1,
#   'harmless': 1,
#   'prejudice': 2,
#   '@pixiestateomind': 1,
#   'time': 1,
#   'Mike': 1,
#   'Brown': 1,
#   'speak': 1,
#   'Stand': 1,
#   'Constitution': 1,
#   'American': 1,
#   'Dream': 1,
#   "That's": 2,
#   'violated': 1,
#   '“': 3,
#   ':': 1,
#   'http://t.co/HUlpIqjoFL': 1,
#   '”': 2,
#   '-': 2,
#   'lol': 1,
#   'thankful': 1,
#   'comment': 3,
#   "that's": 3,
#   'sure': 1,
#   'Never': 1,
#   'said': 3,
#   'replying': 1,
#   'racist': 2,
#   'whole': 2,
#   'situation': 2,
#   'awful': 2,
#   'officer': 1,
#   'held': 1,
#   'accountable': 1,
#   'action': 1,
#   'officially': 1,
#   'favorite': 1,
#   'use': 1,
#   'lived': 1,
#   "can't": 2,
#   'promise': 2,
#   'react': 1,
#   'differently': 1,
#   'Please': 1,
#   'thing': 2,
#   'reverse': 2,
#   '"': 7,
#   ':)': 1,
#   'thinks': 1,
#   'relevant': 1,
#   'job': 1,
#   'probably': 1,
#   '@xianb8': 1,
#   'story': 1,
#   'attacking': 1,
#   'cop': 2,
#   'reason': 1,
#   'way': 1,
#   "grandmother's": 1,
#   'house': 1,
#   'makes': 1,
#   'much': 1,
#   'sense': 1,
#   'BTW': 1,
#   'love': 2,
#   'victim': 3,
#   'card': 2,
#   'felt': 1,
#   'judged': 1,
#   'skin': 1,
#   'color': 1,
#   'anger': 1,
#   'understandable': 1,
#   'generalized': 1,
#   'judgement': 1,
#   'shame': 1,
#   'know': 2,
#   'personally': 1,
#   'individuals': 1,
#   'interested': 1,
#   'raking': 1,
#   'protesters': 1,
#   'coals': 1,
#   'instead': 1,
#   'looking': 1,
#   'recognize': 1,
#   'friend': 2,
#   'see': 2,
#   'one': 2,
#   'believe': 1,
#   'solution': 1,
#   'thinking': 2,
#   'everyone': 1,
#   '@Principia': 4,
#   'go': 2,
#   'around': 2,
#   'gratuitously': 2,
#   'shooting': 2,
#   'agonize': 1,
#   'social': 1,
#   '…': 3,
#   'write': 1,
#   'poetry': 1,
#   'doubt': 1,
#   'self': 1,
#   'centered': 1,
#   'making': 2,
#   'affected': 1,
#   'always': 1,
#   'blessing': 2,
#   'together': 1,
#   'http://t.co/f4lkRMjFMU': 1,
#   '@TheBlackVoice': 1,
#   'serious': 1,
#   'oblivious': 1,
#   'damn': 1,
#   'near': 1,
#   'hilarious': 1,
#   'Thanks': 1,
#   'listening': 1,
#   'caused': 1,
#   'reaction': 1,
#   'clearly': 1,
#   'happened': 1,
#   'neighborhood': 1,
#   'want': 1,
#   'tear': 1,
#   'something': 1,
#   'boo': 1,
#   'fucking': 1,
#   'hoo': 1,
#   'join': 1,
#   'club': 1,
#   'Advocate': 1,
#   'PoC': 1,
#   'stop': 1,
#   'buy': 1,
#   'farce': 1,
#   'Art': 1,
#   'srsly': 1,
#   'Douglas': 1,
#   'Adams': 1,
#   'called': 1,
#   'White': 1,
#   'condescending': 1,
#   'us': 2,
#   'Well': 1,
#   'done': 1,
#   'anything': 1,
#   'prove': 1,
#   'whatever': 1,
#   'means': 1,
#   'Absolutely': 1,
#   'unfortunate': 1,
#   'advocate': 1,
#   'saying': 1,
#   'every': 1,
#   'person': 1,
#   'agree': 2,
#   'hope': 1,
#   'Ferguson': 2,
#   'PD': 1,
#   'comes': 1,
#   'conclusion': 2,
#   'u': 2,
#   'r': 2,
#   'tweeting': 1,
#   'w': 1,
#   'ur': 1,
#   'side': 2,
#   'yet': 1,
#   'condemned': 1,
#   'C': 1,
#   'young': 1,
#   'man': 1,
#   'objectively': 1,
#   'come': 1,
#   'Yes': 1,
#   'Based': 1,
#   'personal': 1,
#   'experiences': 1,
#   '39': 1,
#   'years': 1,
#   'observations': 1,
#   'history': 1,
#   'current': 1,
#   'events': 1,
#   'officers': 1,
#   '’': 1,
#   'bragging': 1,
#   'seedy': 1,
#   'paramilitary': 1,
#   'bars': 1,
#   'SMOKING': 1,
#   'cannot': 1,
#   'stupid': 1,
#   'pot': 1,
#   'calling': 1,
#   'kettle': 1,
#   "They've": 1,
#   'focusing': 1,
#   'bummer': 1,
#   'since': 1,
#   'start': 1,
#   'could': 1,
#   'blowing': 1,
#   'smoke': 1,
#   'behind': 1,
#   'anyone': 1,
#   'good': 1,
#   '#': 2},
#  {'#Ferguson': 6,
#   'completely': 5,
#   'shut': 6,
#   '.': 19,
#   'journalists': 6,
#   'allowed': 5,
#   '@kschottt': 3,
#   '@nagoul1': 19,
#   'FAA': 1,
#   'closed': 1,
#   'Ferguson': 2,
#   'news': 1,
#   'helicopters': 1,
#   '@callmelit': 3,
#   'Smells': 1,
#   'like': 1,
#   '#Gaza': 1,
#   '@YourAnonNews': 7,
#   'good': 1,
#   ',': 4,
#   'State': 1,
#   'Feds': 1,
#   'need': 1,
#   'step': 1,
#   'bring': 1,
#   'integrity': 1,
#   '&': 2,
#   'accountibility': 1,
#   'identify': 1,
#   'journalist': 1,
#   '?': 5,
#   '@sternhe': 2,
#   'thing': 1,
#   'think': 1,
#   'even': 1,
#   'legal': 1,
#   "here's": 1,
#   'official': 1,
#   'release': 1,
#   'http://t.co/MVUFTfMAhy': 1,
#   '“': 4,
#   ':': 6,
#   '”': 4,
#   'unreal': 1,
#   'fuck': 1,
#   'kind': 1,
#   'freedom': 1,
#   'going': 1,
#   'cleanse': 1,
#   'neighbourhood': 1,
#   'blacks': 1,
#   "'": 2,
#   'black': 1,
#   'sympathisers': 1,
#   'no-one': 1,
#   'complain': 1,
#   '#COPPOLITICS': 1,
#   'begins': 1,
#   'want': 2,
#   'us': 1,
#   'seeing': 1,
#   '!': 4,
#   'https://t.co/b3aA8YwAKO': 1,
#   '#ferguson': 1,
#   'Police': 1,
#   'shoot': 1,
#   'unarmed': 1,
#   'civilians': 1,
#   'yard': 1,
#   '@_cokeee': 1,
#   'aka': 1,
#   'Marshall': 1,
#   'Law': 1,
#   'full': 1,
#   'effect': 1,
#   'everyone': 1,
#   'needs': 1,
#   'gun': 1,
#   'objective': 1,
#   'voice': 1,
#   'sus': 1,
#   'See': 1,
#   'right': 2,
#   'scary': 1,
#   'shit': 1,
#   'Black': 1,
#   'time': 1,
#   'anything': 1,
#   'goes': 1,
#   '2': 2,
#   'answer': 1,
#   '4': 1,
#   'Channel': 2,
#   '5': 1,
#   'reporters': 1,
#   'protesters': 1,
#   'word': 1,
#   'CNN': 1,
#   'truck': 1,
#   'around': 1,
#   'earlier': 1,
#   'well': 1,
#   "that's": 1,
#   'citizen': 1,
#   'come': 1,
#   'many': 1,
#   'phone': 1,
#   'w': 1,
#   '/': 1,
#   'camera': 1,
#   'stop': 1,
#   'looting': 1,
#   'long': 1,
#   'enough': 1,
#   'Another': 1,
#   'Gaza': 1,
#   'America': 1,
#   '#FascistCops': 1,
#   'police': 1,
#   'state': 1,
#   'fucking': 1,
#   'disgusting': 1,
#   'careful': 1,
#   'Unacceptable': 1,
#   '#': 5,
#   'COP': 1,
#   'POLITICS': 1,
#   'ferguson': 1,
#   'Ga': 1,
#   'za': 1,
#   'Fascist': 1,
#   'Cops': 1},
#  {'Police': 2,
#   'thrown': 2,
#   'something': 2,
#   'crowd': 3,
#   '.': 7,
#   'sure': 2,
#   'tho': 2,
#   'Protester': 2,
#   'says': 2,
#   '"': 2,
#   'enough': 2,
#   'bullets': 2,
#   'everybody': 2,
#   '#Ferguson': 2,
#   '@Nettaaaaaaaa': 2,
#   'Oh': 1,
#   'shit': 1,
#   'FUCK': 1,
#   'let': 1,
#   'cops': 1,
#   'BAIT': 1,
#   '#myNYPD': 1,
#   'uses': 1,
#   'trick': 1,
#   'excuse': 1,
#   'disburse': 1,
#   'crowds': 1,
#   'want': 1,
#   'reaction': 1,
#   '#': 2,
#   'm': 1,
#   'yN': 1,
#   'Y': 1,
#   'P': 1,
#   'D': 1,
#   'Ferguson': 1},
#  {'St': 2,
#   '.': 16,
#   'Louis': 2,
#   'Co': 2,
#   'Police': 2,
#   'tell': 3,
#   'ofcr': 3,
#   'shot': 4,
#   'man': 3,
#   'pointed': 3,
#   'handgun': 3,
#   'Chambers': 3,
#   '&': 2,
#   'Sheffingdell': 3,
#   '1': 3,
#   'Man': 3,
#   'critical': 3,
#   '#ferguson': 3,
#   '@JrGothDetective': 1,
#   '@valeriehahn': 10,
#   'according': 1,
#   'police': 3,
#   "that's": 1,
#   'truth': 1,
#   'True': 1,
#   '?': 3,
#   '“': 1,
#   ':': 1,
#   'CountyPD': 1,
#   '/': 1,
#   '”': 1,
#   "I'm": 1,
#   'glad': 1,
#   'officer': 1,
#   'bundy': 1,
#   'ranch': 1,
#   ',': 2,
#   "would've": 1,
#   'lot': 1,
#   'people': 1,
#   'pointing': 1,
#   'guns': 1,
#   'Smh': 1,
#   'Uh': 1,
#   '!': 3,
#   'Oh': 1,
#   'serious': 1,
#   'officially': 1,
#   'control': 1,
#   '#Ferguson': 1,
#   'sure': 1,
#   'hope': 1,
#   'false': 1,
#   'sighting': 1,
#   '#PD': 1,
#   'hot': 1,
#   'water': 1,
#   '@Twitlertwit': 1,
#   '@kodacohen': 2,
#   'video': 1,
#   'believe': 1,
#   'anything': 1,
#   '#FERGUSON': 1,
#   'say': 1,
#   'release': 1,
#   '#': 7,
#   'bullets': 1,
#   'autopsy': 1,
#   '#MICHAELBROWN': 1,
#   'tx': 1,
#   'keeping': 1,
#   'us': 1,
#   'informed': 1,
#   'Stay': 1,
#   'safe': 1,
#   'source': 1,
#   'many': 1,
#   'weeks': 1,
#   'interview': 1,
#   'witnesses': 1,
#   '@mattdpearce': 1,
#   'Thank': 1,
#   'much': 1,
#   'getting': 1,
#   'scoop': 1,
#   'People': 1,
#   'pins': 1,
#   'needles': 1,
#   'reddit': 1,
#   'live': 1,
#   'feed': 1,
#   'http://t.co/Rd2wHonMgC': 1,
#   'MICHAEL': 1,
#   'BROWN': 1,
#   'P': 1,
#   'D': 1,
#   'Ferguson': 1,
#   'ferguson': 1,
#   'FERGUSON': 1},
#  {'St': 3,
#   '.': 9,
#   'Louis': 3,
#   'County': 3,
#   'police': 3,
#   'officer': 3,
#   'shot': 5,
#   'man': 3,
#   ',': 4,
#   'according': 3,
#   'PIO': 3,
#   'Brian': 3,
#   'Schellman': 3,
#   '#ferguson': 3,
#   '@valeriehahn': 5,
#   'Surprise': 1,
#   ':(': 1,
#   '@iamlivin4god': 1,
#   'yes': 1,
#   '"': 2,
#   'really': 1,
#   'take': 1,
#   'advantage': 1,
#   'first': 1,
#   'amendment': 1,
#   'right': 1,
#   'stay': 2,
#   'home': 2,
#   'fear': 1,
#   '’': 1,
#   'awesome': 1,
#   'job': 1,
#   '“': 1,
#   ':': 1,
#   '”': 1,
#   'another': 1,
#   'one': 1,
#   ':/': 1,
#   'would': 2,
#   'quit': 1,
#   'chaos': 1,
#   'fun': 1,
#   'get': 1,
#   'hurt': 1,
#   'cops': 1,
#   'fault': 1,
#   'smh': 1,
#   '#': 1,
#   'ferguson': 1},
#  {'#Ferguson': 6,
#   'Police': 3,
#   'hiding': 2,
#   '"': 16,
#   'drive': 6,
#   'shooting': 3,
#   'black': 5,
#   'woman': 2,
#   'recording': 2,
#   'last': 2,
#   "night's": 2,
#   'action': 2,
#   '?': 4,
#   'http://t.co/wfuDYm9q27': 1,
#   '#OpFerguson': 1,
#   '@occbaystreet': 18,
#   'NOBODY': 1,
#   'Believes': 1,
#   'Spook': 1,
#   'Shot': 1,
#   'Drive-By': 1,
#   '!': 8,
#   '@SpookPacShakur': 2,
#   'Howard': 1,
#   'Grad': 1,
#   'Alive': 1,
#   'PreciousGirl': 1,
#   'PRAY': 1,
#   '♥': 1,
#   'http://t.co/xahPZBOwLv': 1,
#   'hav': 2,
#   '2': 3,
#   'make': 2,
#   'seem': 1,
#   'violent': 1,
#   '&': 3,
#   'thuggish': 1,
#   'justify': 1,
#   'continued': 1,
#   '#PoliceState': 1,
#   '@ru4peace2': 4,
#   '@Dreamdefenders': 11,
#   '@KUHU45': 6,
#   'Yup': 1,
#   '...': 7,
#   'Say': 1,
#   'word': 1,
#   "'": 7,
#   'drive-by': 3,
#   'conjures': 1,
#   'gang': 1,
#   'wars': 1,
#   'Strokes': 1,
#   'narrative': 1,
#   'think': 1,
#   'shot': 3,
#   'less': 1,
#   'lethals': 1,
#   'blamed': 1,
#   'people': 2,
#   'killed': 1,
#   'another': 1,
#   'man': 2,
#   '.': 20,
#   'Fuckers': 1,
#   'r': 1,
#   'code': 1,
#   'words': 1,
#   '/': 3,
#   'phrases': 1,
#   'stereotype': 1,
#   'blk': 1,
#   'protesters': 2,
#   ',': 4,
#   'wearing': 1,
#   'mask': 1,
#   'etc': 1,
#   "can't": 2,
#   'open': 1,
#   'fuckin': 1,
#   'mouths': 1,
#   'w': 2,
#   'lies': 1,
#   'spilling': 1,
#   'allow': 2,
#   'peaceful': 1,
#   'protest': 1,
#   'USA': 1,
#   'unacceptable': 1,
#   'tear': 1,
#   'gas': 1,
#   'peacefully': 1,
#   'protesting': 1,
#   'cop': 2,
#   'literally': 2,
#   'goes': 2,
#   'cover': 2,
#   'cops': 4,
#   'mouth': 2,
#   'Wtf': 2,
#   'WTF': 1,
#   'RT': 1,
#   'http://t.co/dicBCVYMVZ': 1,
#   'WOW': 1,
#   'notice': 1,
#   'police': 4,
#   'stopped': 1,
#   'telling': 1,
#   'lady': 2,
#   'one': 1,
#   'shld': 1,
#   'believe': 3,
#   'account': 1,
#   'happens': 1,
#   'lie': 1,
#   '#MikeBrown': 1,
#   '@YourAnonNews': 3,
#   'Suspect': 2,
#   'number': 2,
#   '1.Cops': 1,
#   'dumb': 1,
#   'ass': 1,
#   'KKK': 2,
#   'still': 2,
#   'around': 1,
#   'B': 1,
#   'ONE': 1,
#   'lastnight': 1,
#   'exactly': 1,
#   'wld': 1,
#   'standn': 1,
#   'CALM': 1,
#   'ppl': 1,
#   'done': 1,
#   'see': 1,
#   'happening': 1,
#   'burbs': 1,
#   '“': 1,
#   '@CassandraRules': 1,
#   ':': 1,
#   '”': 1,
#   'worse': 1,
#   'part': 1,
#   'watched': 1,
#   'video': 1,
#   "he'd": 1,
#   'said': 1,
#   'bc': 1,
#   'public': 1,
#   'safety': 1,
#   'concern': 1,
#   '@IMShawnAndrews': 2,
#   'told': 1,
#   'story': 1,
#   'many': 1,
#   'times': 1,
#   'got': 1,
#   'beat': 1,
#   '4': 1,
#   'buddy': 1,
#   'buying': 1,
#   'cheeseburger': 1,
#   '@SeriusBall': 1,
#   'Safe': 1,
#   'say': 1,
#   'happened': 1,
#   'wraps': 1,
#   'agree': 1,
#   'likely': 1,
#   '@kathysamira': 1,
#   'go': 1,
#   'big': 1,
#   'right': 1,
#   'away': 1,
#   'Could': 1,
#   'talk': 1,
#   'witnesses': 1,
#   'somehow': 1,
#   '@LisaJac21671472': 1,
#   'yeah': 1,
#   'looks': 1,
#   'like': 1,
#   'helicopters': 1,
#   'media': 1,
#   'huh': 1,
#   'nah': 1,
#   'reason': 1,
#   'world': 1,
#   'would': 1,
#   'target': 1,
#   'random': 1,
#   '#': 4,
#   'Ferguson': 2,
#   'Po': 1,
#   'li': 1,
#   'c': 1,
#   'eState': 1,
#   'O': 1,
#   'p': 1,
#   'Mike': 1,
#   'Brown': 1},
#  {'Police': 2,
#   'St': 2,
#   '.': 5,
#   'Louis': 2,
#   'County': 2,
#   'say': 2,
#   'officer': 2,
#   'shot': 2,
#   'critically': 2,
#   'wounded': 2,
#   'suspect': 2,
#   'early': 2,
#   'morning': 2,
#   'near': 2,
#   '#Ferguson': 3,
#   'http://t.co/htLmEiuCS5': 2,
#   '@kmoxnews': 7,
#   '@AntonioFrench': 3,
#   'strange': 1,
#   '...': 2,
#   'didnt': 1,
#   'take': 1,
#   '22': 1,
#   'hrs': 1,
#   'release': 1,
#   'statement': 1,
#   'acknowledging': 1,
#   'incident': 1,
#   'referring': 1,
#   'protesters': 1,
#   'suspects': 1,
#   '?': 3,
#   '@GodWomb': 3,
#   '&': 2,
#   'kneeling': 1,
#   'hands': 1,
#   'air': 1,
#   '#FactCheck': 1,
#   'good': 1,
#   'fuck': 1,
#   'police': 1,
#   '@wildwalkerwoman': 1,
#   'article': 1,
#   'looks': 1,
#   'like': 1,
#   'bs': 1,
#   'yet': 1,
#   'see': 1,
#   'confirmed': 1,
#   'tweeps': 1,
#   'Get': 1,
#   'info': 1,
#   ',': 1,
#   '#MSM': 1,
#   '#agenda': 1,
#   'got': 1,
#   'STOP': 1,
#   '#MikeBrown': 1,
#   '@TefPoe': 1,
#   '#NYT': 1,
#   'announced': 1,
#   '#MartialLaw': 1,
#   ':(': 1,
#   '(': 2,
#   'http://t.co/A46fTxEux2': 1,
#   '#': 7,
#   'Martial': 1,
#   'Law': 1,
#   'MS': 1,
#   'M': 1,
#   'Mike': 1,
#   'Brown': 1,
#   'Fact': 1,
#   'Check': 1,
#   'N': 1,
#   'Y': 1,
#   'T': 1,
#   'Ferguson': 1,
#   'agenda': 1},
#  {'Another': 2,
#   'police': 5,
#   'shooting': 2,
#   'protest-plagued': 2,
#   '#Ferguson': 5,
#   ':': 2,
#   'http://t.co/NcVUm7Fqdp': 2,
#   '(': 2,
#   'Scott': 2,
#   'Olson': 2,
#   ',': 7,
#   'Getty': 2,
#   'Images': 2,
#   ')': 2,
#   'http://t.co/YfIp2RUB4N': 2,
#   '@USATODAY': 16,
#   '@NaphiSoc': 4,
#   'http://t.co/mwIYhuJcw5': 1,
#   '.': 10,
#   'Funny': 1,
#   'would': 1,
#   'said': 1,
#   '"': 4,
#   'plague': 1,
#   'violence': 1,
#   'protests': 1,
#   'response': 1,
#   '@nhdogmom': 1,
#   'shot': 1,
#   'first': 1,
#   'ask': 1,
#   'questions': 1,
#   'later': 1,
#   'plagued': 2,
#   'protest': 1,
#   '-': 1,
#   'parts': 1,
#   'Africa': 1,
#   'Ebola': 1,
#   'idiot': 1,
#   'thinks': 1,
#   'solution': 1,
#   'anything': 1,
#   '?': 1,
#   'yes': 1,
#   '...': 2,
#   'accidents': 1,
#   'happen': 2,
#   'put': 1,
#   'spot': 1,
#   'wonder': 1,
#   'America': 1,
#   'becoming': 1,
#   'Police': 1,
#   'State': 1,
#   'look': 1,
#   'back': 1,
#   '30': 1,
#   'years': 1,
#   'tell': 1,
#   'see': 2,
#   'witness': 1,
#   'danger': 1,
#   'truth': 1,
#   'power': 1,
#   'hold': 1,
#   'state': 2,
#   'official': 1,
#   'taken': 1,
#   'far': 1,
#   'abusing': 1,
#   'authority': 1,
#   'loyal': 1,
#   'nation': 1,
#   'fly': 1,
#   'zone': 1,
#   'god': 1,
#   'think': 1,
#   'next': 1,
#   'military': 1,
#   'like': 3,
#   'call': 1,
#   'come': 1,
#   'run': 1,
#   'shoot': 1,
#   'everyone': 1,
#   'reason': 1,
#   'people': 1,
#   'mad': 1,
#   "can't": 1,
#   'bribe': 1,
#   'PD': 1,
#   'one': 1,
#   'got': 1,
#   'rid': 1,
#   '@dosSteckis': 1,
#   'white': 1,
#   'guy': 1,
#   'lacking': 1,
#   'evolution': 1,
#   'comment': 1,
#   '!': 1,
#   '@Shimaganish': 1,
#   'Federal': 1,
#   'custody': 1,
#   'point': 2,
#   "I''ll": 1,
#   'wait': 1,
#   'invest': 1,
#   'conclusion': 1,
#   '3': 1,
#   'black': 1,
#   'officers': 1,
#   'force': 1,
#   "That's": 1,
#   'wrong': 2,
#   'gun': 1,
#   'cop': 1,
#   'refuse': 1,
#   'stand': 1,
#   'nothing': 1,
#   'real': 1,
#   'big': 1,
#   'gang': 1,
#   'really': 1,
#   'makes': 1,
#   'sick': 1,
#   'say': 1,
#   '#': 1,
#   'Ferguson': 1},
#  {'woman': 6,
#   '#Ferguson': 6,
#   'shot': 5,
#   'head': 5,
#   'last': 5,
#   'night': 5,
#   'released': 4,
#   'selfie': 6,
#   '.': 21,
#   'Conflicting': 2,
#   'reports': 2,
#   'happened': 2,
#   ':': 6,
#   'http://t.co/25WX6EkquG': 2,
#   '@SeanCornholio': 2,
#   'wow': 3,
#   '@MichaelSkolnik': 16,
#   'story': 2,
#   'true': 1,
#   'Shooting': 1,
#   'related': 1,
#   'protesting': 1,
#   'Ppl': 1,
#   'street': 1,
#   'upset': 1,
#   'Also': 1,
#   ',': 5,
#   '6mo': 1,
#   'pregnant': 1,
#   'forced': 1,
#   'facedown': 1,
#   'ground': 1,
#   'reported': 1,
#   '@KMOV': 1,
#   '@LauraKHettiger': 1,
#   ';': 2,
#   'injured': 1,
#   'RANDOM': 1,
#   'drive-by': 1,
#   'shooting': 1,
#   'per': 3,
#   'Lt': 1,
#   'Col': 1,
#   'w': 1,
#   '/': 1,
#   '@STLCPD': 1,
#   'http://t.co/YcJivhDui8': 1,
#   'shame': 1,
#   'people': 1,
#   'like': 3,
#   'boy': 2,
#   'skolnik': 1,
#   'giving': 1,
#   'pub': 1,
#   '...': 1,
#   'perpetuates': 1,
#   'ridiculous': 2,
#   'things': 1,
#   '(': 1,
#   ')': 1,
#   '@prettyhurtsss_': 1,
#   'u': 4,
#   'spew': 1,
#   'racism': 2,
#   'hate': 1,
#   'us': 1,
#   'blks': 2,
#   '&': 2,
#   'Potus': 5,
#   '@milbank': 6,
#   '@ezrakelin': 6,
#   '@morningmika': 3,
#   '@GlennKesslerWP': 6,
#   'shw': 1,
#   'slvs': 1,
#   'http://t.co/WQCjnr013h': 1,
#   '@KUHU45': 1,
#   'terrible': 1,
#   'police': 2,
#   'control': 1,
#   'needs': 1,
#   'stopped': 1,
#   'asap': 1,
#   'minding': 1,
#   'ur': 1,
#   'business': 1,
#   'often': 1,
#   'first': 1,
#   'step': 1,
#   'towards': 1,
#   'big': 1,
#   'problems.No': 1,
#   'matter': 1,
#   'color': 1,
#   'much': 2,
#   'money': 1,
#   '“': 3,
#   'took': 1,
#   'http://t.co/5DZv7HE8FM': 1,
#   '”': 3,
#   'EVERYTHING': 1,
#   'WRONG': 1,
#   'WORLD': 1,
#   '⬆': 1,
#   '️': 1,
#   '@kev_cudi_': 2,
#   'crazy': 1,
#   'right': 1,
#   '?': 2,
#   '@MariaChappelleN': 2,
#   'version': 1,
#   'gm': 1,
#   'cld': 1,
#   'N': 1,
#   'wrd': 1,
#   'air.Birthers': 1,
#   'http://t.co/hBVvcHvw48': 1,
#   'http://t.co/qcXNu5M2Vj': 1,
#   '#HUalum': 1,
#   '@liberalphenom': 3,
#   '@charmed86': 1,
#   '@thereval': 3,
#   '@thereidreport': 3,
#   '@trymainlee': 3,
#   '4': 2,
#   'see': 2,
#   '>': 2,
#   'runs': 1,
#   'deep': 1,
#   '-': 1,
#   'MONTH': 1,
#   'LATER': 1,
#   'YET': 1,
#   'interview': 1,
#   '#MyaAatenWhite': 1,
#   'ambulances': 1,
#   'came': 1,
#   'numerous': 1,
#   'calls': 1,
#   'went': 1,
#   'aft': 1,
#   'Flotus': 1,
#   'fam': 1,
#   'going': 1,
#   'vacation': 1,
#   'lk': 1,
#   'whites': 1,
#   'daily': 1,
#   'Obamas': 1,
#   'cnt': 2,
#   'vac': 1,
#   'racist': 1,
#   'http://t.co/EddrhLVnw8': 1,
#   'blk': 1,
#   'go': 1,
#   'golf.wow': 1,
#   'http://t.co/nWHp1OMGdq': 1,
#   '"': 2,
#   'bit': 1,
#   'follow': 1,
#   'get': 1,
#   'shit': 1,
#   'reporting': 1,
#   'days': 1,
#   'diligently': 1,
#   'think': 1,
#   'would': 1,
#   'violent': 1,
#   '#casual': 1,
#   '#impressive': 1,
#   'http://t.co/ki10cz6Jiw': 1,
#   'compelling': 1,
#   'photo': 1,
#   'always': 1,
#   'miraculous': 1,
#   'hear': 1,
#   'headshot': 1,
#   'victim': 1,
#   'surviving': 1,
#   'Holy': 1,
#   'Moses': 1,
#   'never': 1,
#   'used': 1,
#   'believe': 1,
#   'social': 1,
#   'media': 1,
#   'really': 1,
#   'changing': 1,
#   'everything': 1,
#   'interact': 1,
#   '#': 5,
#   'My': 1,
#   'aA': 1,
#   'aten': 1,
#   'White': 1,
#   'HU': 1,
#   'alum': 1,
#   'Ferguson': 1,
#   'casual': 1,
#   'impressive': 1},
#  {'BREAKING': 1,
#   ':': 1,
#   '#Anonymous': 1,
#   'obtained': 1,
#   'audio': 1,
#   'files': 1,
#   'police': 1,
#   'dispatch': 1,
#   'EMS': 1,
#   '#MikeBrown': 1,
#   'shooting': 1,
#   '.': 2,
#   'release': 1,
#   'ASAP': 1,
#   '#Ferguson': 1,
#   '#': 3,
#   'Ferguson': 1,
#   'Mike': 1,
#   'Brown': 1,
#   'Anonymous': 1},
#  {'Mike': 12,
#   'Brown': 12,
#   '…': 10,
#   'Second': 10,
#   'police': 11,
#   'shooting': 11,
#   '#Ferguson': 11,
#   'leaves': 10,
#   'man': 11,
#   'critical': 10,
#   'condition': 10,
#   'http://t.co/uZpgcJK0bB': 2,
#   'RT': 2,
#   '@GlobalGrind': 13,
#   ':': 8,
#   'http://t.co/4oLCTZKyaK': 1,
#   'http://t.co/nxR7kK9rG5': 1,
#   '<': 1,
#   'SMH': 2,
#   '😔': 1,
#   '🙏': 1,
#   '“': 6,
#   'http://t.co/tMI5pz26Af': 1,
#   '”': 6,
#   '|': 1,
#   'Wow': 1,
#   'smh': 2,
#   'guy': 1,
#   'shot': 1,
#   '.': 2,
#   'get': 1,
#   'shit': 1,
#   'twisted': 1,
#   'armed': 1,
#   'handgun': 2,
#   'pointed': 2,
#   'officers': 1,
#   '...': 1,
#   'far': 1,
#   'different': 1,
#   '#MikeBrown': 1,
#   'FERGUSON': 1,
#   'POLICE': 1,
#   'DEPARTMENT': 1,
#   '"': 2,
#   'Justice': 2,
#   'right': 1,
#   'http://t.co/OHopwmqSYx': 1,
#   '#mikebrown': 1,
#   'Sad': 1,
#   'failed': 1,
#   'mention': 1,
#   '2nd': 1,
#   'County': 1,
#   'Sheriff': 1,
#   'deputy': 1,
#   'recovered': 1,
#   'http://t.co/H2m52IGnwI': 1,
#   'http://t.co/MengO3jbYx': 1,
#   'http://t.co/aqIaHXXkMy': 1,
#   '@barbs73': 1,
#   'omg': 1,
#   '!': 2,
#   'http://t.co/Z3kvU6Ladz': 1,
#   '😐': 1,
#   '@globalgrind': 1,
#   'http://t.co/AIT7xh0liT': 1,
#   'people': 1,
#   'going': 1,
#   '?': 1,
#   '#riseup': 1,
#   '#JusticeForMikeBrown': 1,
#   'http://t.co/cWyPsZExuh': 1,
#   '#': 5,
#   'For': 1,
#   'rise': 1,
#   'up': 1,
#   'Ferguson': 1,
#   'mike': 1,
#   'brown': 1},
#  {'Prayers': 1,
#   'mya': 1,
#   ',': 1,
#   'HU': 1,
#   'graduate': 1,
#   'shot': 1,
#   'protesting': 1,
#   'St': 1,
#   '.': 3,
#   'Louis': 1,
#   '!': 1,
#   '#MikeBrown': 1,
#   '#Ferguson': 2,
#   'http://t.co/J0OEIkJLHU': 1,
#   '@RokBailey': 2,
#   'Usa': 1,
#   'back': 1,
#   '50s': 1,
#   '#MLK': 1,
#   'would': 1,
#   'turn': 1,
#   'grave': 1,
#   'heaing': 1,
#   'utube': 1,
#   'video': 1,
#   'beginning': 1,
#   'cover-up': 1,
#   'damning': 1,
#   'shame': 1,
#   'Americans': 1,
#   'let': 1,
#   'police': 1,
#   'power': 1,
#   'get': 1,
#   'far': 1,
#   '#': 3,
#   'Ferguson': 1,
#   'Mike': 1,
#   'Brown': 1,
#   'M': 1,
#   'L': 1,
#   'K': 1},
#  {'Lets': 2,
#   'bomb': 2,
#   'nurseries': 2,
#   'w': 2,
#   '/': 2,
#   'White': 2,
#   'Babies': 2,
#   '!': 5,
#   '?': 14,
#   'FBI': 2,
#   ':': 8,
#   '#NBP': 3,
#   'leader': 2,
#   'inciting': 2,
#   'violence': 2,
#   '#Ferguson': 2,
#   'http://t.co/TCXSbfrTsV': 2,
#   '#tcot': 2,
#   'http://t.co/XDZqcWnoUQ': 2,
#   '@AmyMek': 38,
#   'whitey': 1,
#   'says': 1,
#   '"': 8,
#   'got': 1,
#   "e'm": 1,
#   '...': 5,
#   'Muppet': 1,
#   'brainwashed': 1,
#   'RT': 1,
#   '@tomgreen1959': 1,
#   '@dhrxsol1234': 2,
# ...
#   'glaube': 1,
#   'fest': 1,
#   'daran': 1,
#   'dass': 1,
#   'Fehler': 1,
#   'macht': 1,
#   '#': 2,
#   'Andreas': 1,
#   'Lu': 1,
#   'bit': 1,
#   'z': 1,
#   'wings': 1},
#  {'#GermanWings': 1,
#   'co-pilot': 1,
#   'fresh': 1,
#   '#Muslim': 1,
#   'convert': 2,
#   '-': 1,
#   'http://t.co/iNVyryt5LE': 1,
#   'via': 1,
#   '@Orvan': 4,
#   'Converts': 1,
#   '#Islam': 1,
#   'disturbed': 1,
#   '#WhiteMuslims': 1,
#   '@wuhokay': 3,
#   '@Thew3B': 3,
#   'position': 1,
#   'keep': 1,
#   'cockpit': 1,
#   'doors': 1,
#   'locked': 1,
#   'planes': 1,
#   'terrorism': 1,
#   'Culpable': 1,
#   'anyway': 1,
#   'fault': 1,
#   'evil': 1,
#   '@riwired': 7,
#   'evidence': 3,
#   'made': 1,
#   'public': 1,
#   ',': 5,
#   '(': 1,
#   'objective': 1,
#   ')': 1,
#   'writer': 1,
#   'talking': 1,
#   'saying': 1,
#   '"': 6,
#   'indicates': 1,
#   '?': 2,
#   'Must': 1,
#   'something': 1,
#   'like': 1,
#   'frankly': 1,
#   'first': 1,
#   'thing': 1,
#   'thought': 1,
#   'yesterday': 1,
#   '.': 10,
#   'look': 1,
#   ':': 1,
#   'https://t.co/uAD4PF3KiF': 1,
#   'Could': 1,
#   'propaganda': 1,
#   'Thing': 1,
#   'see': 1,
#   'lots': 1,
#   'tweets': 1,
#   'claiming': 2,
#   'jihadist': 1,
#   'Truth': 1,
#   'one': 2,
#   'knows': 1,
#   '@prittstift_nl': 1,
#   'right': 1,
#   'pro': 1,
#   'ISIS': 1,
#   'accounts': 1,
#   'brother': 1,
#   'Allah': 1,
#   'Perhaps': 1,
#   "that's": 1,
#   '..': 2,
#   'religions': 1,
#   'thugs': 1,
#   'good': 2,
#   'humans': 2,
#   '..\n\n..': 1,
#   'is.lam': 1,
#   'converts': 1,
#   'killers': 1,
#   'always': 1,
#   '..\n..': 1,
#   'boycott': 1,
#   '#HDL': 1,
#   '@KapilSpeaks': 1,
#   '@Jen3578': 2,
#   'agree': 1,
#   'totally': 1,
#   '@CoraBuhlert': 1,
#   'Seems': 1,
#   'people': 1,
#   'jumping': 1,
#   'conclusions': 1,
#   ':|': 1,
#   'beyond': 1,
#   "someone's": 1,
#   'comment': 1,
#   'site': 1,
#   'obscure': 1,
#   'magazine': 1,
#   'ever': 1,
#   'heard': 1,
#   'technology': 1,
#   "can't": 1,
#   'make': 1,
#   'things': 1,
#   'IDIOT': 1,
#   'proof': 1,
#   'whoever': 1,
#   'designed': 1,
#   'door': 1,
#   'provided': 1,
#   'pilot': 1,
#   'access': 1,
#   '#': 5,
#   'Islam': 1,
#   'Mu': 1,
#   'slim': 1,
#   'Whit': 1,
#   'eMus': 1,
#   'li': 1,
#   'ms': 1,
#   'H': 1,
#   'D': 1,
#   'L': 1,
#   'German': 1,
#   'Wings': 1},
#  {'#Germanwings': 1,
#   'co-pilot': 1,
#   'suffered': 1,
#   'serious': 1,
#   'depression': 1,
#   '6': 1,
#   'years': 1,
#   'ago': 1,
#   ':': 1,
#   'German': 2,
#   'newspaper': 1,
#   'http://t.co/LXDzBdNdMB': 1,
#   'http://t.co/yTUNdHyEJY': 1,
#   '#': 1,
#   'wings': 1},
#  {'Andreas': 1,
#   'Lubitiz': 1,
#   "'": 2,
#   'deemed': 2,
#   'unsuitable': 1,
#   'flight': 3,
#   'duties': 1,
#   'training': 1,
#   '#Germanwings': 2,
#   'http://t.co/nk5GGyuxaa': 1,
#   'http://t.co/HQpKZD4DSI': 1,
#   '@Independent': 9,
#   'SHAME': 1,
#   'SOCIETY': 1,
#   '!': 7,
#   'mental': 2,
#   'ill': 1,
#   'man': 1,
#   'Lufhansa': 1,
#   'knew': 1,
#   'murderers': 1,
#   'protect': 1,
#   'Directing': 1,
#   '18min': 1,
#   'horror': 1,
#   'movie': 1,
#   '"': 4,
#   'audience': 1,
#   'behind': 1,
#   'widescreen': 1,
#   'front.He': 1,
#   'musthave': 1,
#   'weird': 1,
#   'DVD': 1,
#   'collectn': 1,
#   'terrorist': 1,
#   'killed': 1,
#   'innocents': 1,
#   'u': 1,
#   'call': 1,
#   'white': 1,
#   'Muslim': 1,
#   '.': 3,
#   'BTW': 1,
#   'messed': 1,
#   'name': 3,
#   ',': 3,
#   'also': 1,
#   'goes': 1,
#   'shows': 1,
#   'unnecessary': 1,
#   'print': 1,
#   'real': 1,
#   'love': 1,
#   'stories': 1,
#   'songs': 1,
#   'lyrics': 1,
#   'heart': 1,
#   'touching': 1,
#   'status': 1,
#   ':': 1,
#   'Punjabian': 1,
#   'Da': 1,
#   'King': 1,
#   'song': 1,
#   'Dil': 1,
#   'chandre': 1,
#   'http://t.co/ALjzBJzObT': 1,
#   'http://t.co/aLgn6mKMil': 1,
#   'pincode': 1,
#   'crew': 1,
#   'access': 1,
#   'cockpit': 1,
#   '?': 3,
#   'printing': 1,
#   'full': 1,
#   'inflict': 1,
#   'serious': 1,
#   'harm': 1,
#   'family': 1,
#   'relatives': 1,
#   'really': 1,
#   'disgusting': 1,
#   'force': 1,
#   'back': 1,
#   'work': 1,
#   'early': 1,
#   'Could': 1,
#   'stigmatise': 1,
#   'sufferers.Will': 1,
#   'professions': 1,
#   'limits': 1,
#   'sufferers': 1,
#   '#kneejerk': 1,
#   'Feel': 1,
#   'sorry': 1,
#   'everyone': 1,
#   'concerned.So': 1,
#   'many': 1,
#   'issues': 1,
#   'arising': 1,
#   'this.Seriously': 1,
#   'raises': 1,
#   'health': 1,
#   'fore.Did': 1,
#   'airline': 1,
#   '1': 1,
#   '2': 1,
#   '#': 2,
#   'knee': 1,
#   'jerk': 1,
#   'German': 1,
#   'wings': 1},
#  {'#Germanwings': 1,
#   'Co': 1,
#   'Pilot': 1,
#   'New': 1,
#   'Muslim': 2,
#   'Convert': 1,
#   'Islamic': 1,
#   'State': 1,
#   'Praises': 1,
#   'Hero': 1,
#   '#WakeUpAmerica': 1,
#   '🇺': 1,
#   '🇸': 1,
#   'http://t.co/NYefk5WCPm': 1,
#   'http://t.co/J195dkGFGU': 1,
#   'Leftists': 1,
#   'want': 3,
#   'truth': 1,
#   'LIES': 1,
#   '.': 24,
#   'different': 1,
#   'faiths': 1,
#   'unlike': 1,
#   'RIGHT': 1,
#   '#USURY': 1,
#   'TREASON': 1,
#   'dumb': 1,
#   'masses': 1,
#   '@JackJolis': 1,
#   '@DrMartyFox': 21,
#   '@GolanMay': 4,
#   'far': 1,
#   'nothing': 1,
#   'conspiracy': 1,
#   'theorie': 1,
#   'going': 1,
#   'around': 1,
#   'alternative': 1,
#   'social': 1,
#   'media': 1,
#   '#IwantFacts': 1,
#   '@etabori': 1,
#   '’': 1,
#   'fall': 1,
#   'bullshit': 1,
#   '@cox24563': 1,
#   'Michael': 1,
#   'Mannheimer': 1,
#   'break': 1,
#   'story': 1,
#   'website': 1,
#   'doesnt': 1,
#   'react': 1,
#   'Facebook': 2,
#   'true': 2,
#   'making': 1,
#   'Islam': 1,
#   'seem': 1,
#   'like': 4,
#   'movie': 1,
#   'Invasion': 1,
#   'Body': 1,
#   'Snatchers': 1,
#   'makes': 1,
#   'stop': 1,
#   'using': 1,
#   'brain': 1,
#   '@peddoc63': 2,
#   '@LindaSuhler': 2,
#   '@gatewaypundit': 2,
#   'TRUTH': 3,
#   'revealed': 1,
#   'Finally': 1,
#   'set': 1,
#   'free': 1,
#   'w': 1,
#   '/': 1,
#   '?': 12,
#   '@RickCanton': 3,
#   'remember': 1,
#   'innocent': 1,
#   'deaths': 1,
#   'give': 1,
#   'mention': 1,
#   'co': 1,
#   'pilot': 2,
#   '...': 5,
#   'gives': 1,
#   'publicity': 1,
#   'German': 2,
#   'co-pilot': 1,
#   'mosque': 1,
#   'Bremen': 1,
#   '-': 2,
#   'man': 1,
#   ',': 3,
#   'leftist': 1,
#   'powers-that-be': 1,
#   'REALLY': 1,
#   'da': 1,
#   'FUCK': 1,
#   '@recedam1': 1,
#   '@abd_charlie': 1,
#   '@AbouDjaffar': 1,
#   '@An0n1214': 1,
#   'serious': 2,
#   '@RachelCohen12': 2,
#   'way': 1,
#   'world': 1,
#   'thoughts': 1,
#   '"': 4,
#   'copycat': 1,
#   '91descent': 1,
#   'mountains': 1,
#   'DRUGS': 1,
#   'mentioned': 1,
#   'depression': 1,
#   '@IL4me': 1,
#   'True': 1,
#   'would': 1,
#   'news': 2,
#   '@drmartyfox': 1,
#   'page': 3,
#   'fake': 1,
#   'removed': 1,
#   'converted': 1,
#   'death': 1,
#   'Omg': 1,
#   '@th_christine': 1,
#   'claim': 1,
#   'work': 1,
#   'place': 1,
#   'violence': 1,
#   'Obama': 1,
#   'Glad': 1,
#   'able': 1,
#   'rule': 1,
#   'terrorism': 1,
#   'right': 3,
#   'bat': 1,
#   '!': 1,
#   'realize': 1,
#   "that's": 1,
#   'nutty': 1,
#   'fan': 1,
#   '@EelPieLtd': 1,
#   '@ThePatriot143': 2,
#   'fox': 1,
#   'tjey': 1,
#   'found': 1,
#   "we're": 1,
#   'koran': 1,
#   'Mine': 1,
#   'Slow': 1,
#   'methodical': 1,
#   'descent': 1,
#   'got': 1,
#   ':': 1,
#   'MSM': 1,
#   'silent': 2,
#   'Fox': 1,
#   'News': 1,
#   'first': 1,
#   'thought': 1,
#   '#': 4,
#   'USURY': 1,
#   'Wa': 1,
#   'keUp': 1,
#   'America': 1,
#   'wings': 1,
#   'I': 1,
#   'Facts': 1},
#  {'Report': 6,
#   ':': 12,
#   'Germanwings': 6,
#   'Co-Pilot': 6,
#   'Treated': 5,
#   'Depression': 6,
#   'http://t.co/ewynIJ23A2': 1,
#   '.': 29,
#   '@nprnews': 20,
#   '@MorningEdition': 4,
#   'relevant': 1,
#   '?': 6,
#   '@justincapps': 1,
#   'exactly': 1,
#   ',': 24,
#   'stigmatizing': 1,
#   'mental': 2,
#   'illness': 2,
#   'time': 1,
#   'cost': 1,
#   '@amras': 1,
#   'Came': 1,
#   'say': 1,
#   'Tweets': 1,
#   'powerful': 1,
#   'statements': 1,
#   'convey': 1,
#   'far': 1,
#   '140': 1,
#   'characters': 1,
#   'whether': 1,
#   'intended': 1,
#   "LET'S": 1,
#   'STIGMATIZE': 1,
#   'INCREDIBLY': 1,
#   'COMMON': 1,
#   'ILLNESS': 1,
#   '!': 4,
#   'people': 5,
#   'may': 1,
#   'mentally': 1,
#   'ill': 1,
#   ';': 1,
#   'murderers': 1,
#   'things': 1,
#   'go': 1,
#   'hand': 3,
#   '“': 5,
#   'http://t.co/38qVFIkC5v': 1,
#   '”': 4,
#   'OK': 1,
#   '@SPLaws': 2,
#   'TBD': 1,
#   'point': 1,
#   'worry': 1,
#   'knee-jerk': 1,
#   'over-reactions': 1,
#   "we're": 1,
#   'prone': 1,
#   'America': 1,
#   'anything': 1,
#   'Cue': 1,
#   'bashing': 1,
#   'http://t.co/2CEYFKu69M': 1,
#   '@david_burns': 5,
#   "I'm": 1,
#   'chewing': 1,
#   'bit': 1,
#   '...': 1,
#   'Good': 1,
#   'call': 1,
#   'DB': 1,
#   'Germans': 1,
#   'evidently': 1,
#   'least': 1,
#   'one': 4,
#   'u': 1,
#   'know': 1,
#   'thought': 1,
#   'beginning': 1,
#   'else': 1,
#   'going': 1,
#   'forbid': 1,
#   'depression': 5,
#   "I'd": 1,
#   'like': 1,
#   'list': 1,
#   '-': 1,
#   "I've": 1,
#   'diagnosed': 1,
#   'since': 1,
#   'teen': 1,
#   '1': 1,
#   'flying': 1,
#   '2': 2,
#   'Foreign': 1,
#   'carriers': 1,
#   'STILL': 1,
#   'cabin': 1,
#   'times': 1,
#   'policy': 1,
#   'Wow': 1,
#   'yeah': 1,
#   'NPR': 1,
#   'MT': 2,
#   'let': 2,
#   '’': 4,
#   'careful': 2,
#   'red': 2,
#   'flag': 2,
#   'end': 2,
#   'fly': 2,
#   'drive': 2,
#   'teach': 2,
#   'etc': 2,
#   'received': 1,
#   '18': 1,
#   'months': 1,
#   'psychiatric': 1,
#   'treatment': 1,
#   'http://t.co/UaNq0REgiP': 1,
#   'paint': 1,
#   'rather': 1,
#   'fine': 1,
#   'portrait': 1,
#   'type': 1,
#   'large': 1,
#   'brush': 1,
#   'use': 1,
#   'whitewash': 1,
#   'barn': 1,
#   'Inform': 1,
#   'Please': 1,
#   'participate': 1,
#   'sensationalism': 1,
#   'stigmatise': 1,
#   'buses': 1,
#   'kids': 1,
#   'Along': 1,
#   '~': 1,
#   '6': 1,
#   '%': 1,
#   'global': 1,
#   'population': 1,
#   'apparently': 1,
#   'must': 1,
#   'pointed': 1,
#   'flown': 1,
#   'planes': 1,
#   'mountainsides': 1,
#   'story': 1,
#   'serves': 1,
#   'airlines': 1,
#   'bc': 1,
#   'blames': 1,
#   'something': 1,
#   'identifiable': 1,
#   'ppl': 1,
#   'feel': 1,
#   'safe': 1,
#   'even': 1,
#   'thing': 1,
#   'cause': 1,
#   'Raise': 1,
#   'virtual': 1,
#   'killed': 1,
#   '🙋': 1,
#   '#nostigma': 1,
#   'Tx': 1,
#   'right': 2,
#   'David': 1,
#   'jumped': 1,
#   'citizen': 1,
#   'overactive': 1,
#   'imagination': 1,
#   'pilot': 1,
#   '4': 1,
#   'reasons': 1,
#   'real': 1,
#   'question': 1,
#   'many': 1,
#   'Americans': 1,
#   'depressed': 1,
#   'Cant': 1,
#   'contributed': 1,
#   'chemical': 1,
#   'embalance': 1,
#   'embarrassing': 1,
#   'racist': 1,
#   'ableist': 1,
#   'otherwise': 1,
#   'appalling': 1,
#   'reporting': 1,
#   'http://t.co/6R9oHad22d”@JonRottenberg': 1,
#   '#depression': 1,
#   '#': 2,
#   'no': 1,
#   'stigma': 1},
#  {'#Germanwings': 1,
#   '#CoPilot': 1,
#   'recent': 1,
#   'Muslim': 4,
#   'convert': 1,
#   'well': 1,
#   'psychiatric': 1,
#   'patient': 1,
#   '.': 22,
#   '#ISIS': 1,
#   'lauding': 1,
#   'hero': 1,
#   'http://t.co/J29Y3tDjOP': 1,
#   '@DanOClunaigh': 4,
#   '@Zone6Combat': 20,
#   'assume': 1,
#   'u': 2,
#   'read': 2,
#   'thread': 1,
#   ',': 13,
#   'saw': 1,
#   'tiresome': 1,
#   'word': 1,
#   'mention': 1,
#   'pilot': 1,
#   'either': 2,
#   'r': 1,
#   'non': 1,
#   "I'm": 3,
#   'curious': 1,
#   'concerns': 1,
#   'implication': 1,
#   'Islamic': 1,
#   'involvement': 2,
#   '?': 6,
#   "'": 2,
#   'Andreas': 1,
#   'Lubitz': 1,
#   'Fans': 1,
#   'page': 2,
#   'set': 1,
#   'brainless': 1,
#   'fool': 1,
#   'variety': 1,
#   'agent': 1,
#   'provocateur': 1,
#   '. .': 1,
#   'Find': 1,
#   'article': 1,
#   'complete': 1,
#   'w': 2,
#   '/': 2,
#   'screenshots': 1,
#   'personal': 1,
#   'Facebook': 2,
#   'acct': 1,
#   'Jihadist': 1,
#   'rhetoric': 1,
#   'calling': 1,
#   'ppl': 1,
#   'idiots': 2,
#   '@ellepuntopi': 3,
#   'È': 1,
#   'bellissimo': 1,
#   'che': 1,
#   'mettono': 1,
#   'la': 1,
#   'foto': 1,
#   'dove': 1,
#   "c'è": 1,
#   'scritto': 1,
#   '"': 4,
#   'known': 2,
#   'terrorist': 4,
#   'asserendo': 1,
#   'il': 1,
#   'contrario': 1,
#   '...': 1,
#   'investigation': 1,
#   'works': 1,
#   'among': 1,
#   'professionals': 1,
#   'hysterical': 1,
#   'islamophobes': 1,
#   '@OkKelly22': 3,
#   'concern': 1,
#   'Islamist': 1,
#   'looks': 1,
#   'like': 1,
#   'good': 1,
#   'European': 1,
#   'Christian': 1,
#   'anything': 1,
#   'could': 1,
#   'aimed': 1,
#   'plane': 1,
#   'Sagrada': 1,
#   'Familia': 1,
#   'Trade': 1,
#   'Center': 1,
#   'Barcelona': 1,
#   'come': 1,
#   'actually': 1,
#   'kidding': 1,
#   'Please': 1,
#   'point': 2,
#   'substantial': 2,
#   'evidence': 5,
#   'motives': 3,
#   'Evidence': 1,
#   'pls': 1,
#   'Even': 1,
#   'one': 2,
#   'bit': 1,
#   'speak': 1,
#   "Let's": 1,
#   'see': 1,
#   'world': 2,
#   'needs': 1,
#   '!': 1,
#   '@SimZombie': 1,
#   'watch': 1,
#   'list': 1,
#   'mean': 1,
#   'jihadist': 1,
#   'sympathies': 1,
#   'beliefs': 1,
#   'Lack': 1,
#   'means': 1,
#   'terrorism': 2,
#   'found': 1,
#   'Yep': 1,
#   'sound': 1,
#   'logic': 1,
#   'better': 1,
#   'yet': 1,
#   'link': 1,
#   'ridiculous': 1,
#   'tweet': 1,
#   'everyone': 1,
#   '#facepalm': 1,
#   'Yeah': 1,
#   'delusional': 1,
#   'Noooooooooooooooo': 1,
#   'would': 1,
#   'EVER': 1,
#   'thought': 1,
#   'say': 1,
#   '::': 2,
#   ':': 3,
#   'yawn': 1,
#   'http://t.co/NjBemt7cHo': 1,
#   'great': 1,
#   'fact': 1,
#   'checking': 1,
#   'Um': 1,
#   'yes': 1,
#   'definition': 1,
#   'political': 2,
#   "there's": 1,
#   'absolutely': 1,
#   'copilot': 1,
#   'getting': 1,
#   'back': 1,
#   'absence': 1,
#   'assertions': 1,
#   'groundless': 1,
#   'make': 1,
#   '10': 1,
#   'mins': 1,
#   'microphone': 1,
#   'whole': 1,
#   'listening': 1,
#   'voice': 1,
#   'recorder': 1,
#   'message': 1,
#   '#': 4,
#   'CoPilot': 1,
#   'face': 1,
#   'palm': 1,
#   'I': 1,
#   'SIS': 1,
#   'German': 1,
#   'wings': 1},
#  {'GERMAN': 1,
#   'NEWS': 1,
#   'REPORT': 1,
#   ':': 1,
#   'Co-Pilot': 1,
#   'Germanwings': 1,
#   'Airbus': 1,
#   'MUSLIM': 1,
#   'CONVERT': 1,
#   '…': 1,
#   '’': 2,
#   'Hero': 1,
#   'Islamic': 1,
#   'State': 1,
#   '?': 4,
#   'http://t.co/Pw2kxje31m': 1,
#   'via': 1,
#   '@gatewaypundit': 8,
#   '@jjauthor': 7,
#   'MSM': 1,
#   'refuses': 1,
#   'say': 1,
#   'muslim': 2,
#   '.': 6,
#   'mental': 1,
#   'case': 1,
#   '/': 1,
#   'jihads': 1,
#   'Islam': 1,
#   'wonderfully': 1,
#   'peaceful': 2,
#   'religion': 1,
#   'wonder': 1,
#   'Iran': 1,
#   'centrifuges': 1,
#   'gave': 1,
#   'knew': 2,
#   'scarf': 1,
#   'wearing': 1,
#   'photo': 1,
#   'meant': 1,
#   'trouble': 1,
#   '!': 3,
#   'terrorism': 1,
#   'crazy': 1,
#   'bastards': 1,
#   'ones': 1,
#   'evil': 1,
#   'enough': 1,
#   'shit': 1,
#   'like': 1,
#   'Hmmm.Doesn': 1,
#   "'": 1,
#   'pundit': 1,
#   'mean': 1,
#   'joke': 1,
#   'seen': 1,
#   'news': 1,
#   '@DesireeAaron': 1,
#   'surprise': 1},
#  {'BREAKING': 1,
#   ':': 1,
#   'German': 1,
#   'Media': 1,
#   'Site': 1,
#   'Says': 1,
#   'Germanwings': 2,
#   'Co-Pilot': 1,
#   'Muslim': 3,
#   'Convert': 1,
#   'http://t.co/bTKvcLMN60': 1,
#   'via': 1,
#   '@anyclinic': 24,
#   '@SoTrophyHntrs': 2,
#   '@RWSurferGirl': 25,
#   'legitimate': 1,
#   '@rwsurfergirl': 2,
#   "'": 1,
#   'honesty': 1,
#   '.': 12,
#   'legit': 1,
#   'news': 1,
#   'sight': 1,
#   '?': 4,
#   'looks': 1,
#   'suspicious': 1,
#   '@JohnnyUtah27': 4,
#   'would': 2,
#   'know': 1,
#   'first': 2,
#   'thirty': 1,
#   'seconds': 1,
#   '...': 2,
#   'dam': 1,
#   'thought': 1,
#   'muslim': 1,
#   'wonder': 1,
#   'depreased': 1,
#   '@MrJamieD': 2,
#   "can't": 1,
#   'sain': 1,
#   'cut': 1,
#   'heads': 1,
#   '@FredSanford13': 2,
#   'good': 1,
#   'rumor': 1,
#   'start': 1,
#   'somewhere': 1,
#   'Way': 1,
#   '!': 6,
#   '😵': 1,
#   'man': 1,
#   'sick': 1,
#   'allowed': 1,
#   'fly': 1,
#   'doctor': 1,
#   'mentioned': 1,
#   'proactive': 1,
#   '..': 2,
#   'mental': 2,
#   'illness': 1,
#   'girlfriend': 2,
#   'discovered': 1,
#   "he's": 1,
#   'convert': 1,
#   'turns': 1,
#   'guy': 1,
#   'handle': 1,
#   'losing': 1,
#   'job': 1,
#   ',': 8,
#   'probably': 2,
#   'dumping': 1,
#   'added': 1,
#   'problem': 1,
#   'Especially': 1,
#   'since': 2,
#   'posts': 1,
#   'twitter': 1,
#   'BS': 1,
#   'nothing': 1,
#   'taken': 2,
#   'granted': 1,
#   '@pbanik': 1,
#   'Away': 1,
#   'troll': 1,
#   'nonsense': 2,
#   'though': 1,
#   'find': 1,
#   'claim': 2,
#   'suicide': 1,
#   'revelation': 1,
#   'question': 1,
#   'relevancy': 1,
#   'religion': 1,
#   'stability': 1,
#   'radicalism': 1,
#   'yes': 1,
#   '@weekiwachee03': 2,
#   'fairness': 1,
#   'muslims': 1,
#   'story': 1,
#   'unsubstantiated': 1,
#   'croc': 1,
#   'source': 1,
#   '154': 1,
#   'followers': 1,
#   'true': 3,
#   'said': 1,
#   'cover': 1,
#   'incompetence': 1,
#   "it'll": 1,
#   'awhile': 1,
#   'let': 1,
#   'little': 1,
#   'jewel': 1,
#   'like': 2,
#   'trolls': 1,
#   'read': 2,
#   '/': 1,
#   'follow': 1,
#   'tweets': 1,
#   'based': 1,
#   'dishonesty': 1,
#   '@CedarStArt': 2,
#   'yup': 1,
#   'painting': 1,
#   'narrative': 1,
#   'well': 1,
#   'embarrassing': 1,
#   'conservative': 1,
#   'sites': 1,
#   'publish': 1,
#   'makes': 1,
#   'look': 1,
#   'daily': 1,
#   'kos': 1,
#   "I've": 1,
#   'seen': 1,
#   'several': 1,
#   'smaller': 1,
#   'websites': 1,
#   'proclaim': 1,
#   'thing': 1,
#   "I'm": 2,
#   'waiting': 1,
#   'confirmation': 1,
#   'retweeting': 1,
#   'Hah': 1,
#   'Literally': 1,
#   'word': 1,
#   'plane': 1,
#   'crash': 1,
#   '"': 2,
#   'terrorism': 1,
#   'Time': 1,
#   'tell': 1,
#   'confused': 1,
#   'suffering': 1,
#   'depression': 1,
#   '&': 1,
#   'DRs': 1,
#   'notes': 1,
#   'excusing': 1,
#   'work': 1,
#   'Screenshots': 1,
#   'social': 1,
#   'media': 1,
#   'enough': 1}]

# %% [markdown]
# # Text Classification (4 marks)

# %% [markdown]
# ### Question 5 (1.0 mark)
#
# **Instructions**: Here we are interested to do text classification, to predict, given a tweet and its reactions, whether it is a rumour or not. The task here is to create training, development and test partitions from the preprocessed events and convert the bag-of-words representation into feature vectors.
#
# **Task**: Create training, development and test partitions with a 60%/20%/20% ratio. Remember to preserve the ratio of rumour/non-rumour events for all your partitions. Next, turn the bag-of-words dictionary of each event into a feature vector, using scikit-learn `DictVectorizer`.

# %%
from sklearn.feature_extraction import DictVectorizer
ji

vectorizer = DictVectorizer()

def get_labels(list_a):
    labels = []
    for each_event in list_a:
        if each_event in preprocessed_rumour_events:
            labels.append('rumour')
        else:
            labels.append('non-rumour')
    return labels

all_events = preprocessed_rumour_events + preprocessed_nonrumour_events
all_labels = get_labels(all_events)

training_data, dev_and_test_data, training_labels, dev_and_test_labels = train_test_split(all_events, all_labels, 
                                                                                          stratify = all_labels, 
                                                                                          random_state = 1, 
                                                                                          test_size = 0.4)

dev_data, test_data, dev_labels, test_labels = train_test_split(dev_and_test_data, dev_and_test_labels,
                                                               stratify = dev_and_test_labels,
                                                               random_state = 1, 
                                                               test_size = 0.5)    

training_set = vectorizer.fit_transform(training_data)
dev_set      = vectorizer.transform(dev_data)
test_set     = vectorizer.transform(test_data)


print("Vocabulary size =", len(vectorizer.vocabulary_))
# Out:
# Vocabulary size = 27852

# %%
dev_labels
# Out:
# ['rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour',
#  'rumour',
#  'non-rumour',
#  'rumour',
#  'rumour',
#  'rumour',
#  'rumour',
#  'non-rumour',
#  'non-rumour',
#  'non-rumour']

# %% [markdown]
# ### Question 6 (2.0 mark)
#
# **Instructions**: Now, let's build some classifiers. Here, we'll be comparing Naive Bayes and Logistic Regression. For each, you need to first find a good value for their main regularisation (hyper)parameters, which you should identify using the scikit-learn docs or other resources. Use the development set you created for this tuning process; do **not** use cross-validation in the training set, or involve the test set in any way. You don't need to show all your work, but you do need to print out the accuracy with enough different settings to strongly suggest you have found an optimal or near-optimal choice. We should not need to look at your code to interpret the output.
#
# **Task**: Implement two text classifiers: Naive Bayes and Logistic Regression. Tune the hyper-parameters of these classifiers and print the task performance for different hyper-parameter settings.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score


def print_accuracy(clf_list):
    for each_clf in clf_list:
        each_clf.fit(training_set, training_labels)
        a = each_clf.predict(dev_set)
        print ('accuracy =', accuracy_score(dev_labels,a))
            
# Naive Bayes Method
NB_clfs = []

print('Naive Bayes Method: ')

clf1 = MultinomialNB(alpha = 0.4, fit_prior=True)
clf2 = MultinomialNB(alpha = 0.5, fit_prior=True)
clf3 = MultinomialNB(alpha = 0.6, fit_prior=True)
clf4 = MultinomialNB(alpha = 0.7, fit_prior=True)
clf5 = MultinomialNB(alpha = 0.8, fit_prior=True)
clf6 = MultinomialNB(alpha = 0.9, fit_prior=True)
clf7 = MultinomialNB(alpha = 1, fit_prior=True)

NB_clfs.append(clf1)
NB_clfs.append(clf2)
NB_clfs.append(clf3)
NB_clfs.append(clf4)
NB_clfs.append(clf5)
NB_clfs.append(clf6)
NB_clfs.append(clf7)

print_accuracy(NB_clfs)

# Here we choose the alpha parameter to be 0.5 for the Naive Bayes classifier. 


#Logistic regression with different parameter settings

# 'lbfgs' method
print('\nLogistic Regression with solver=\'lbfgs\': ')
Logistic_clfs_1 = []


clf1 = LogisticRegression(C= 1, solver='lbfgs', max_iter = 1000, 
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour':2}, 
                         penalty='l2',dual =False, multi_class='ovr')

clf2 = LogisticRegression(C= 1, solver='lbfgs', max_iter = 1000, 
                         fit_intercept=True, class_weight = {'rumour':2, 'non-rumour':1.5}, 
                         penalty='l2',dual =False, multi_class='ovr')


clf3 = LogisticRegression(C= 0.6, solver='lbfgs',max_iter = 1000,
                         fit_intercept=True, class_weight = {'rumour':2, 'non-rumour':1.5}, 
                         penalty='l2',dual =False, multi_class='ovr')

clf4 = LogisticRegression(C= 0.1, solver='lbfgs', max_iter = 1000,
                         fit_intercept=True, class_weight = {'rumour':2, 'non-rumour':1.5}, 
                         penalty='l2',dual =False, multi_class='ovr')

clf5 = LogisticRegression(C= 0.6, solver='lbfgs',max_iter = 1000, 
                         fit_intercept=True, class_weight = {'rumour':3, 'non-rumour':2}, 
                         penalty='l2',dual =False, multi_class='ovr') 

clf6 = LogisticRegression(C= 0.6, solver='lbfgs',max_iter = 1000, 
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour':21}, 
                         penalty='l2',dual =False, multi_class='ovr') 

Logistic_clfs_1.append(clf1)
Logistic_clfs_1.append(clf2)
Logistic_clfs_1.append(clf3)
Logistic_clfs_1.append(clf4)
Logistic_clfs_1.append(clf5)
Logistic_clfs_1.append(clf6)

print_accuracy(Logistic_clfs_1)

# For 'lbfgs', max accuracy occurs when the inverse of regularization strength is 0.6,
# and 'rumour':'non-rumour' = 2:1.5. Here the max accuracy is 82%. 


# 'liblinear' method

print('\nLogistic Regression with solver = \'liblinear\': ')

Logistic_clfs_2 = []
clf1 = LogisticRegression(C= 1, solver='liblinear',
                         fit_intercept=False, class_weight = {'rumour':1, 'non-rumour':2}, 
                         penalty='l2',dual =False, multi_class='ovr')
clf2 = LogisticRegression(C= 0.8, solver='liblinear',
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour':2}, 
                         penalty='l2',dual =False, multi_class='ovr')

clf3 = LogisticRegression(C= 0.58, solver='liblinear',
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour':2}, 
                         penalty='l2',dual =False, multi_class='ovr') 

clf4 = LogisticRegression(C= 0.58, solver='liblinear',
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour':1}, 
                         penalty='l2',dual =False, multi_class='ovr') 
clf5 = LogisticRegression(C= 0.3, solver='liblinear',
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour':1}, 
                         penalty='l2',dual =False, multi_class='ovr') 

Logistic_clfs_2.append(clf1)
Logistic_clfs_2.append(clf2)
Logistic_clfs_2.append(clf3)
Logistic_clfs_2.append(clf4)
Logistic_clfs_2.append(clf5)

print_accuracy(Logistic_clfs_2)

# Here for solver = 'liblinear', I'd choose clf4, namely rumour:non-romour = 1:1 
# with a stronger regularisation.  The max accuracy is 82.67%. 


# 'newton-cg' method

print('\nLogistic Regression with solver = \'newton-cg\': ')
Logistic_clfs_3 = []

clf1 = LogisticRegression(C= 1, solver='newton-cg',
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour': 2}, 
                         penalty='l2',dual =False, multi_class='ovr')
clf2 = LogisticRegression(C= 0.5, solver='newton-cg',
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour': 2}, 
                         penalty='l2',dual =False, multi_class='ovr')
clf3 = LogisticRegression(C= 0.5, solver='newton-cg',
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour': 1}, 
                         penalty='l2',dual =False, multi_class='ovr')
clf4 = LogisticRegression(C= 0.2, solver='newton-cg',
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour': 1}, 
                         penalty='l2',dual =False, multi_class='ovr')
clf5 = LogisticRegression(C= 0.2, solver='newton-cg',
                         fit_intercept=True, class_weight = {'rumour':2, 'non-rumour':1.5}, 
                         penalty='l2',dual =False, multi_class='ovr') #0.846667


Logistic_clfs_3.append(clf1)
Logistic_clfs_3.append(clf2)
Logistic_clfs_3.append(clf3)
Logistic_clfs_3.append(clf4)
Logistic_clfs_3.append(clf5)

print_accuracy(Logistic_clfs_3)

# Here the max accuracy is achieved when C = 0.5 with the two classes having the same weight. 
# 'newton-cg' method achieves a max accuracy of 82%. 

#'sag' method

print('\nLogistic Regression with solver = \'sag\': ')
Logistic_clfs_4 = []

clf1 = LogisticRegression(C= 1, solver='sag', max_iter = 5000,
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour':2}, 
                         penalty='l2',dual =False, multi_class='ovr') 
clf2 = LogisticRegression(C= 0.67, solver='sag', max_iter = 5000,
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour':2}, 
                         penalty='l2',dual =False, multi_class='ovr') 
clf3 = LogisticRegression(C= 0.2, solver='sag', max_iter = 5000,
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour':2}, 
                         penalty='l2',dual =False, multi_class='ovr') 
clf4 = LogisticRegression(C= 1, solver='sag', max_iter = 5000,
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour':1}, 
                         penalty='l2',dual =False, multi_class='ovr') 
clf5 = LogisticRegression(C= 1, solver='sag', max_iter = 5000,
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour':1.5}, 
                         penalty='l2',dual =False, multi_class='ovr')

Logistic_clfs_4.append(clf1)
Logistic_clfs_4.append(clf2)
Logistic_clfs_4.append(clf3)
Logistic_clfs_4.append(clf4)
Logistic_clfs_4.append(clf5)

print_accuracy(Logistic_clfs_4)

# 'sag' method achieves its max accuracy when there's little/no regularisation and the 
# setting of rumour:non-rumour is 1:1. The max accuracy is 82.33%. 



#'saga' method

print('\nLogistic Regression with solver = \'saga\': ')
Logistic_clfs_5 = []
clf1 = LogisticRegression(C= 1, solver='saga', max_iter = 5000,
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour':2}, 
                         penalty='l2',dual =False, multi_class='ovr') 
clf2 =LogisticRegression(C= 0.2, solver='saga', max_iter = 5000,
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour':2}, 
                         penalty='l2',dual =False, multi_class='ovr')  
clf3 = LogisticRegression(C= 0.1, solver='saga', max_iter = 5000,
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour':2}, 
                         penalty='l2',dual =False, multi_class='ovr') 
clf4 = LogisticRegression(C= 0.1, solver='saga', max_iter = 5000,
                         fit_intercept=True, class_weight = {'rumour':1, 'non-rumour':1}, 
                         penalty='l2',dual =False, multi_class='ovr') 
clf5 = LogisticRegression(C= 0.1, solver='saga', max_iter = 5000,
                         fit_intercept=True, class_weight = {'rumour':1.5, 'non-rumour':1}, 
                         penalty='l2',dual =False, multi_class='ovr') 
clf6 = LogisticRegression(C= 0.05, solver='saga', max_iter = 5000,
                         fit_intercept=True, class_weight = {'rumour':1.8, 'non-rumour':1}, 
                         penalty='l2',dual =False, multi_class='ovr') 

Logistic_clfs_5.append(clf1)
Logistic_clfs_5.append(clf2)
Logistic_clfs_5.append(clf3)
Logistic_clfs_5.append(clf4)
Logistic_clfs_5.append(clf5)
Logistic_clfs_5.append(clf6)

print_accuracy(Logistic_clfs_5)
# In this method, a relatively strong regularisation and adjusted weights for the
# two classes combined give a better result. The max accuracy is this case is 81.67%.
# Out:
# Naive Bayes Method:
# accuracy = 0.7966666666666666
# accuracy = 0.8033333333333333
# accuracy = 0.7966666666666666
# accuracy = 0.7933333333333333
# accuracy = 0.7933333333333333
# accuracy = 0.7866666666666666
# accuracy = 0.7933333333333333
#
# Logistic Regression with solver='lbfgs':
# accuracy = 0.8166666666666667
# accuracy = 0.8166666666666667
# accuracy = 0.82
# accuracy = 0.8133333333333334
# accuracy = 0.8166666666666667
# accuracy = 0.79
#
# Logistic Regression with solver = 'liblinear':
# accuracy = 0.8233333333333334
# accuracy = 0.8166666666666667
# accuracy = 0.81
# accuracy = 0.8266666666666667
# accuracy = 0.8133333333333334
#
# Logistic Regression with solver = 'newton-cg':
# accuracy = 0.8166666666666667
# accuracy = 0.8133333333333334
# accuracy = 0.82
# accuracy = 0.81
# accuracy = 0.8166666666666667
#
# Logistic Regression with solver = 'sag':
# accuracy = 0.8166666666666667
# accuracy = 0.8133333333333334
# accuracy = 0.81
# accuracy = 0.8233333333333334
# accuracy = 0.8133333333333334
#
# Logistic Regression with solver = 'saga':
# accuracy = 0.8066666666666666
# accuracy = 0.81
# accuracy = 0.8133333333333334
# accuracy = 0.8133333333333334
# accuracy = 0.8166666666666667
# accuracy = 0.8166666666666667

# %% [markdown]
# ### Question 7 (1.0 mark)
#
# **Instructions**: Using the best settings you have found, compare the two classifiers based on performance in the test set. Print out both accuracy and macro-averaged F-score for each classifier. Be sure to label your output.
#
# **Task**: Compute test performance in terms of accuracy and macro-averaged F-score for both Naive Bayes and Logistic Regression, using optimal hyper-parameter settings.

# %%
# In the previous question, the optimal accuracy for logistic regression classifiers was 82.67%. 
# Here we are to test the performance of it along with the optimal Naive Bayes classifier on test set. 

clfs = []
clfs.append(NB_clfs[1])
clfs.append(Logistic_clfs_2[3])

for each_clf in clfs:
    print(each_clf)
    each_clf.fit(training_set, training_labels)
    a = each_clf.predict(test_set)
    print ('Accuracy =', accuracy_score(test_labels, a))
    print ('f1_score =', f1_score(test_labels, a, average = 'macro'))
    print ('\n')

# We can conclude that in this case, the logistic regression with this particular parameter settings
# yields a higher accuracy and macro-averaged F-score compared to the Naive Bayes method. 
# The accuracy of this classifier is 83%, which is even higher than that in the dev set.
# Out:
# MultinomialNB(alpha=0.5, class_prior=None, fit_prior=True)
# Accuracy = 0.7866666666666666
# f1_score = 0.770334928229665
#
#
# LogisticRegression(C=0.58, class_weight={'non-rumour': 1, 'rumour': 1},
#                    dual=False, fit_intercept=True, intercept_scaling=1,
#                    l1_ratio=None, max_iter=100, multi_class='ovr', n_jobs=None,
#                    penalty='l2', random_state=None, solver='liblinear',
#                    tol=0.0001, verbose=0, warm_start=False)
# Accuracy = 0.83
# f1_score = 0.7982568335552949
